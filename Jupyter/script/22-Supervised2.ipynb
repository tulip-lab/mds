# %% [markdown]
# # FLIP (01) Practical Data Science
#
# ---
# Team Director: Shaoni Wang | snwang@tulip.academy<br />
#
# TULIP Academy <br />
# http://www.tulip.academy
#
# ---

# %% [markdown]
# # Session 47 Supervised Learning in MLlib
#
#
# Spark has many libraries, namely under MLlib (Machine Learning Library)! Spark allows for quick and easy scalability of practical machine learning!
#
# In this lab exercise, you will learn about how to build a Linear Regression Model, a SVM model, and a Logistic Regression Model, also you will learn how to create Classification and Regression DecisionTree and RandomForest Models, as well as how to tune the parameters for each to create more optimal trees and ensembles of trees.
#
# ## Content
#
#
#
# ### Part 1 [Linear Regression](#lr)
#
#
# ### Part 2 [Support Vector Machine](#svm)
#
#
# ### Part 3 [Logistic Regression](#logit)
#
#
# ### Part 4 Decision Tree (Regression)
#
# 4.1 [maxDepth Parameter](#md)
#
# 4.2 [maxBins Parameter](#mb)
#
# 4.3 [minInstancesPerNode Parameter](#mip)
#
# 4.4 [minInfoGain Parameter](#mig)
#
#
# ### Part 5 [Decision Tree (Classification)](#dtc)
#
# ### Part 6 [Random Forest (Classification)](#rfc)
#
# 6.1 [numTrees Parameter](#nt)
#
# 6.2 [featureSubsetStrategy Parameter](#fss)
#
# ### Part 7 [Random Forest (Regression)](#rfr)

# %% [markdown]
# ---
# <a id = "lr"></a>
# ## <span style="color:#0b486b">1. Linear Regression</span>
#
# <img src = "http://www.biostathandbook.com/pix/regressionlollipop.gif", style="height: 200pt; width: 200pt;", align = 'center'>
#
# <div align="justify"><font size="3">Linear regression uses a "line of best fit", based on previous data in order to predict future values. There are plenty of model evaluation metrics that can be applied to linear regression.
#
# In this lab, we will look at <b>Mean Squared Error (MSE)</b></font></div>
#
# Import the following libraries: <br>
# <ul>
#     <li>LabeledPoint, LinearRegressionWithSGD, LinearRegressionModel from pyspark.mllib.regression</li>
# </ul>

# %%
from pyspark.mllib.regression import LabeledPoint, LinearRegressionWithSGD, LinearRegressionModel

# %% [markdown]
# Now we need to create a <b>RDD of data</b> called <b>rdd_data</b>. That will be done by using the SparkContext (sc) to read in the <b>brain_body_data.csv</b> dataset. Take a look at the dataset so you have a feel for how it's structured.

# %%
import pyspark
from pyspark.sql import SQLContext
sc = pyspark.SparkContext()

# %%
rdd_data = sc.textFile("22_data/brain_body_data.csv")

# %% [markdown]
# Now, run a <b>map function</b> on <b>rdd_data</b>, where the input is a <b>lambda function</b> that is as follows: <i>lambda line: line.split(",")</i>. This is so we can split the dataset by commas, since it's a comma-separated value file (CSV). Store this into a variable called <b>split_data</b>

# %%
split_data = rdd_data.map(lambda line: line.split(","))

# %% [markdown]
# Next, run the following function that will convert each line in our RDD into a LabeledPoint.

# %%
def labeledParse(line):
    return LabeledPoint(line[0], [line[1]])

# %% [markdown]
# Now, run a <b>map function</b> on <b>split_data</b>, passing in <b>labeledParse</b> as input. Store the output into a variable called <b>reg_data</b>.

# %%
reg_data = split_data.map(labeledParse)

# %% [markdown]
# Now, we will create a variable called <b>linReg_model</b>, which will contain the linear regression model. The model will be made by calling the <b>LinearRegressionWithSGD</b> class and using the <b>.train</b> function with it. The .train function will take in 3 inputs:
# <ul>
#     <li>1st: The training data (reg_data in this case)</li>
#     <li>2nd: The number of iterations, or how many times the regression will run (use iterations=150)</li>
#     <li>3rd: step used in SGD (use step=0.00001 in this case) </li>
# </ul>

# %%
linReg_model = LinearRegressionWithSGD.train(reg_data, iterations=150, step=0.00001)
# Out:
# C:\Users\lenovo\spark\python\lib\pyspark.zip\pyspark\mllib\regression.py:281: UserWarning: Deprecated in 2.0.0. Use ml.regression.LinearRegression.

# %% [markdown]
# Next, we will create a variable called <b>actualAndPred</b>, which will contain the actual response, along with the predicted response from the model. This will be done by using the <b>map</b> function on <b>reg_data</b>, and passing in:<br> <b>lambda p: (p.label, linReg_model.predict(p.features))</b> as the input.

# %%
actualAndPreds = reg_data.map(lambda p: (p.label, linReg_model.predict(p.features)))

# %% [markdown]
# We will calculate the Mean Squared Error (MSE) value for the prediction. Run the following code to calculate the MSE. <br> <br>
#
# The map function takes the actual value and subtracts it by the predicted value, then
# squares the result. This is done for each value. <br> <br>
#
# Next, the reduce function sums all of the mapped values together. <br> <br>
#
# Afterwards, the result is divided by the number of elements that are present in actualAndPreds.

# %%
MSE = actualAndPreds.map(lambda value: (value[0] - value[1])**2).reduce(lambda x, y: x + y) / actualAndPreds.count()
print("Mean Squared Error = " + str(MSE))
# Out:
# Mean Squared Error = 104244.7139017532

# %% [markdown]
# ---
# <a id = "svm"></a>
# ## <span style="color:#0b486b">2. Support Vector Machine (SVM)</span>
#
#
# <img src = "http://blogs.quovantis.com/wp-content/uploads/2015/09/Svm_max_sep_hyperplane_with_margin.png", style="height: 200pt; width: 200pt;", align = 'center'>
#
#
# <div align="justify"><font size="3">Support Vector Machines can be used for both <b>classification and regression</b> analysis. In our case, we will be using it for classification. Linear SVM in Spark only supports <b>binary classification</b>.</font></div>
#
# Import the following libraries: <br>
# <ul>
#     <li>SVMWithSGD, SVMModel from pyspark.mllib.classification</li>
#     <li>LabeledPoint from pyspark.mllib.regression</li>
# </ul>

# %%
from pyspark.mllib.classification import SVMWithSGD, SVMModel
from pyspark.mllib.regression import LabeledPoint

# %% [markdown]
# Now we need to create a <b>RDD of data</b> called <b>svm_data</b>. That will be done by using the SparkContext (sc) to read in the <b>sample_svm_data.txt</b> dataset, which is a sample dataset that is built-in to Spark. It contains 322 rows of data.

# %%
svm_data = sc.textFile("22_data/sample_svm_data.txt")

# %% [markdown]
# For this dataset, it isn't in a format that we need, so we will need the following function to modify it. This function will also create LabeledPoints out of the data, which is necessary to train the SVM Model. Depending on your dataset, the parsing required will differ.

# %%
def labeledParse(line):
    values = [float(x) for x in line.split(' ')]
    return LabeledPoint(values[0], values[1:])

# %% [markdown]
# This will be applied to <b>svm_data</b> by using the <b>.map</b> function, and passing in the <b>labeledParse function</b>. This will apply the labeledParse function to the entire dataset. Call the output <b>svm_parsed</b>

# %%
svm_parsed = svm_data.map(labeledParse)

# %% [markdown]
# Now create a SVM model using the <b>SVMWithSGD.train</b> function called <b>svm_model</b>, which requires two inputs:
# <ul>
#     <li>1st: The dataset containing the LabeledPoints (<b>svm_parsed</b> in this case)</li>
#     <li>2nd: The number of iterations the model will run (<b>120</b> in this case)</li>
# </ul>

# %%
svm_model = SVMWithSGD.train(svm_parsed, iterations=120)

# %% [markdown]
# Next, we will create a variable called <b>svm_Labels_Predicts</b>, which will map a tuple containing the label and the prediction. <br>
# This will be done by using the <b>.map</b> function once again, but on the parsed data, <b>svm_parsed</b>. <br>
# The input into svm_parsed.map() will be a lambda function: <b>lambda x: (x.label, svm_model.predict(x.features))</b>

# %%
svm_Labels_Predicts = svm_parsed.map(lambda x: (x.label, svm_model.predict(x.features)))

# %% [markdown]
# Now, we will take a look at the training error, called <b>trainingError</b>, which will tell us the accuracy of how well our model did. It will do this by counting the number of incorrect predictions it made, and divide it by the total number of predictions.<br>
# We will run a <b>.filter</b> on the model we just created, <b>svm_Labels_Predicts</b>, <b>count</b> the output of that with <b>.count()</b>, then <b>divide</b> by the <b>number of elements in svm_parsed</b>. <br> <br>
#
# This filter will take a lambda function as input: <b>lambda (v, p): v != p</b>, which just means that the function will look at the predicted value and the labeled value, then see if the prediction matched the label.<br><br>
#
# Make sure to add a <b>.count()</b> to the <b>filter</b>, then <b>divide</b> the whole thing by <b>float(svm_parsed.count())</b>

# %%
trainingError = svm_Labels_Predicts.filter(lambda value: value[0] != value[1]).count() / float(svm_parsed.count())

# %% [markdown]
# Finally, print trainingError, to see the percentage that the model predicted incorrectly.

# %%
print(trainingError)
# Out:
# 0.38198757763975155

# %% [markdown]
# ---
# <a id = "logit"></a>
# ## <span style="color:#0b486b">3. Logistic Regression</span>
#
#
# <img src = "http://cvxr.com/cvx/examples/cvxbook/Ch07_statistical_estim/html/logistics__01.png", style="height: 200pt; width: 200pt;", align = 'center'>
#
# <div align="justify"><font size="3">Logistic Regression is a classifier, similar to SVM. Logistic Regression can be used for Binary Classification, which is pretty clear when looking at the diagram above. In the diagram, where are two distinct sections that data resides, which represents a binary classification. <br> <br> In this lab, we will use the same dataset as the one used for SVM, so we can compare the accuracy of both models.</font></div>
#
# Import the following libraries: <br>
# <ul>
#     <li>LogisticRegressionWithLBFGS, LogisticRegressionModel from pyspark.mllib.classification</li>
#     <li>LabeledPoint from pyspark.mllib.regression</li>
# </ul>

# %%
from pyspark.mllib.classification import LogisticRegressionWithLBFGS, LogisticRegressionModel
from pyspark.mllib.regression import LabeledPoint

# %% [markdown]
# Since we are still using the same dataset as in SVM, we will be using the same <b>svm_parsed</b> variable.

# %% [markdown]
# Create a variable called <b>logReg_model</b>, where we <b>train</b> a <b>LogisticRegressionWithLBFGS</b> model by passing in <b>svm_parsed</b>.

# %%
# Build the model
logReg_model = LogisticRegressionWithLBFGS.train(svm_parsed)

# %% [markdown]
# Next, create a variable called <b>logReg_Labels_Predicts</b> by <b>mapping</b> the <b>svm_parsed</b> data and passing in the <b>label</b>, along with the <b>logReg_model prediction</b>. This is similar to what we did in the SVM section of the lab.

# %%
logReg_Labels_Predicts = svm_parsed.map(lambda p: (p.label, logReg_model.predict(p.features)))

# %% [markdown]
# Finally, we will find the training error, or percentage that the model predicted incorrect. Thids will by done by applying the <b>filter</b> function on <b>logReg_Labels_Predicts</b>. We will pass in a lambda function that will filter for all values that do not equal <b>(lambda (v, p): v != p)</b>, then apply a <b>count()</b> on the filter. This will get the number of incorrect predictions. Now, we need to divide by the total number of predictions, or <b>float(svm_parsed.count())</b>. Store this as <b>trainingError2</b>. Refer to the SVM section if you need a hint.

# %%
trainingError2 = logReg_Labels_Predicts.filter(lambda value: value[0] != value[1]).count() / float(svm_parsed.count())

# %% [markdown]
# Now print trainingError2 and trianingError (from the SVM section)

# %%
print(trainingError2)
print(trainingError)
# Out:
# 0.36645962732919257
# 0.38198757763975155

# %% [markdown]
# It seems as though the training error for Logistic Regression is just slightly better than SVM for this case!

# %% [markdown]
# ---
# ## <span style="color:#0b486b">4. Decision Tree (Regression)</span>
#
# Import the following libraries:
# <ul>
#     <li>DecisionTree, DecisionTreeModel from pyspark.mllib.tree</li>
#     <li>MLUtils from pyspark.mllib.util</li>
#     <li>time</li>
# </ul>

# %%
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
from pyspark.mllib.util import MLUtils
import time

# %% [markdown]
# Next, we will load in the <b>poker.txt</b> LibSVM file, which is a dataset based on poker hands. Use <b>MLUtils.loadLibSVMFile</b> and pass in the spark context (<b>sc</b>) and the path to the file <b>'resources/poker.txt'</b>. Store this into a variable called <b>regDT_data</b>

# %%
regDT_data = MLUtils.loadLibSVMFile(sc, '22_data/poker.txt')

# %% [markdown]
# Next, we need to split the data into a training dataset (called <b>regDT_train</b>) and testing dataset (called <b>regDT_test</b>). This will be done by running the <b>.randomSplit</b> function on <b>regDT_data</b>. The input into .randomSplit will be <b>[0.7, 0.3]</b>. <br> <br>
#
# This will give us a training dataset containing 70% of the data, and a testing dataset containing 30% of the data.

# %%
(regDT_train, regDT_test) = regDT_data.randomSplit([0.7, 0.3])

# %% [markdown]
# Next, we need to create the Regression Decision Tree called <b>regDT_model</b>. To instantiate the regressor, use <b>DecisionTree.trainRegressor</b>. We will pass in the following parameters:
# <ul>
#     <li>1st: The input data. In our case, we will use <b>regDT_train</b></li>
#     <li>2nd: The categorical features info. For our dataset, have <b>categoricalFeaturesInfo</b> equal <b>{}</b></li>
#     <li>3rd: The type of impurity. Since we're dealing with <b>Regression</b>, we will be have <b>impurity</b> set to <b>'variance'</b></li>
#     <li>4th: The maximum depth of the tree. For now, set <b>maxDepth</b> to <b>5</b>, which is the default value</li>
#     <li>5th: The maximum number of bins. For now, set <b>maxBins</b> to <b>32</b>, which is the default value</li>
#     <li>6th: The minimum instances required per node. For now, set <b>minInstancesPerNode</b> to <b>1</b>, which is the default value</li>
#     <li>7th: The minimum required information gain per node. For now, set <b>minInfoGain</b> to <b>0.0</b>, which is the default value</li>
# </ul> <br> <br>
#
# We will also be timing how long it takes to create the model, so run <b>start = time.time()</b> before creating the model and <b>print(time.time()-start)</b> after the model has been created. <br>
# <b>Note</b>: The timings differ on run and by computer, therefore some statements throughout the lab may not directly align with the results you get, which is okay! There are many factors that can affect the time output.

# %%
start = time.time()
regDT_model = DecisionTree.trainRegressor(regDT_train, categoricalFeaturesInfo={},
                                    impurity='variance', maxDepth=5, maxBins=32,
                                    minInstancesPerNode=1, minInfoGain=0.0)
print (time.time()-start)
# Out:
# 11.239694595336914

# %% [markdown]
# Next, we want to get the models prediction on the test data, which we will call <b>regDT_pred</b>. We will run <b>.predict</b> on regDT_model, passing in the testing data, <b>regDT_test</b> that is mapped using <b>.map</b> which maps the features by passing in a lambda function (<b>lambda x: x.features</b>).

# %%
regDT_pred = regDT_model.predict(regDT_test.map(lambda x: x.features))

# %% [markdown]
# Now create a variable called <b>regDT_label_pred</b> which uses a <b>.map</b> on <b>regDT_test</b>. Pass <b>lambda l: l.label</b> into the mapping function. Outside of the mapping function, add a <b>.zip(regDT_pred)</b>. This will merge the label with the prediction</b>

# %%
regDT_label_pred = regDT_test.map(lambda l: l.label).zip(regDT_pred)

# %% [markdown]
# Now we will calculate the Mean Squared Error for this prediction, which we will call <b>regDT_MSE</b>. This will equate to <b>regDT_label_pred.map(lambda (v, p): (v - p)**2).sum() / float(regDT_test.count())</b>, which will take the difference of the actual value and the predicted response, square it, and sum that with the rest of the values. Afterwards, it is divided by the total number of values in the testing data.

# %%
regDT_MSE = regDT_label_pred.map(lambda value: (value[0] - value[1])**2).sum() / float(regDT_test.count())

# %% [markdown]
# Next, print out the MSE prediction value (<b>str(regDT_MSE)</b>), as well as the learned regression tree model (<b>regDT_model.toDebugString()</b>), so you have an idea of what the tree looks like.

# %%
print('Test Mean Squared Error = ' + str(regDT_MSE))
print('Learned Regression Tree Model: ' + regDT_model.toDebugString())
# Out:
# Test Mean Squared Error = 0.5617129041772837
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 63 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 1.0658082975679541
#       Else (feature 1 > 8.0)
#        Predict: 0.6205493387589013
#      Else (feature 3 > 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 0.6168505516549649
#       Else (feature 1 > 8.0)
#        Predict: 0.47962382445141066
#     Else (feature 9 > 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6046267087276551
#       Else (feature 3 > 8.0)
#        Predict: 0.4741100323624595
#      Else (feature 1 > 8.0)
#       If (feature 7 <= 6.0)
#        Predict: 0.5028248587570622
#       Else (feature 7 > 6.0)
#        Predict: 0.3765182186234818
#    Else (feature 5 > 8.0)
#     If (feature 1 <= 8.0)
#      If (feature 9 <= 1.0)
#       If (feature 1 <= 1.0)
#        Predict: 1.4444444444444444
#       Else (feature 1 > 1.0)
#        Predict: 0.48255813953488375
#      Else (feature 9 > 1.0)
#       If (feature 7 <= 4.0)
#        Predict: 0.47324414715719065
#       Else (feature 7 > 4.0)
#        Predict: 0.5271966527196653
#     Else (feature 1 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.45743329097839897
#       Else (feature 3 > 10.0)
#        Predict: 0.5611814345991561
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6354166666666666
#       Else (feature 3 > 8.0)
#        Predict: 1.0594059405940595
#   Else (feature 7 > 8.0)
#    If (feature 1 <= 8.0)
#     If (feature 5 <= 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.5529640427599611
#       Else (feature 5 > 8.0)
#        Predict: 0.8512396694214877
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 10.0)
#        Predict: 0.4821664464993395
#       Else (feature 9 > 10.0)
#        Predict: 0.611904761904762
#     Else (feature 5 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 6.0)
#        Predict: 0.3316831683168317
#       Else (feature 3 > 6.0)
#        Predict: 0.5648148148148148
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.6627906976744186
#       Else (feature 3 > 10.0)
#        Predict: 1.1858407079646018
#    Else (feature 1 > 8.0)
#     If (feature 3 <= 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.47566718995290425
#       Else (feature 5 > 8.0)
#        Predict: 0.5989010989010989
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.6765432098765433
#       Else (feature 5 > 8.0)
#        Predict: 0.9699570815450643
#     Else (feature 3 > 8.0)
#      If (feature 5 <= 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 0.6307277628032345
#       Else (feature 9 > 8.0)
#        Predict: 1.0486725663716814
#      Else (feature 5 > 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 1.1502347417840375
#       Else (feature 9 > 8.0)
#        Predict: 2.048076923076923

# %% [markdown]
# Now that we've created the basic Regression Decision Tree, let's start tuning some parameters! To speed up the process and reduce the amount of code that appears in this notebook, I've made a function that encorporates all of the code above. This way, we can tune the parameters in a single line of code. <br> <br>
#
# Read over the code, and it should be apparent what each of the inputs should be. But just to reiterate:
# <ul>
#     <li>1st: maxDepthValue is the value for maxDepth (Type:Int, Range: 0 to 30)</li>
#     <li>2nd: maxBinsValue is the value for maxBins (Type: Int, Range: >= 2)</li>
#     <li>3rd: minInstancesValue is the value for minInstancesPerNode (Type: Int, Range: >=1)</li>
#     <li>4th: minInfoGainValue is the value for minInfoGain (Type: Float)</li>
#     <ul>
#         <li><b>NOTE</b>: The input for minInfoGain MUST contain a decimal (ex. -3.0, 0.1, etc.) or else you will get an error</li>
#     </ul>
# </ul>

# %%
def regDT_tuner(maxDepthValue, maxBinsValue, minInstancesValue, minInfoGainValue):
    start = time.time()
    regDT_model = DecisionTree.trainRegressor(regDT_train, categoricalFeaturesInfo={},
                                        impurity='variance', maxDepth=maxDepthValue, maxBins=maxBinsValue,
                                        minInstancesPerNode=minInstancesValue, minInfoGain=minInfoGainValue)
    print (time.time()-start)

    regDT_pred = regDT_model.predict(regDT_test.map(lambda x: x.features))
    regDT_label_pred = regDT_test.map(lambda l: l.label).zip(regDT_pred)
    regDT_MSE = regDT_label_pred.map(lambda value: (value[0] - value[1])**2).sum() / float(regDT_test.count())

    print('Test Mean Squared Error = ' + str(regDT_MSE))
    print('Learned Regression Tree Model: ' + regDT_model.toDebugString())

# %% [markdown]
# Start off by re-creating the original tree. That requires the inputs: <b>(5, 32, 1, 0.0)</b> into <b>regDT_tuner</b>

# %%
regDT_tuner(5, 32, 1, 0.0)
# Out:
# 7.127284288406372
# Test Mean Squared Error = 0.5617129041772837
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 63 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 1.0658082975679541
#       Else (feature 1 > 8.0)
#        Predict: 0.6205493387589013
#      Else (feature 3 > 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 0.6168505516549649
#       Else (feature 1 > 8.0)
#        Predict: 0.47962382445141066
#     Else (feature 9 > 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6046267087276551
#       Else (feature 3 > 8.0)
#        Predict: 0.4741100323624595
#      Else (feature 1 > 8.0)
#       If (feature 7 <= 6.0)
#        Predict: 0.5028248587570622
#       Else (feature 7 > 6.0)
#        Predict: 0.3765182186234818
#    Else (feature 5 > 8.0)
#     If (feature 1 <= 8.0)
#      If (feature 9 <= 1.0)
#       If (feature 1 <= 1.0)
#        Predict: 1.4444444444444444
#       Else (feature 1 > 1.0)
#        Predict: 0.48255813953488375
#      Else (feature 9 > 1.0)
#       If (feature 7 <= 4.0)
#        Predict: 0.47324414715719065
#       Else (feature 7 > 4.0)
#        Predict: 0.5271966527196653
#     Else (feature 1 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.45743329097839897
#       Else (feature 3 > 10.0)
#        Predict: 0.5611814345991561
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6354166666666666
#       Else (feature 3 > 8.0)
#        Predict: 1.0594059405940595
#   Else (feature 7 > 8.0)
#    If (feature 1 <= 8.0)
#     If (feature 5 <= 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.5529640427599611
#       Else (feature 5 > 8.0)
#        Predict: 0.8512396694214877
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 10.0)
#        Predict: 0.4821664464993395
#       Else (feature 9 > 10.0)
#        Predict: 0.611904761904762
#     Else (feature 5 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 6.0)
#        Predict: 0.3316831683168317
#       Else (feature 3 > 6.0)
#        Predict: 0.5648148148148148
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.6627906976744186
#       Else (feature 3 > 10.0)
#        Predict: 1.1858407079646018
#    Else (feature 1 > 8.0)
#     If (feature 3 <= 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.47566718995290425
#       Else (feature 5 > 8.0)
#        Predict: 0.5989010989010989
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.6765432098765433
#       Else (feature 5 > 8.0)
#        Predict: 0.9699570815450643
#     Else (feature 3 > 8.0)
#      If (feature 5 <= 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 0.6307277628032345
#       Else (feature 9 > 8.0)
#        Predict: 1.0486725663716814
#      Else (feature 5 > 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 1.1502347417840375
#       Else (feature 9 > 8.0)
#        Predict: 2.048076923076923

# %% [markdown]
# Remember that when we are tuning a specific parameter, that we will keep the other parameters at their original value

# %% [markdown]
# <a id = "md"></a>
#
# ### <span style="color:#0b486b">4.1 maxDepth Parameter</span>
#
# Let's start by tuning the <b>maxDepth</b> parameter. Begin by setting it to a lower value, such as <b>1</b>

# %%
regDT_tuner(1, 32, 1, 0.0)
# Out:
# 6.427727222442627
# Test Mean Squared Error = 0.6061532788362421
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 1 with 3 nodes
#   If (feature 7 <= 8.0)
#    Predict: 0.6151769087523278
#   Else (feature 7 > 8.0)
#    Predict: 0.6429528203601726

# %% [markdown]
# By decreasing the maxDepth parameter, you can see that the run-time slightly decreased, presenting a smaller tree as well. You may also see a slight increase in the error, which is to be expected since the tree is too small to make accurate predictions.

# %% [markdown]
# Now try increasing to value of <b>maxDepth</b> to a large number, such as <b>30</b>, which is the maximum value.

# %%
regDT_tuner(30, 32, 1, 0.0)
# Out:
# 15.76350712776184
# Test Mean Squared Error = 1.0954840418487617
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 24 with 12727 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        If (feature 5 <= 6.0)
#         If (feature 3 <= 6.0)
#          If (feature 9 <= 6.0)
#           If (feature 1 <= 5.0)
#            If (feature 7 <= 6.0)
#             If (feature 5 <= 5.0)
#              If (feature 5 <= 3.0)
#               If (feature 1 <= 1.0)
#                If (feature 7 <= 4.0)
#                 If (feature 3 <= 4.0)
#                  If (feature 8 <= 1.0)
#                   If (feature 0 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 0 > 3.0)
#                    Predict: 2.0
#                  Else (feature 8 > 1.0)
#                   If (feature 7 <= 2.0)
#                    If (feature 7 <= 1.0)
#                     Predict: 6.0
#                    Else (feature 7 > 1.0)
#                     If (feature 0 <= 1.0)
#                      Predict: 3.0
#                     Else (feature 0 > 1.0)
#                      Predict: 2.0
#                   Else (feature 7 > 2.0)
#                    Predict: 8.0
#                 Else (feature 3 > 4.0)
#                  If (feature 2 <= 1.0)
#                   Predict: 3.0
#                  Else (feature 2 > 1.0)
#                   Predict: 1.0
#                Else (feature 7 > 4.0)
#                 If (feature 9 <= 4.0)
#                  If (feature 0 <= 1.0)
#                   If (feature 2 <= 1.0)
#                    Predict: 1.0
#                   Else (feature 2 > 1.0)
#                    Predict: 2.0
#                  Else (feature 0 > 1.0)
#                   Predict: 1.0
#                 Else (feature 9 > 4.0)
#                  Predict: 0.0
#               Else (feature 1 > 1.0)
#                If (feature 9 <= 3.0)
#                 If (feature 7 <= 5.0)
#                  If (feature 3 <= 3.0)
#                   If (feature 1 <= 4.0)
#                    If (feature 8 <= 2.0)
#                     If (feature 1 <= 3.0)
#                      If (feature 6 <= 3.0)
#                       Predict: 2.0
#                      Else (feature 6 > 3.0)
#                       Predict: 3.0
#                     Else (feature 1 > 3.0)
#                      Predict: 1.0
#                    Else (feature 8 > 2.0)
#                     If (feature 1 <= 2.0)
#                      If (feature 5 <= 2.0)
#                       If (feature 0 <= 2.0)
#                        Predict: 3.0
#                       Else (feature 0 > 2.0)
#                        If (feature 3 <= 1.0)
#                         Predict: 2.0
#                        Else (feature 3 > 1.0)
#                         Predict: 3.0
#                      Else (feature 5 > 2.0)
#                       Predict: 1.0
#                     Else (feature 1 > 2.0)
#                      If (feature 0 <= 1.0)
#                       If (feature 1 <= 3.0)
#                        Predict: 3.0
#                       Else (feature 1 > 3.0)
#                        Predict: 4.0
#                      Else (feature 0 > 1.0)
#                       Predict: 6.0
#                   Else (feature 1 > 4.0)
#                    If (feature 5 <= 2.0)
#                     Predict: 2.0
#                    Else (feature 5 > 2.0)
#                     Predict: 1.0
#                  Else (feature 3 > 3.0)
#                   If (feature 1 <= 4.0)
#                    Predict: 1.0
#                   Else (feature 1 > 4.0)
#                    If (feature 0 <= 2.0)
#                     Predict: 2.0
#                    Else (feature 0 > 2.0)
#                     Predict: 3.0
#                 Else (feature 7 > 5.0)
#                  If (feature 6 <= 2.0)
#                   If (feature 8 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 8 > 3.0)
#                    Predict: 0.0
#                  Else (feature 6 > 2.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 1.0
#                   Else (feature 0 > 1.0)
#                    Predict: 2.0
#                Else (feature 9 > 3.0)
#                 If (feature 7 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 7 > 2.0)
#                  If (feature 0 <= 2.0)
#                   If (feature 2 <= 2.0)
#                    If (feature 4 <= 1.0)
#                     Predict: 3.0
#                    Else (feature 4 > 1.0)
#                     If (feature 4 <= 3.0)
#                      Predict: 2.0
#                     Else (feature 4 > 3.0)
#                      Predict: 1.0
#                   Else (feature 2 > 2.0)
#                    If (feature 1 <= 3.0)
#                     Predict: 2.0
#                    Else (feature 1 > 3.0)
#                     Predict: 1.0
#                  Else (feature 0 > 2.0)
#                   If (feature 7 <= 3.0)
#                    If (feature 8 <= 2.0)
#                     Predict: 4.0
#                    Else (feature 8 > 2.0)
#                     If (feature 5 <= 1.0)
#                      Predict: 1.0
#                     Else (feature 5 > 1.0)
#                      Predict: 3.0
#                   Else (feature 7 > 3.0)
#                    If (feature 8 <= 3.0)
#                     If (feature 6 <= 2.0)
#                      If (feature 2 <= 3.0)
#                       If (feature 3 <= 5.0)
#                        Predict: 2.0
#                       Else (feature 3 > 5.0)
#                        Predict: 1.0
#                      Else (feature 2 > 3.0)
#                       Predict: 1.0
#                     Else (feature 6 > 2.0)
#                      If (feature 3 <= 1.0)
#                       Predict: 0.0
#                      Else (feature 3 > 1.0)
#                       If (feature 2 <= 1.0)
#                        If (feature 0 <= 3.0)
#                         Predict: 2.0
#                        Else (feature 0 > 3.0)
#                         Predict: 1.0
#                       Else (feature 2 > 1.0)
#                        Predict: 1.0
#                    Else (feature 8 > 3.0)
#                     If (feature 5 <= 1.0)
#                      If (feature 7 <= 5.0)
#                       Predict: 0.0
#                      Else (feature 7 > 5.0)
#                       Predict: 1.0
#                     Else (feature 5 > 1.0)
#                      Predict: 1.0
#              Else (feature 5 > 3.0)
#               If (feature 8 <= 3.0)
#                If (feature 3 <= 1.0)
#                 If (feature 2 <= 3.0)
#                  If (feature 7 <= 5.0)
#                   Predict: 1.0
#                  Else (feature 7 > 5.0)
#                   If (feature 0 <= 2.0)
#                    Predict: 2.0
#                   Else (feature 0 > 2.0)
#                    Predict: 1.0
#                 Else (feature 2 > 3.0)
#                  Predict: 2.0
#                Else (feature 3 > 1.0)
#                 If (feature 1 <= 3.0)
#                  If (feature 9 <= 1.0)
#                   If (feature 0 <= 1.0)
#                    If (feature 2 <= 2.0)
#                     Predict: 2.0
#                    Else (feature 2 > 2.0)
#                     Predict: 1.0
#                   Else (feature 0 > 1.0)
#                    Predict: 1.0
#                  Else (feature 9 > 1.0)
#                   If (feature 9 <= 3.0)
#                    If (feature 7 <= 4.0)
#                     If (feature 4 <= 1.0)
#                      Predict: 4.0
#                     Else (feature 4 > 1.0)
#                      If (feature 0 <= 3.0)
#                       If (feature 0 <= 1.0)
#                        If (feature 2 <= 3.0)
#                         Predict: 4.0
#                        Else (feature 2 > 3.0)
#                         Predict: 1.0
#                       Else (feature 0 > 1.0)
#                        If (feature 5 <= 4.0)
#                         If (feature 0 <= 2.0)
#                          If (feature 1 <= 1.0)
#                           Predict: 2.0
#                          Else (feature 1 > 1.0)
#                           Predict: 1.0
#                         Else (feature 0 > 2.0)
#                          Predict: 2.0
#                        Else (feature 5 > 4.0)
#                         Predict: 1.0
#                      Else (feature 0 > 3.0)
#                       Predict: 3.0
#                    Else (feature 7 > 4.0)
#                     If (feature 3 <= 3.0)
#                      If (feature 6 <= 1.0)
#                       Predict: 2.0
#                      Else (feature 6 > 1.0)
#                       Predict: 3.0
#                     Else (feature 3 > 3.0)
#                      Predict: 4.0
#                   Else (feature 9 > 3.0)
#                    If (feature 3 <= 2.0)
#                     If (feature 0 <= 1.0)
#                      Predict: 4.0
#                     Else (feature 0 > 1.0)
#                      If (feature 0 <= 2.0)
#                       Predict: 2.0
#                      Else (feature 0 > 2.0)
#                       Predict: 1.0
#                    Else (feature 3 > 2.0)
#                     If (feature 1 <= 2.0)
#                      If (feature 9 <= 5.0)
#                       If (feature 3 <= 5.0)
#                        If (feature 5 <= 4.0)
#                         If (feature 0 <= 2.0)
#                          Predict: 1.0
#                         Else (feature 0 > 2.0)
#                          Predict: 0.0
#                        Else (feature 5 > 4.0)
#                         Predict: 2.0
#                       Else (feature 3 > 5.0)
#                        Predict: 3.0
#                      Else (feature 9 > 5.0)
#                       If (feature 0 <= 3.0)
#                        Predict: 3.0
#                       Else (feature 0 > 3.0)
#                        Predict: 4.0
#                     Else (feature 1 > 2.0)
#                      If (feature 2 <= 2.0)
#                       If (feature 0 <= 1.0)
#                        Predict: 2.0
#                       Else (feature 0 > 1.0)
#                        Predict: 1.0
#                      Else (feature 2 > 2.0)
#                       If (feature 2 <= 3.0)
#                        Predict: 1.0
#                       Else (feature 2 > 3.0)
#                        If (feature 3 <= 4.0)
#                         Predict: 1.0
#                        Else (feature 3 > 4.0)
#                         Predict: 0.0
#                 Else (feature 1 > 3.0)
#                  If (feature 6 <= 2.0)
#                   If (feature 4 <= 1.0)
#                    Predict: 3.0
#                   Else (feature 4 > 1.0)
#                    If (feature 1 <= 4.0)
#                     Predict: 6.0
#                    Else (feature 1 > 4.0)
#                     Predict: 4.0
#                  Else (feature 6 > 2.0)
#                   If (feature 7 <= 1.0)
#                    If (feature 1 <= 4.0)
#                     Predict: 6.0
#                    Else (feature 1 > 4.0)
#                     If (feature 0 <= 2.0)
#                      Predict: 2.0
#                     Else (feature 0 > 2.0)
#                      Predict: 3.0
#                   Else (feature 7 > 1.0)
#                    If (feature 8 <= 1.0)
#                     If (feature 0 <= 1.0)
#                      Predict: 2.0
#                     Else (feature 0 > 1.0)
#                      Predict: 1.0
#                    Else (feature 8 > 1.0)
#                     If (feature 9 <= 1.0)
#                      Predict: 3.0
#                     Else (feature 9 > 1.0)
#                      If (feature 3 <= 5.0)
#                       If (feature 0 <= 1.0)
#                        Predict: 1.0
#                       Else (feature 0 > 1.0)
#                        If (feature 0 <= 2.0)
#                         Predict: 2.0
#                        Else (feature 0 > 2.0)
#                         Predict: 1.0
#                      Else (feature 3 > 5.0)
#                       Predict: 3.0
#               Else (feature 8 > 3.0)
#                If (feature 7 <= 5.0)
#                 If (feature 7 <= 3.0)
#                  If (feature 3 <= 1.0)
#                   Predict: 2.0
#                  Else (feature 3 > 1.0)
#                   Predict: 1.0
#                 Else (feature 7 > 3.0)
#                  If (feature 3 <= 2.0)
#                   Predict: 2.0
#                  Else (feature 3 > 2.0)
#                   Predict: 3.0
#                Else (feature 7 > 5.0)
#                 If (feature 0 <= 2.0)
#                  Predict: 0.0
#                 Else (feature 0 > 2.0)
#                  Predict: 1.0
#             Else (feature 5 > 5.0)
#              If (feature 4 <= 3.0)
#               If (feature 3 <= 3.0)
#                If (feature 1 <= 1.0)
#                 Predict: 0.0
#                Else (feature 1 > 1.0)
#                 If (feature 0 <= 3.0)
#                  If (feature 0 <= 2.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 1.0
#                   Else (feature 0 > 1.0)
#                    Predict: 2.0
#                  Else (feature 0 > 2.0)
#                   Predict: 1.0
#                 Else (feature 0 > 3.0)
#                  If (feature 1 <= 2.0)
#                   Predict: 0.0
#                  Else (feature 1 > 2.0)
#                   If (feature 7 <= 2.0)
#                    Predict: 0.0
#                   Else (feature 7 > 2.0)
#                    Predict: 1.0
#               Else (feature 3 > 3.0)
#                If (feature 8 <= 1.0)
#                 If (feature 6 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 6 > 1.0)
#                  Predict: 3.0
#                Else (feature 8 > 1.0)
#                 If (feature 7 <= 5.0)
#                  Predict: 1.0
#                 Else (feature 7 > 5.0)
#                  Predict: 2.0
#              Else (feature 4 > 3.0)
#               If (feature 8 <= 1.0)
#                If (feature 0 <= 2.0)
#                 Predict: 3.0
#                Else (feature 0 > 2.0)
#                 Predict: 6.0
#               Else (feature 8 > 1.0)
#                If (feature 1 <= 4.0)
#                 Predict: 1.0
#                Else (feature 1 > 4.0)
#                 Predict: 3.0
#            Else (feature 7 > 6.0)
#             If (feature 6 <= 1.0)
#              If (feature 3 <= 4.0)
#               If (feature 7 <= 7.0)
#                Predict: 0.0
#               Else (feature 7 > 7.0)
#                If (feature 5 <= 3.0)
#                 If (feature 0 <= 3.0)
#                  Predict: 0.0
#                 Else (feature 0 > 3.0)
#                  Predict: 1.0
#                Else (feature 5 > 3.0)
#                 If (feature 1 <= 1.0)
#                  If (feature 2 <= 2.0)
#                   Predict: 1.0
#                  Else (feature 2 > 2.0)
#                   Predict: 0.0
#                 Else (feature 1 > 1.0)
#                  Predict: 1.0
#              Else (feature 3 > 4.0)
#               If (feature 7 <= 7.0)
#                Predict: 1.0
#               Else (feature 7 > 7.0)
#                If (feature 1 <= 2.0)
#                 Predict: 0.0
#                Else (feature 1 > 2.0)
#                 Predict: 1.0
#             Else (feature 6 > 1.0)
#              If (feature 5 <= 5.0)
#               If (feature 8 <= 1.0)
#                If (feature 9 <= 3.0)
#                 If (feature 5 <= 3.0)
#                  If (feature 0 <= 1.0)
#                   Predict: 2.0
#                  Else (feature 0 > 1.0)
#                   Predict: 3.0
#                 Else (feature 5 > 3.0)
#                  Predict: 1.0
#                Else (feature 9 > 3.0)
#                 If (feature 3 <= 2.0)
#                  Predict: 0.0
#                 Else (feature 3 > 2.0)
#                  Predict: 1.0
#               Else (feature 8 > 1.0)
#                If (feature 3 <= 4.0)
#                 If (feature 4 <= 3.0)
#                  If (feature 0 <= 1.0)
#                   If (feature 1 <= 1.0)
#                    Predict: 3.0
#                   Else (feature 1 > 1.0)
#                    Predict: 1.0
#                  Else (feature 0 > 1.0)
#                   If (feature 4 <= 1.0)
#                    If (feature 5 <= 2.0)
#                     Predict: 0.0
#                    Else (feature 5 > 2.0)
#                     Predict: 1.0
#                   Else (feature 4 > 1.0)
#                    If (feature 1 <= 1.0)
#                     If (feature 0 <= 3.0)
#                      Predict: 1.0
#                     Else (feature 0 > 3.0)
#                      Predict: 0.0
#                    Else (feature 1 > 1.0)
#                     Predict: 1.0
#                 Else (feature 4 > 3.0)
#                  If (feature 9 <= 5.0)
#                   If (feature 0 <= 2.0)
#                    If (feature 2 <= 3.0)
#                     Predict: 1.0
#                    Else (feature 2 > 3.0)
#                     Predict: 0.0
#                   Else (feature 0 > 2.0)
#                    Predict: 1.0
#                  Else (feature 9 > 5.0)
#                   Predict: 0.0
#                Else (feature 3 > 4.0)
#                 If (feature 9 <= 4.0)
#                  If (feature 5 <= 4.0)
#                   If (feature 1 <= 4.0)
#                    Predict: 0.0
#                   Else (feature 1 > 4.0)
#                    If (feature 4 <= 1.0)
#                     Predict: 0.0
#                    Else (feature 4 > 1.0)
#                     Predict: 1.0
#                  Else (feature 5 > 4.0)
#                   Predict: 1.0
#                 Else (feature 9 > 4.0)
#                  If (feature 0 <= 3.0)
#                   Predict: 1.0
#                  Else (feature 0 > 3.0)
#                   Predict: 0.0
#              Else (feature 5 > 5.0)
#               If (feature 0 <= 1.0)
#                If (feature 1 <= 2.0)
#                 Predict: 1.0
#                Else (feature 1 > 2.0)
#                 Predict: 4.0
#               Else (feature 0 > 1.0)
#                If (feature 3 <= 4.0)
#                 If (feature 0 <= 3.0)
#                  Predict: 1.0
#                 Else (feature 0 > 3.0)
#                  If (feature 1 <= 2.0)
#                   Predict: 0.0
#                  Else (feature 1 > 2.0)
#                   If (feature 1 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 1 > 3.0)
#                    Predict: 0.0
#                Else (feature 3 > 4.0)
#                 If (feature 0 <= 3.0)
#                  Predict: 1.0
#                 Else (feature 0 > 3.0)
#                  Predict: 3.0
#           Else (feature 1 > 5.0)
#            If (feature 8 <= 2.0)
#             If (feature 3 <= 4.0)
#              If (feature 4 <= 1.0)
#               If (feature 3 <= 2.0)
#                If (feature 1 <= 6.0)
#                 Predict: 1.0
#                Else (feature 1 > 6.0)
#                 If (feature 5 <= 4.0)
#                  If (feature 2 <= 3.0)
#                   Predict: 0.0
#                  Else (feature 2 > 3.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 0.0
#                   Else (feature 0 > 1.0)
#                    Predict: 1.0
#                 Else (feature 5 > 4.0)
#                  If (feature 7 <= 4.0)
#                   If (feature 7 <= 1.0)
#                    Predict: 1.0
#                   Else (feature 7 > 1.0)
#                    Predict: 0.0
#                  Else (feature 7 > 4.0)
#                   Predict: 1.0
#               Else (feature 3 > 2.0)
#                If (feature 0 <= 1.0)
#                 Predict: 0.0
#                Else (feature 0 > 1.0)
#                 If (feature 0 <= 3.0)
#                  If (feature 9 <= 2.0)
#                   Predict: 1.0
#                  Else (feature 9 > 2.0)
#                   If (feature 1 <= 7.0)
#                    If (feature 6 <= 2.0)
#                     If (feature 7 <= 7.0)
#                      Predict: 2.0
#                     Else (feature 7 > 7.0)
#                      Predict: 1.0
#                    Else (feature 6 > 2.0)
#                     Predict: 1.0
#                   Else (feature 1 > 7.0)
#                    Predict: 2.0
#                 Else (feature 0 > 3.0)
#                  If (feature 1 <= 6.0)
#                   Predict: 0.0
#                  Else (feature 1 > 6.0)
#                   Predict: 1.0
#              Else (feature 4 > 1.0)
#               If (feature 6 <= 1.0)
#                If (feature 5 <= 5.0)
#                 If (feature 7 <= 6.0)
#                  If (feature 9 <= 1.0)
#                   Predict: 0.0
#                  Else (feature 9 > 1.0)
#                   Predict: 1.0
#                 Else (feature 7 > 6.0)
#                  Predict: 0.0
#                Else (feature 5 > 5.0)
#                 Predict: 0.0
#               Else (feature 6 > 1.0)
#                If (feature 3 <= 3.0)
#                 If (feature 5 <= 1.0)
#                  If (feature 3 <= 1.0)
#                   Predict: 3.0
#                  Else (feature 3 > 1.0)
#                   If (feature 2 <= 2.0)
#                    If (feature 4 <= 2.0)
#                     Predict: 1.0
#                    Else (feature 4 > 2.0)
#                     Predict: 0.0
#                   Else (feature 2 > 2.0)
#                    Predict: 1.0
#                 Else (feature 5 > 1.0)
#                  If (feature 3 <= 1.0)
#                   If (feature 0 <= 3.0)
#                    If (feature 7 <= 3.0)
#                     If (feature 1 <= 6.0)
#                      Predict: 0.0
#                     Else (feature 1 > 6.0)
#                      Predict: 1.0
#                    Else (feature 7 > 3.0)
#                     Predict: 1.0
#                   Else (feature 0 > 3.0)
#                    Predict: 2.0
#                  Else (feature 3 > 1.0)
#                   If (feature 7 <= 5.0)
#                    If (feature 0 <= 3.0)
#                     If (feature 8 <= 1.0)
#                      If (feature 7 <= 1.0)
#                       Predict: 1.0
#                      Else (feature 7 > 1.0)
#                       Predict: 3.0
#                     Else (feature 8 > 1.0)
#                      If (feature 5 <= 3.0)
#                       If (feature 1 <= 6.0)
#                        Predict: 3.0
#                       Else (feature 1 > 6.0)
#                        Predict: 2.0
#                      Else (feature 5 > 3.0)
#                       Predict: 1.0
#                    Else (feature 0 > 3.0)
#                     Predict: 4.0
#                   Else (feature 7 > 5.0)
#                    Predict: 1.0
#                Else (feature 3 > 3.0)
#                 If (feature 2 <= 3.0)
#                  If (feature 5 <= 1.0)
#                   Predict: 0.0
#                  Else (feature 5 > 1.0)
#                   If (feature 5 <= 4.0)
#                    If (feature 7 <= 6.0)
#                     Predict: 1.0
#                    Else (feature 7 > 6.0)
#                     Predict: 0.0
#                   Else (feature 5 > 4.0)
#                    If (feature 2 <= 1.0)
#                     Predict: 1.0
#                    Else (feature 2 > 1.0)
#                     Predict: 0.0
#                 Else (feature 2 > 3.0)
#                  Predict: 3.0
#             Else (feature 3 > 4.0)
#              If (feature 7 <= 2.0)
#               If (feature 4 <= 3.0)
#                If (feature 9 <= 3.0)
#                 Predict: 1.0
#                Else (feature 9 > 3.0)
#                 If (feature 0 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 0 > 2.0)
#                  Predict: 0.0
#               Else (feature 4 > 3.0)
#                Predict: 0.0
#              Else (feature 7 > 2.0)
#               If (feature 1 <= 7.0)
#                If (feature 9 <= 2.0)
#                 If (feature 2 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 2 > 1.0)
#                  If (feature 8 <= 1.0)
#                   If (feature 0 <= 2.0)
#                    Predict: 3.0
#                   Else (feature 0 > 2.0)
#                    Predict: 2.0
#                  Else (feature 8 > 1.0)
#                   Predict: 1.0
#                Else (feature 9 > 2.0)
#                 If (feature 5 <= 2.0)
#                  If (feature 6 <= 1.0)
#                   Predict: 2.0
#                  Else (feature 6 > 1.0)
#                   Predict: 1.0
#                 Else (feature 5 > 2.0)
#                  If (feature 7 <= 3.0)
#                   Predict: 6.0
#                  Else (feature 7 > 3.0)
#                   If (feature 1 <= 6.0)
#                    If (feature 0 <= 1.0)
#                     Predict: 1.0
#                    Else (feature 0 > 1.0)
#                     Predict: 2.0
#                   Else (feature 1 > 6.0)
#                    If (feature 0 <= 1.0)
#                     Predict: 3.0
#                    Else (feature 0 > 1.0)
#                     Predict: 4.0
#               Else (feature 1 > 7.0)
#                If (feature 6 <= 1.0)
#                 Predict: 2.0
#                Else (feature 6 > 1.0)
#                 Predict: 1.0
#            Else (feature 8 > 2.0)
#             If (feature 1 <= 6.0)
#              If (feature 3 <= 3.0)
#               If (feature 7 <= 6.0)
#                If (feature 0 <= 3.0)
#                 If (feature 6 <= 1.0)
#                  If (feature 0 <= 1.0)
#                   Predict: 2.0
#                  Else (feature 0 > 1.0)
#                   Predict: 1.0
#                 Else (feature 6 > 1.0)
#                  Predict: 1.0
#                Else (feature 0 > 3.0)
#                 If (feature 2 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 2 > 1.0)
#                  Predict: 0.0
#               Else (feature 7 > 6.0)
#                If (feature 9 <= 4.0)
#                 Predict: 0.0
#                Else (feature 9 > 4.0)
#                 Predict: 1.0
#              Else (feature 3 > 3.0)
#               If (feature 9 <= 2.0)
#                If (feature 4 <= 3.0)
#                 If (feature 3 <= 5.0)
#                  Predict: 1.0
#                 Else (feature 3 > 5.0)
#                  Predict: 2.0
#                Else (feature 4 > 3.0)
#                 If (feature 0 <= 3.0)
#                  Predict: 4.0
#                 Else (feature 0 > 3.0)
#                  Predict: 2.0
#               Else (feature 9 > 2.0)
#                If (feature 8 <= 3.0)
#                 If (feature 2 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 2 > 1.0)
#                  Predict: 2.0
#                Else (feature 8 > 3.0)
#                 Predict: 1.0
#             Else (feature 1 > 6.0)
#              If (feature 7 <= 6.0)
#               If (feature 2 <= 1.0)
#                If (feature 9 <= 1.0)
#                 Predict: 2.0
#                Else (feature 9 > 1.0)
#                 If (feature 3 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 3 > 2.0)
#                  If (feature 4 <= 3.0)
#                   If (feature 7 <= 4.0)
#                    Predict: 0.0
#                   Else (feature 7 > 4.0)
#                    Predict: 1.0
#                  Else (feature 4 > 3.0)
#                   Predict: 1.0
#               Else (feature 2 > 1.0)
#                If (feature 3 <= 1.0)
#                 Predict: 0.0
#                Else (feature 3 > 1.0)
#                 If (feature 4 <= 2.0)
#                  If (feature 5 <= 4.0)
#                   If (feature 3 <= 5.0)
#                    If (feature 2 <= 3.0)
#                     If (feature 6 <= 3.0)
#                      If (feature 2 <= 2.0)
#                       Predict: 1.0
#                      Else (feature 2 > 2.0)
#                       If (feature 9 <= 2.0)
#                        Predict: 2.0
#                       Else (feature 9 > 2.0)
#                        Predict: 1.0
#                     Else (feature 6 > 3.0)
#                      Predict: 2.0
#                    Else (feature 2 > 3.0)
#                     If (feature 0 <= 3.0)
#                      Predict: 0.0
#                     Else (feature 0 > 3.0)
#                      Predict: 1.0
#                   Else (feature 3 > 5.0)
#                    If (feature 0 <= 2.0)
#                     Predict: 0.0
#                    Else (feature 0 > 2.0)
#                     Predict: 1.0
#                  Else (feature 5 > 4.0)
#                   If (feature 2 <= 3.0)
#                    Predict: 0.0
#                   Else (feature 2 > 3.0)
#                    If (feature 0 <= 3.0)
#                     Predict: 1.0
#                    Else (feature 0 > 3.0)
#                     Predict: 0.0
#                 Else (feature 4 > 2.0)
#                  If (feature 9 <= 3.0)
#                   If (feature 3 <= 2.0)
#                    Predict: 1.0
#                   Else (feature 3 > 2.0)
#                    Predict: 0.0
#                  Else (feature 9 > 3.0)
#                   If (feature 6 <= 3.0)
#                    If (feature 1 <= 7.0)
#                     If (feature 3 <= 2.0)
#                      Predict: 0.0
#                     Else (feature 3 > 2.0)
#                      Predict: 1.0
#                    Else (feature 1 > 7.0)
#                     Predict: 1.0
#                   Else (feature 6 > 3.0)
#                    If (feature 0 <= 2.0)
#                     Predict: 0.0
#                    Else (feature 0 > 2.0)
#                     Predict: 1.0
#              Else (feature 7 > 6.0)
#               If (feature 5 <= 1.0)
#                If (feature 7 <= 7.0)
#                 Predict: 1.0
#                Else (feature 7 > 7.0)
#                 Predict: 0.0
#               Else (feature 5 > 1.0)
#                If (feature 9 <= 4.0)
#                 If (feature 9 <= 2.0)
#                  Predict: 2.0
#                 Else (feature 9 > 2.0)
#                  Predict: 1.0
#                Else (feature 9 > 4.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 3.0
#                 Else (feature 0 > 1.0)
#                  Predict: 2.0
#          Else (feature 9 > 6.0)
#           If (feature 8 <= 3.0)
#            If (feature 5 <= 5.0)
#             If (feature 7 <= 6.0)
#              If (feature 9 <= 7.0)
#               If (feature 5 <= 4.0)
#                If (feature 1 <= 7.0)
#                 If (feature 5 <= 2.0)
#                  If (feature 6 <= 3.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 0.0
#                   Else (feature 0 > 1.0)
#                    If (feature 3 <= 2.0)
#                     Predict: 1.0
#                    Else (feature 3 > 2.0)
#                     If (feature 2 <= 2.0)
#                      Predict: 0.0
#                     Else (feature 2 > 2.0)
#                      If (feature 3 <= 3.0)
#                       Predict: 0.0
#                      Else (feature 3 > 3.0)
#                       Predict: 1.0
#                  Else (feature 6 > 3.0)
#                   If (feature 4 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 4 > 3.0)
#                    Predict: 2.0
#                 Else (feature 5 > 2.0)
#                  If (feature 0 <= 3.0)
#                   If (feature 1 <= 1.0)
#                    If (feature 0 <= 1.0)
#                     Predict: 1.0
#                    Else (feature 0 > 1.0)
#                     Predict: 0.0
#                   Else (feature 1 > 1.0)
#                    If (feature 7 <= 3.0)
#                     Predict: 1.0
#                    Else (feature 7 > 3.0)
#                     If (feature 0 <= 1.0)
#                      Predict: 1.0
#                     Else (feature 0 > 1.0)
#                      Predict: 2.0
#                  Else (feature 0 > 3.0)
#                   If (feature 1 <= 5.0)
#                    Predict: 0.0
#                   Else (feature 1 > 5.0)
#                    Predict: 1.0
#                Else (feature 1 > 7.0)
#                 If (feature 7 <= 4.0)
#                  If (feature 2 <= 2.0)
#                   If (feature 4 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 4 > 3.0)
#                    Predict: 0.0
#                  Else (feature 2 > 2.0)
#                   Predict: 0.0
#                 Else (feature 7 > 4.0)
#                  Predict: 0.0
#               Else (feature 5 > 4.0)
#                Predict: 0.0
#              Else (feature 9 > 7.0)
#               If (feature 2 <= 3.0)
#                If (feature 4 <= 3.0)
#                 If (feature 1 <= 7.0)
#                  If (feature 4 <= 1.0)
#                   If (feature 2 <= 2.0)
#                    If (feature 6 <= 3.0)
#                     Predict: 1.0
#                    Else (feature 6 > 3.0)
#                     Predict: 0.0
#                   Else (feature 2 > 2.0)
#                    Predict: 0.0
#                  Else (feature 4 > 1.0)
#                   If (feature 8 <= 1.0)
#                    If (feature 7 <= 3.0)
#                     Predict: 1.0
#                    Else (feature 7 > 3.0)
#                     If (feature 0 <= 3.0)
#                      Predict: 0.0
#                     Else (feature 0 > 3.0)
#                      Predict: 1.0
#                   Else (feature 8 > 1.0)
#                    Predict: 1.0
#                 Else (feature 1 > 7.0)
#                  Predict: 2.0
#                Else (feature 4 > 3.0)
#                 If (feature 5 <= 3.0)
#                  If (feature 1 <= 1.0)
#                   Predict: 1.0
#                  Else (feature 1 > 1.0)
#                   Predict: 3.0
#                 Else (feature 5 > 3.0)
#                  Predict: 1.0
#               Else (feature 2 > 3.0)
#                If (feature 5 <= 3.0)
#                 If (feature 1 <= 6.0)
#                  Predict: 0.0
#                 Else (feature 1 > 6.0)
#                  Predict: 1.0
#                Else (feature 5 > 3.0)
#                 If (feature 0 <= 3.0)
#                  If (feature 3 <= 4.0)
#                   If (feature 0 <= 2.0)
#                    Predict: 2.0
#                   Else (feature 0 > 2.0)
#                    Predict: 1.0
#                  Else (feature 3 > 4.0)
#                   Predict: 1.0
#                 Else (feature 0 > 3.0)
#                  Predict: 0.0
#             Else (feature 7 > 6.0)
#              If (feature 4 <= 1.0)
#               If (feature 8 <= 1.0)
#                If (feature 0 <= 3.0)
#                 Predict: 4.0
#                Else (feature 0 > 3.0)
#                 Predict: 2.0
#               Else (feature 8 > 1.0)
#                If (feature 1 <= 5.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 0 > 1.0)
#                  If (feature 0 <= 3.0)
#                   Predict: 2.0
#                  Else (feature 0 > 3.0)
#                   Predict: 1.0
#                Else (feature 1 > 5.0)
#                 If (feature 1 <= 6.0)
#                  Predict: 0.0
#                 Else (feature 1 > 6.0)
#                  Predict: 1.0
#              Else (feature 4 > 1.0)
#               If (feature 1 <= 7.0)
#                If (feature 6 <= 2.0)
#                 If (feature 0 <= 1.0)
#                  If (feature 1 <= 1.0)
#                   Predict: 1.0
#                  Else (feature 1 > 1.0)
#                   Predict: 0.0
#                 Else (feature 0 > 1.0)
#                  Predict: 1.0
#                Else (feature 6 > 2.0)
#                 If (feature 1 <= 6.0)
#                  If (feature 3 <= 4.0)
#                   Predict: 0.0
#                  Else (feature 3 > 4.0)
#                   If (feature 0 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 0 > 3.0)
#                    Predict: 0.0
#                 Else (feature 1 > 6.0)
#                  Predict: 1.0
#               Else (feature 1 > 7.0)
#                If (feature 5 <= 1.0)
#                 If (feature 2 <= 1.0)
#                  Predict: 2.0
#                 Else (feature 2 > 1.0)
#                  Predict: 3.0
#                Else (feature 5 > 1.0)
#                 Predict: 1.0
#            Else (feature 5 > 5.0)
#             If (feature 0 <= 2.0)
#              If (feature 1 <= 2.0)
#               If (feature 3 <= 4.0)
#                Predict: 0.0
#               Else (feature 3 > 4.0)
#                Predict: 1.0
#              Else (feature 1 > 2.0)
#               If (feature 3 <= 1.0)
#                If (feature 0 <= 1.0)
#                 Predict: 1.0
#                Else (feature 0 > 1.0)
#                 Predict: 0.0
#               Else (feature 3 > 1.0)
#                Predict: 1.0
#             Else (feature 0 > 2.0)
#              If (feature 6 <= 1.0)
#               If (feature 2 <= 1.0)
#                Predict: 1.0
#               Else (feature 2 > 1.0)
#                If (feature 3 <= 3.0)
#                 Predict: 0.0
#                Else (feature 3 > 3.0)
#                 Predict: 1.0
#              Else (feature 6 > 1.0)
#               If (feature 1 <= 5.0)
#                If (feature 7 <= 4.0)
#                 If (feature 1 <= 2.0)
#                  Predict: 3.0
#                 Else (feature 1 > 2.0)
#                  Predict: 4.0
#                Else (feature 7 > 4.0)
#                 Predict: 2.0
#               Else (feature 1 > 5.0)
#                If (feature 2 <= 3.0)
#                 Predict: 1.0
#                Else (feature 2 > 3.0)
#                 Predict: 2.0
#           Else (feature 8 > 3.0)
#            If (feature 7 <= 7.0)
#             If (feature 0 <= 1.0)
#              If (feature 3 <= 4.0)
#               If (feature 6 <= 2.0)
#                Predict: 1.0
#               Else (feature 6 > 2.0)
#                If (feature 7 <= 6.0)
#                 Predict: 0.0
#                Else (feature 7 > 6.0)
#                 Predict: 1.0
#              Else (feature 3 > 4.0)
#               Predict: 0.0
#             Else (feature 0 > 1.0)
#              If (feature 2 <= 1.0)
#               If (feature 1 <= 2.0)
#                Predict: 0.0
#               Else (feature 1 > 2.0)
#                Predict: 1.0
#              Else (feature 2 > 1.0)
#               If (feature 3 <= 4.0)
#                If (feature 7 <= 4.0)
#                 If (feature 4 <= 3.0)
#                  If (feature 5 <= 3.0)
#                   If (feature 1 <= 5.0)
#                    Predict: 1.0
#                   Else (feature 1 > 5.0)
#                    Predict: 2.0
#                  Else (feature 5 > 3.0)
#                   If (feature 0 <= 2.0)
#                    Predict: 2.0
#                   Else (feature 0 > 2.0)
#                    Predict: 3.0
#                 Else (feature 4 > 3.0)
#                  If (feature 0 <= 3.0)
#                   Predict: 3.0
#                  Else (feature 0 > 3.0)
#                   Predict: 5.0
#                Else (feature 7 > 4.0)
#                 If (feature 1 <= 6.0)
#                  If (feature 4 <= 3.0)
#                   Predict: 1.0
#                  Else (feature 4 > 3.0)
#                   Predict: 0.0
#                 Else (feature 1 > 6.0)
#                  Predict: 2.0
#               Else (feature 3 > 4.0)
#                If (feature 1 <= 7.0)
#                 Predict: 1.0
#                Else (feature 1 > 7.0)
#                 Predict: 0.0
#            Else (feature 7 > 7.0)
#             If (feature 1 <= 7.0)
#              If (feature 0 <= 3.0)
#               Predict: 1.0
#              Else (feature 0 > 3.0)
#               Predict: 2.0
#             Else (feature 1 > 7.0)
#              Predict: 6.0
#         Else (feature 3 > 6.0)
#          If (feature 0 <= 3.0)
#           If (feature 5 <= 2.0)
#            If (feature 1 <= 3.0)
#             If (feature 7 <= 2.0)
#              If (feature 8 <= 1.0)
#               If (feature 0 <= 1.0)
#                If (feature 5 <= 1.0)
#                 Predict: 1.0
#                Else (feature 5 > 1.0)
#                 Predict: 2.0
#               Else (feature 0 > 1.0)
#                Predict: 1.0
#              Else (feature 8 > 1.0)
#               Predict: 2.0
#             Else (feature 7 > 2.0)
#              If (feature 1 <= 1.0)
#               If (feature 6 <= 1.0)
#                Predict: 1.0
#               Else (feature 6 > 1.0)
#                Predict: 0.0
#              Else (feature 1 > 1.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                If (feature 1 <= 2.0)
#                 Predict: 1.0
#                Else (feature 1 > 2.0)
#                 Predict: 0.0
#            Else (feature 1 > 3.0)
#             If (feature 9 <= 7.0)
#              If (feature 9 <= 1.0)
#               If (feature 1 <= 7.0)
#                Predict: 1.0
#               Else (feature 1 > 7.0)
#                Predict: 2.0
#              Else (feature 9 > 1.0)
#               If (feature 2 <= 3.0)
#                If (feature 7 <= 3.0)
#                 If (feature 1 <= 6.0)
#                  Predict: 0.0
#                 Else (feature 1 > 6.0)
#                  If (feature 0 <= 1.0)
#                   Predict: 1.0
#                  Else (feature 0 > 1.0)
#                   If (feature 2 <= 1.0)
#                    Predict: 1.0
#                   Else (feature 2 > 1.0)
#                    Predict: 0.0
#                Else (feature 7 > 3.0)
#                 If (feature 7 <= 7.0)
#                  If (feature 5 <= 1.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 0.0
#                   Else (feature 0 > 1.0)
#                    Predict: 1.0
#                  Else (feature 5 > 1.0)
#                   If (feature 4 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 4 > 3.0)
#                    If (feature 2 <= 1.0)
#                     Predict: 2.0
#                    Else (feature 2 > 1.0)
#                     Predict: 1.0
#                 Else (feature 7 > 7.0)
#                  Predict: 0.0
#               Else (feature 2 > 3.0)
#                If (feature 6 <= 1.0)
#                 Predict: 1.0
#                Else (feature 6 > 1.0)
#                 Predict: 0.0
#             Else (feature 9 > 7.0)
#              If (feature 1 <= 5.0)
#               Predict: 2.0
#              Else (feature 1 > 5.0)
#               Predict: 1.0
#           Else (feature 5 > 2.0)
#            If (feature 9 <= 2.0)
#             If (feature 7 <= 3.0)
#              If (feature 4 <= 3.0)
#               If (feature 8 <= 3.0)
#                If (feature 1 <= 6.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 0.0
#                 Else (feature 0 > 1.0)
#                  Predict: 1.0
#                Else (feature 1 > 6.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 2.0
#                 Else (feature 0 > 1.0)
#                  Predict: 1.0
#               Else (feature 8 > 3.0)
#                If (feature 5 <= 4.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 2.0
#                 Else (feature 0 > 1.0)
#                  Predict: 3.0
#                Else (feature 5 > 4.0)
#                 Predict: 1.0
#              Else (feature 4 > 3.0)
#               If (feature 5 <= 3.0)
#                Predict: 1.0
#               Else (feature 5 > 3.0)
#                Predict: 0.0
#             Else (feature 7 > 3.0)
#              If (feature 7 <= 6.0)
#               If (feature 4 <= 1.0)
#                If (feature 0 <= 1.0)
#                 If (feature 1 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 1 > 1.0)
#                  Predict: 0.0
#                Else (feature 0 > 1.0)
#                 Predict: 1.0
#               Else (feature 4 > 1.0)
#                If (feature 2 <= 3.0)
#                 Predict: 0.0
#                Else (feature 2 > 3.0)
#                 If (feature 3 <= 7.0)
#                  Predict: 1.0
#                 Else (feature 3 > 7.0)
#                  Predict: 0.0
#              Else (feature 7 > 6.0)
#               If (feature 8 <= 3.0)
#                Predict: 1.0
#               Else (feature 8 > 3.0)
#                If (feature 1 <= 5.0)
#                 Predict: 1.0
#                Else (feature 1 > 5.0)
#                 Predict: 0.0
#            Else (feature 9 > 2.0)
#             If (feature 4 <= 3.0)
#              If (feature 1 <= 3.0)
#               If (feature 9 <= 6.0)
#                If (feature 4 <= 1.0)
#                 If (feature 2 <= 2.0)
#                  Predict: 2.0
#                 Else (feature 2 > 2.0)
#                  If (feature 1 <= 2.0)
#                   Predict: 0.0
#                  Else (feature 1 > 2.0)
#                   If (feature 7 <= 2.0)
#                    Predict: 1.0
#                   Else (feature 7 > 2.0)
#                    Predict: 0.0
#                Else (feature 4 > 1.0)
#                 If (feature 5 <= 3.0)
#                  If (feature 3 <= 7.0)
#                   Predict: 1.0
#                  Else (feature 3 > 7.0)
#                   Predict: 0.0
#                 Else (feature 5 > 3.0)
#                  Predict: 1.0
#               Else (feature 9 > 6.0)
#                If (feature 6 <= 3.0)
#                 If (feature 0 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 0 > 2.0)
#                  Predict: 0.0
#                Else (feature 6 > 3.0)
#                 Predict: 2.0
#              Else (feature 1 > 3.0)
#               If (feature 7 <= 6.0)
#                If (feature 5 <= 4.0)
#                 If (feature 7 <= 1.0)
#                  Predict: 0.0
#                 Else (feature 7 > 1.0)
#                  If (feature 9 <= 5.0)
#                   If (feature 7 <= 4.0)
#                    If (feature 5 <= 3.0)
#                     Predict: 2.0
#                    Else (feature 5 > 3.0)
#                     Predict: 1.0
#                   Else (feature 7 > 4.0)
#                    Predict: 1.0
#                  Else (feature 9 > 5.0)
#                   If (feature 1 <= 5.0)
#                    If (feature 9 <= 6.0)
#                     Predict: 1.0
#                    Else (feature 9 > 6.0)
#                     Predict: 0.0
#                   Else (feature 1 > 5.0)
#                    Predict: 1.0
#                Else (feature 5 > 4.0)
#                 If (feature 2 <= 3.0)
#                  If (feature 9 <= 7.0)
#                   If (feature 2 <= 1.0)
#                    If (feature 7 <= 4.0)
#                     Predict: 1.0
#                    Else (feature 7 > 4.0)
#                     If (feature 0 <= 1.0)
#                      Predict: 2.0
#                     Else (feature 0 > 1.0)
#                      Predict: 1.0
#                   Else (feature 2 > 1.0)
#                    Predict: 1.0
#                  Else (feature 9 > 7.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 1.0
#                   Else (feature 0 > 1.0)
#                    Predict: 4.0
#                 Else (feature 2 > 3.0)
#                  If (feature 3 <= 7.0)
#                   If (feature 0 <= 1.0)
#                    Predict: 4.0
#                   Else (feature 0 > 1.0)
#                    Predict: 3.0
#                  Else (feature 3 > 7.0)
#                   Predict: 1.0
#               Else (feature 7 > 6.0)
#                If (feature 0 <= 1.0)
#                 Predict: 4.0
#                Else (feature 0 > 1.0)
#                 If (feature 5 <= 3.0)
#                  If (feature 1 <= 6.0)
#                   Predict: 2.0
#                  Else (feature 1 > 6.0)
#                   Predict: 3.0
#                 Else (feature 5 > 3.0)
#                  Predict: 1.0
#             Else (feature 4 > 3.0)
#              If (feature 0 <= 2.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.0
#               Else (feature 7 > 2.0)
#                If (feature 5 <= 5.0)
#                 If (feature 1 <= 3.0)
#                  Predict: 3.0
#                 Else (feature 1 > 3.0)
#                  If (feature 9 <= 3.0)
#                   Predict: 0.0
#                  Else (feature 9 > 3.0)
#                   If (feature 5 <= 4.0)
#                    If (feature 9 <= 4.0)
#                     If (feature 0 <= 1.0)
#                      Predict: 3.0
#                     Else (feature 0 > 1.0)
#                      Predict: 2.0
#                    Else (feature 9 > 4.0)
#                     Predict: 1.0
#                   Else (feature 5 > 4.0)
#                    Predict: 3.0
#                Else (feature 5 > 5.0)
#                 Predict: 1.0
#              Else (feature 0 > 2.0)
#               If (feature 8 <= 2.0)
#                If (feature 9 <= 5.0)
#                 If (feature 1 <= 4.0)
#                  Predict: 3.0
#                 Else (feature 1 > 4.0)
#                  Predict: 4.0
#                Else (feature 9 > 5.0)
#                 Predict: 1.0
#               Else (feature 8 > 2.0)
#                If (feature 1 <= 1.0)
#                 Predict: 3.0
#                Else (feature 1 > 1.0)
#                 Predict: 1.0
#          Else (feature 0 > 3.0)
#           If (feature 5 <= 4.0)
#            If (feature 4 <= 1.0)
#             If (feature 5 <= 1.0)
#              If (feature 2 <= 2.0)
#               Predict: 1.0
#              Else (feature 2 > 2.0)
#               Predict: 3.0
#             Else (feature 5 > 1.0)
#              If (feature 5 <= 2.0)
#               If (feature 1 <= 3.0)
#                Predict: 0.0
#               Else (feature 1 > 3.0)
#                Predict: 1.0
#              Else (feature 5 > 2.0)
#               If (feature 6 <= 3.0)
#                If (feature 7 <= 4.0)
#                 Predict: 2.0
# ...
#               Else (feature 8 > 3.0)
#                Predict: 0.0
#              Else (feature 5 > 2.0)
#               Predict: 0.0
#             Else (feature 5 > 4.0)
#              If (feature 8 <= 1.0)
#               Predict: 1.0
#              Else (feature 8 > 1.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.0
#               Else (feature 1 > 9.0)
#                If (feature 4 <= 2.0)
#                 Predict: 1.0
#                Else (feature 4 > 2.0)
#                 If (feature 3 <= 11.0)
#                  Predict: 1.0
#                 Else (feature 3 > 11.0)
#                  Predict: 0.0
#          Else (feature 1 > 10.0)
#           If (feature 5 <= 1.0)
#            If (feature 4 <= 1.0)
#             Predict: 4.0
#            Else (feature 4 > 1.0)
#             If (feature 0 <= 1.0)
#              Predict: 1.0
#             Else (feature 0 > 1.0)
#              Predict: 0.0
#           Else (feature 5 > 1.0)
#            If (feature 3 <= 11.0)
#             If (feature 1 <= 11.0)
#              If (feature 3 <= 9.0)
#               Predict: 1.0
#              Else (feature 3 > 9.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.0
#               Else (feature 0 > 1.0)
#                Predict: 3.0
#             Else (feature 1 > 11.0)
#              Predict: 1.0
#            Else (feature 3 > 11.0)
#             If (feature 1 <= 11.0)
#              Predict: 1.0
#             Else (feature 1 > 11.0)
#              If (feature 0 <= 1.0)
#               If (feature 7 <= 12.0)
#                Predict: 3.0
#               Else (feature 7 > 12.0)
#                If (feature 2 <= 2.0)
#                 Predict: 2.0
#                Else (feature 2 > 2.0)
#                 Predict: 1.0
#              Else (feature 0 > 1.0)
#               If (feature 1 <= 12.0)
#                If (feature 2 <= 3.0)
#                 Predict: 2.0
#                Else (feature 2 > 3.0)
#                 If (feature 4 <= 2.0)
#                  Predict: 2.0
#                 Else (feature 4 > 2.0)
#                  Predict: 1.0
#               Else (feature 1 > 12.0)
#                Predict: 1.0
#      Else (feature 5 > 8.0)
#       If (feature 9 <= 8.0)
#        If (feature 9 <= 1.0)
#         If (feature 5 <= 12.0)
#          If (feature 3 <= 12.0)
#           If (feature 2 <= 3.0)
#            If (feature 1 <= 10.0)
#             If (feature 0 <= 3.0)
#              Predict: 0.0
#             Else (feature 0 > 3.0)
#              Predict: 1.0
#            Else (feature 1 > 10.0)
#             Predict: 1.0
#           Else (feature 2 > 3.0)
#            If (feature 1 <= 10.0)
#             Predict: 1.0
#            Else (feature 1 > 10.0)
#             Predict: 0.0
#          Else (feature 3 > 12.0)
#           If (feature 0 <= 2.0)
#            Predict: 9.0
#           Else (feature 0 > 2.0)
#            If (feature 4 <= 3.0)
#             Predict: 1.0
#            Else (feature 4 > 3.0)
#             Predict: 2.0
#         Else (feature 5 > 12.0)
#          If (feature 3 <= 11.0)
#           If (feature 8 <= 3.0)
#            If (feature 1 <= 9.0)
#             Predict: 2.0
#            Else (feature 1 > 9.0)
#             If (feature 0 <= 3.0)
#              Predict: 9.0
#             Else (feature 0 > 3.0)
#              Predict: 4.0
#           Else (feature 8 > 3.0)
#            Predict: 1.0
#          Else (feature 3 > 11.0)
#           If (feature 1 <= 11.0)
#            Predict: 0.0
#           Else (feature 1 > 11.0)
#            Predict: 1.0
#        Else (feature 9 > 1.0)
#         If (feature 7 <= 10.0)
#          If (feature 3 <= 10.0)
#           If (feature 2 <= 2.0)
#            If (feature 5 <= 11.0)
#             If (feature 0 <= 2.0)
#              Predict: 2.0
#             Else (feature 0 > 2.0)
#              Predict: 1.0
#            Else (feature 5 > 11.0)
#             If (feature 6 <= 1.0)
#              If (feature 1 <= 10.0)
#               Predict: 1.0
#              Else (feature 1 > 10.0)
#               Predict: 0.0
#             Else (feature 6 > 1.0)
#              Predict: 1.0
#           Else (feature 2 > 2.0)
#            If (feature 0 <= 3.0)
#             If (feature 1 <= 11.0)
#              Predict: 1.0
#             Else (feature 1 > 11.0)
#              If (feature 0 <= 2.0)
#               If (feature 2 <= 3.0)
#                Predict: 3.0
#               Else (feature 2 > 3.0)
#                If (feature 0 <= 1.0)
#                 Predict: 1.0
#                Else (feature 0 > 1.0)
#                 Predict: 2.0
#              Else (feature 0 > 2.0)
#               Predict: 1.0
#            Else (feature 0 > 3.0)
#             Predict: 3.0
#          Else (feature 3 > 10.0)
#           If (feature 5 <= 9.0)
#            If (feature 4 <= 2.0)
#             If (feature 1 <= 9.0)
#              Predict: 3.0
#             Else (feature 1 > 9.0)
#              If (feature 1 <= 10.0)
#               Predict: 1.0
#              Else (feature 1 > 10.0)
#               Predict: 2.0
#            Else (feature 4 > 2.0)
#             If (feature 0 <= 1.0)
#              Predict: 1.0
#             Else (feature 0 > 1.0)
#              If (feature 1 <= 10.0)
#               Predict: 1.0
#              Else (feature 1 > 10.0)
#               Predict: 0.0
#           Else (feature 5 > 9.0)
#            If (feature 5 <= 12.0)
#             If (feature 4 <= 1.0)
#              If (feature 0 <= 3.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                Predict: 0.0
#              Else (feature 0 > 3.0)
#               Predict: 3.0
#             Else (feature 4 > 1.0)
#              If (feature 2 <= 3.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.0
#               Else (feature 0 > 1.0)
#                If (feature 1 <= 9.0)
#                 If (feature 3 <= 12.0)
#                  Predict: 1.0
#                 Else (feature 3 > 12.0)
#                  Predict: 0.0
#                Else (feature 1 > 9.0)
#                 If (feature 7 <= 9.0)
#                  If (feature 0 <= 3.0)
#                   If (feature 3 <= 11.0)
#                    Predict: 1.0
#                   Else (feature 3 > 11.0)
#                    If (feature 4 <= 3.0)
#                     Predict: 0.0
#                    Else (feature 4 > 3.0)
#                     Predict: 1.0
#                  Else (feature 0 > 3.0)
#                   Predict: 0.0
#                 Else (feature 7 > 9.0)
#                  If (feature 0 <= 3.0)
#                   Predict: 0.0
#                  Else (feature 0 > 3.0)
#                   Predict: 1.0
#              Else (feature 2 > 3.0)
#               Predict: 1.0
#            Else (feature 5 > 12.0)
#             If (feature 4 <= 1.0)
#              Predict: 0.0
#             Else (feature 4 > 1.0)
#              If (feature 3 <= 12.0)
#               Predict: 1.0
#              Else (feature 3 > 12.0)
#               If (feature 2 <= 2.0)
#                Predict: 2.0
#               Else (feature 2 > 2.0)
#                Predict: 1.0
#         Else (feature 7 > 10.0)
#          If (feature 9 <= 7.0)
#           If (feature 5 <= 10.0)
#            If (feature 9 <= 6.0)
#             If (feature 4 <= 1.0)
#              If (feature 3 <= 12.0)
#               If (feature 7 <= 11.0)
#                If (feature 1 <= 10.0)
#                 Predict: 1.0
#                Else (feature 1 > 10.0)
#                 Predict: 0.0
#               Else (feature 7 > 11.0)
#                If (feature 6 <= 3.0)
#                 Predict: 1.0
#                Else (feature 6 > 3.0)
#                 If (feature 0 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 0 > 2.0)
#                  Predict: 2.0
#              Else (feature 3 > 12.0)
#               If (feature 0 <= 2.0)
#                Predict: 3.0
#               Else (feature 0 > 2.0)
#                Predict: 1.0
#             Else (feature 4 > 1.0)
#              If (feature 3 <= 12.0)
#               If (feature 9 <= 3.0)
#                If (feature 0 <= 1.0)
#                 Predict: 1.0
#                Else (feature 0 > 1.0)
#                 Predict: 2.0
#               Else (feature 9 > 3.0)
#                If (feature 0 <= 3.0)
#                 Predict: 1.0
#                Else (feature 0 > 3.0)
#                 If (feature 4 <= 2.0)
#                  Predict: 0.0
#                 Else (feature 4 > 2.0)
#                  Predict: 1.0
#              Else (feature 3 > 12.0)
#               If (feature 1 <= 9.0)
#                Predict: 1.0
#               Else (feature 1 > 9.0)
#                Predict: 0.0
#            Else (feature 9 > 6.0)
#             If (feature 1 <= 10.0)
#              If (feature 0 <= 3.0)
#               Predict: 1.0
#              Else (feature 0 > 3.0)
#               Predict: 0.0
#             Else (feature 1 > 10.0)
#              Predict: 0.0
#           Else (feature 5 > 10.0)
#            If (feature 3 <= 10.0)
#             If (feature 8 <= 2.0)
#              If (feature 8 <= 1.0)
#               Predict: 1.0
#              Else (feature 8 > 1.0)
#               If (feature 1 <= 9.0)
#                Predict: 1.0
#               Else (feature 1 > 9.0)
#                Predict: 0.0
#             Else (feature 8 > 2.0)
#              Predict: 1.0
#            Else (feature 3 > 10.0)
#             If (feature 0 <= 3.0)
#              If (feature 6 <= 3.0)
#               If (feature 1 <= 10.0)
#                If (feature 8 <= 2.0)
#                 Predict: 1.0
#                Else (feature 8 > 2.0)
#                 If (feature 3 <= 11.0)
#                  Predict: 1.0
#                 Else (feature 3 > 11.0)
#                  Predict: 0.0
#               Else (feature 1 > 10.0)
#                If (feature 2 <= 3.0)
#                 If (feature 2 <= 2.0)
#                  If (feature 0 <= 1.0)
#                   If (feature 1 <= 12.0)
#                    Predict: 2.0
#                   Else (feature 1 > 12.0)
#                    Predict: 1.0
#                  Else (feature 0 > 1.0)
#                   Predict: 1.0
#                 Else (feature 2 > 2.0)
#                  Predict: 2.0
#                Else (feature 2 > 3.0)
#                 Predict: 1.0
#              Else (feature 6 > 3.0)
#               If (feature 5 <= 11.0)
#                Predict: 1.0
#               Else (feature 5 > 11.0)
#                If (feature 0 <= 2.0)
#                 Predict: 3.0
#                Else (feature 0 > 2.0)
#                 If (feature 1 <= 9.0)
#                  Predict: 1.0
#                 Else (feature 1 > 9.0)
#                  Predict: 2.0
#             Else (feature 0 > 3.0)
#              If (feature 7 <= 11.0)
#               If (feature 1 <= 11.0)
#                Predict: 7.0
#               Else (feature 1 > 11.0)
#                If (feature 2 <= 1.0)
#                 Predict: 1.0
#                Else (feature 2 > 1.0)
#                 Predict: 3.0
#              Else (feature 7 > 11.0)
#               Predict: 1.0
#          Else (feature 9 > 7.0)
#           If (feature 4 <= 2.0)
#            If (feature 0 <= 2.0)
#             Predict: 0.0
#            Else (feature 0 > 2.0)
#             If (feature 1 <= 9.0)
#              Predict: 2.0
#             Else (feature 1 > 9.0)
#              Predict: 1.0
#           Else (feature 4 > 2.0)
#            If (feature 0 <= 1.0)
#             Predict: 0.0
#            Else (feature 0 > 1.0)
#             If (feature 0 <= 2.0)
#              Predict: 3.0
#             Else (feature 0 > 2.0)
#              Predict: 4.0
#       Else (feature 9 > 8.0)
#        If (feature 1 <= 12.0)
#         If (feature 7 <= 12.0)
#          If (feature 8 <= 3.0)
#           If (feature 2 <= 2.0)
#            If (feature 0 <= 1.0)
#             If (feature 3 <= 10.0)
#              Predict: 1.0
#             Else (feature 3 > 10.0)
#              Predict: 3.0
#            Else (feature 0 > 1.0)
#             If (feature 9 <= 9.0)
#              Predict: 2.0
#             Else (feature 9 > 9.0)
#              If (feature 8 <= 1.0)
#               If (feature 1 <= 9.0)
#                Predict: 2.0
#               Else (feature 1 > 9.0)
#                Predict: 1.0
#              Else (feature 8 > 1.0)
#               If (feature 7 <= 9.0)
#                If (feature 0 <= 3.0)
#                 Predict: 1.0
#                Else (feature 0 > 3.0)
#                 Predict: 2.0
#               Else (feature 7 > 9.0)
#                Predict: 1.0
#           Else (feature 2 > 2.0)
#            If (feature 3 <= 12.0)
#             If (feature 7 <= 9.0)
#              If (feature 0 <= 2.0)
#               If (feature 0 <= 1.0)
#                Predict: 4.0
#               Else (feature 0 > 1.0)
#                Predict: 6.0
#              Else (feature 0 > 2.0)
#               If (feature 1 <= 9.0)
#                Predict: 1.0
#               Else (feature 1 > 9.0)
#                Predict: 3.0
#             Else (feature 7 > 9.0)
#              If (feature 5 <= 10.0)
#               If (feature 2 <= 3.0)
#                Predict: 1.0
#               Else (feature 2 > 3.0)
#                Predict: 2.0
#              Else (feature 5 > 10.0)
#               If (feature 5 <= 11.0)
#                If (feature 1 <= 9.0)
#                 Predict: 4.0
#                Else (feature 1 > 9.0)
#                 Predict: 3.0
#               Else (feature 5 > 11.0)
#                If (feature 1 <= 11.0)
#                 If (feature 9 <= 9.0)
#                  Predict: 1.0
#                 Else (feature 9 > 9.0)
#                  If (feature 4 <= 2.0)
#                   If (feature 5 <= 12.0)
#                    Predict: 2.0
#                   Else (feature 5 > 12.0)
#                    Predict: 1.0
#                  Else (feature 4 > 2.0)
#                   If (feature 6 <= 2.0)
#                    Predict: 3.0
#                   Else (feature 6 > 2.0)
#                    Predict: 2.0
#                Else (feature 1 > 11.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 4.0
#                 Else (feature 0 > 1.0)
#                  If (feature 7 <= 11.0)
#                   Predict: 2.0
#                  Else (feature 7 > 11.0)
#                   Predict: 3.0
#            Else (feature 3 > 12.0)
#             If (feature 1 <= 10.0)
#              If (feature 1 <= 9.0)
#               Predict: 1.0
#              Else (feature 1 > 9.0)
#               Predict: 4.0
#             Else (feature 1 > 10.0)
#              Predict: 1.0
#          Else (feature 8 > 3.0)
#           If (feature 9 <= 11.0)
#            If (feature 1 <= 11.0)
#             If (feature 3 <= 12.0)
#              If (feature 0 <= 1.0)
#               Predict: 2.0
#              Else (feature 0 > 1.0)
#               If (feature 0 <= 3.0)
#                Predict: 3.0
#               Else (feature 0 > 3.0)
#                Predict: 2.0
#             Else (feature 3 > 12.0)
#              Predict: 4.0
#            Else (feature 1 > 11.0)
#             Predict: 4.0
#           Else (feature 9 > 11.0)
#            If (feature 1 <= 9.0)
#             Predict: 1.0
#            Else (feature 1 > 9.0)
#             Predict: 2.0
#         Else (feature 7 > 12.0)
#          If (feature 3 <= 11.0)
#           If (feature 1 <= 10.0)
#            If (feature 2 <= 2.0)
#             If (feature 0 <= 2.0)
#              Predict: 2.0
#             Else (feature 0 > 2.0)
#              Predict: 1.0
#            Else (feature 2 > 2.0)
#             If (feature 0 <= 1.0)
#              Predict: 3.0
#             Else (feature 0 > 1.0)
#              Predict: 2.0
#           Else (feature 1 > 10.0)
#            If (feature 9 <= 12.0)
#             Predict: 1.0
#            Else (feature 9 > 12.0)
#             Predict: 2.0
#          Else (feature 3 > 11.0)
#           If (feature 0 <= 3.0)
#            Predict: 2.0
#           Else (feature 0 > 3.0)
#            Predict: 3.0
#        Else (feature 1 > 12.0)
#         If (feature 2 <= 3.0)
#          If (feature 6 <= 2.0)
#           If (feature 2 <= 2.0)
#            Predict: 4.0
#           Else (feature 2 > 2.0)
#            If (feature 5 <= 11.0)
#             Predict: 2.0
#            Else (feature 5 > 11.0)
#             Predict: 3.0
#          Else (feature 6 > 2.0)
#           If (feature 2 <= 1.0)
#            Predict: 3.0
#           Else (feature 2 > 1.0)
#            If (feature 3 <= 10.0)
#             If (feature 0 <= 1.0)
#              Predict: 1.0
#             Else (feature 0 > 1.0)
#              Predict: 2.0
#            Else (feature 3 > 10.0)
#             Predict: 2.0
#         Else (feature 2 > 3.0)
#          If (feature 0 <= 1.0)
#           Predict: 6.0
#          Else (feature 0 > 1.0)
#           Predict: 4.0

# %% [markdown]
# With a large value for maxDepth, you can see that the run-time increased greatly, along with the size of the tree. The MSE has increased greatly compared to the original, which is due to overfitting of the training data from having a deep tree.

# %% [markdown]
# <a id = "mb"></a>
#
# ### <span style="color:#0b486b">4.2 maxBins Parameter</span>
#
# Now let's tune the <b>maxBins</b> variable. Start by decreasing the value to 2, to see what the lower end of this value does to the tree.

# %%
regDT_tuner(5, 2, 1, 0.0)
# Out:
# 7.329657316207886
# Test Mean Squared Error = 0.5739291605485574
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 63 nodes
#   If (feature 7 <= 6.0)
#    If (feature 5 <= 6.0)
#     If (feature 9 <= 6.0)
#      If (feature 3 <= 6.0)
#       If (feature 1 <= 7.0)
#        Predict: 1.495702005730659
#       Else (feature 1 > 7.0)
#        Predict: 0.7900552486187845
#      Else (feature 3 > 6.0)
#       If (feature 1 <= 7.0)
#        Predict: 0.7826923076923077
#       Else (feature 1 > 7.0)
#        Predict: 0.5386313465783664
#     Else (feature 9 > 6.0)
#      If (feature 1 <= 7.0)
#       If (feature 3 <= 6.0)
#        Predict: 0.7676348547717843
#       Else (feature 3 > 6.0)
#        Predict: 0.5454545454545454
#      Else (feature 1 > 7.0)
#       If (feature 8 <= 2.0)
#        Predict: 0.538135593220339
#       Else (feature 8 > 2.0)
#        Predict: 0.44298245614035087
#    Else (feature 5 > 6.0)
#     If (feature 3 <= 6.0)
#      If (feature 9 <= 6.0)
#       If (feature 1 <= 7.0)
#        Predict: 0.7069672131147541
#       Else (feature 1 > 7.0)
#        Predict: 0.49184149184149184
#      Else (feature 9 > 6.0)
#       If (feature 2 <= 2.0)
#        Predict: 0.553072625698324
#       Else (feature 2 > 2.0)
#        Predict: 0.48028673835125446
#     Else (feature 3 > 6.0)
#      If (feature 9 <= 6.0)
#       If (feature 1 <= 7.0)
#        Predict: 0.5271828665568369
#       Else (feature 1 > 7.0)
#        Predict: 0.4319852941176471
#      Else (feature 9 > 6.0)
#       If (feature 1 <= 7.0)
#        Predict: 0.45973645680819913
#       Else (feature 1 > 7.0)
#        Predict: 0.669051878354204
#   Else (feature 7 > 6.0)
#    If (feature 5 <= 6.0)
#     If (feature 3 <= 6.0)
#      If (feature 9 <= 6.0)
#       If (feature 1 <= 7.0)
#        Predict: 0.7692307692307693
#       Else (feature 1 > 7.0)
#        Predict: 0.5578703703703703
#      Else (feature 9 > 6.0)
#       If (feature 6 <= 2.0)
#        Predict: 0.5958254269449715
#       Else (feature 6 > 2.0)
#        Predict: 0.47330960854092524
#     Else (feature 3 > 6.0)
#      If (feature 1 <= 7.0)
#       If (feature 6 <= 2.0)
#        Predict: 0.4613050075872534
#       Else (feature 6 > 2.0)
#        Predict: 0.5468998410174881
#      Else (feature 1 > 7.0)
#       If (feature 9 <= 6.0)
#        Predict: 0.496
#       Else (feature 9 > 6.0)
#        Predict: 0.6734348561759729
#    Else (feature 5 > 6.0)
#     If (feature 3 <= 6.0)
#      If (feature 1 <= 7.0)
#       If (feature 6 <= 2.0)
#        Predict: 0.5331278890600925
#       Else (feature 6 > 2.0)
#        Predict: 0.5007751937984496
#      Else (feature 1 > 7.0)
#       If (feature 9 <= 6.0)
#        Predict: 0.5078740157480315
#       Else (feature 9 > 6.0)
#        Predict: 0.6751700680272109
#     Else (feature 3 > 6.0)
#      If (feature 1 <= 7.0)
#       If (feature 9 <= 6.0)
#        Predict: 0.5523255813953488
#       Else (feature 9 > 6.0)
#        Predict: 0.7606382978723404
#      Else (feature 1 > 7.0)
#       If (feature 9 <= 6.0)
#        Predict: 0.7738095238095238
#       Else (feature 9 > 6.0)
#        Predict: 1.3064798598949212

# %% [markdown]
# Comparing this to the original tree, we can see a small decrease in the training time, but not much of a difference in regards to MSE or the size of the tree.

# %% [markdown]
# Now let's take a look at the upper end, with a value of 15000

# %%
regDT_tuner(5, 15000, 1, 0.0)
# Out:
# 8.51483941078186
# Test Mean Squared Error = 0.5617129041772837
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 63 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 1.0658082975679541
#       Else (feature 1 > 8.0)
#        Predict: 0.6205493387589013
#      Else (feature 3 > 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 0.6168505516549649
#       Else (feature 1 > 8.0)
#        Predict: 0.47962382445141066
#     Else (feature 9 > 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6046267087276551
#       Else (feature 3 > 8.0)
#        Predict: 0.4741100323624595
#      Else (feature 1 > 8.0)
#       If (feature 7 <= 6.0)
#        Predict: 0.5028248587570622
#       Else (feature 7 > 6.0)
#        Predict: 0.3765182186234818
#    Else (feature 5 > 8.0)
#     If (feature 1 <= 8.0)
#      If (feature 9 <= 1.0)
#       If (feature 1 <= 1.0)
#        Predict: 1.4444444444444444
#       Else (feature 1 > 1.0)
#        Predict: 0.48255813953488375
#      Else (feature 9 > 1.0)
#       If (feature 7 <= 4.0)
#        Predict: 0.47324414715719065
#       Else (feature 7 > 4.0)
#        Predict: 0.5271966527196653
#     Else (feature 1 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.45743329097839897
#       Else (feature 3 > 10.0)
#        Predict: 0.5611814345991561
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6354166666666666
#       Else (feature 3 > 8.0)
#        Predict: 1.0594059405940595
#   Else (feature 7 > 8.0)
#    If (feature 1 <= 8.0)
#     If (feature 5 <= 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.5529640427599611
#       Else (feature 5 > 8.0)
#        Predict: 0.8512396694214877
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 10.0)
#        Predict: 0.4821664464993395
#       Else (feature 9 > 10.0)
#        Predict: 0.611904761904762
#     Else (feature 5 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 6.0)
#        Predict: 0.3316831683168317
#       Else (feature 3 > 6.0)
#        Predict: 0.5648148148148148
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.6627906976744186
#       Else (feature 3 > 10.0)
#        Predict: 1.1858407079646018
#    Else (feature 1 > 8.0)
#     If (feature 3 <= 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.47566718995290425
#       Else (feature 5 > 8.0)
#        Predict: 0.5989010989010989
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.6765432098765433
#       Else (feature 5 > 8.0)
#        Predict: 0.9699570815450643
#     Else (feature 3 > 8.0)
#      If (feature 5 <= 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 0.6307277628032345
#       Else (feature 9 > 8.0)
#        Predict: 1.0486725663716814
#      Else (feature 5 > 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 1.1502347417840375
#       Else (feature 9 > 8.0)
#        Predict: 2.048076923076923

# %% [markdown]
# With a very large maxBin value, we don't see too much of a change in the overall time or in the MSE. The model still has the same depth and nodes, as expected.

# %% [markdown]
# <a id = "mip"></a>
#
# ### <span style="color:#0b486b">4.3 minInstancesPerNode parameter</span>
#
# Next we will look at tuning the <b>minInstancesPerNode</b> parameter. It starts off at the lowest value of 1, but let's see what happens if we keep increasing the value. Starting off with the value <b>100</b>

# %%
regDT_tuner(5, 32, 100, 0.0)
# Out:
# 7.367946147918701
# Test Mean Squared Error = 0.5626862315187708
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 61 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 1.0658082975679541
#       Else (feature 1 > 8.0)
#        Predict: 0.6205493387589013
#      Else (feature 3 > 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 0.6168505516549649
#       Else (feature 1 > 8.0)
#        Predict: 0.47962382445141066
#     Else (feature 9 > 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6046267087276551
#       Else (feature 3 > 8.0)
#        Predict: 0.4741100323624595
#      Else (feature 1 > 8.0)
#       If (feature 7 <= 6.0)
#        Predict: 0.5028248587570622
#       Else (feature 7 > 6.0)
#        Predict: 0.3765182186234818
#    Else (feature 5 > 8.0)
#     If (feature 1 <= 8.0)
#      If (feature 9 <= 1.0)
#       Predict: 0.6130653266331658
#      Else (feature 9 > 1.0)
#       If (feature 7 <= 4.0)
#        Predict: 0.47324414715719065
#       Else (feature 7 > 4.0)
#        Predict: 0.5271966527196653
#     Else (feature 1 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.45743329097839897
#       Else (feature 3 > 10.0)
#        Predict: 0.5611814345991561
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6354166666666666
#       Else (feature 3 > 8.0)
#        Predict: 1.0594059405940595
#   Else (feature 7 > 8.0)
#    If (feature 1 <= 8.0)
#     If (feature 5 <= 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.5529640427599611
#       Else (feature 5 > 8.0)
#        Predict: 0.8512396694214877
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 10.0)
#        Predict: 0.4821664464993395
#       Else (feature 9 > 10.0)
#        Predict: 0.611904761904762
#     Else (feature 5 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 6.0)
#        Predict: 0.3316831683168317
#       Else (feature 3 > 6.0)
#        Predict: 0.5648148148148148
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.6627906976744186
#       Else (feature 3 > 10.0)
#        Predict: 1.1858407079646018
#    Else (feature 1 > 8.0)
#     If (feature 3 <= 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.47566718995290425
#       Else (feature 5 > 8.0)
#        Predict: 0.5989010989010989
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.6765432098765433
#       Else (feature 5 > 8.0)
#        Predict: 0.9699570815450643
#     Else (feature 3 > 8.0)
#      If (feature 5 <= 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 0.6307277628032345
#       Else (feature 9 > 8.0)
#        Predict: 1.0486725663716814
#      Else (feature 5 > 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 1.1502347417840375
#       Else (feature 9 > 8.0)
#        Predict: 2.048076923076923

# %% [markdown]
# With minInstancesPerNode set to 100, we don't see much of a change in time and MSE, but we can see that there are less nodes in the tree. Try now with a value of <b>1000</b>

# %%
regDT_tuner(5, 32, 1000, 0.0)
# Out:
# 7.481520414352417
# Test Mean Squared Error = 0.5864002473699866
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 25 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 7.0)
#        Predict: 1.0695940347970174
#       Else (feature 1 > 7.0)
#        Predict: 0.6890971039182283
#      Else (feature 3 > 8.0)
#       Predict: 0.563302752293578
#     Else (feature 9 > 8.0)
#      If (feature 1 <= 7.0)
#       Predict: 0.5529920692141312
#      Else (feature 1 > 7.0)
#       Predict: 0.4837291116974494
#    Else (feature 5 > 8.0)
#     If (feature 1 <= 8.0)
#      If (feature 9 <= 6.0)
#       Predict: 0.5384615384615384
#      Else (feature 9 > 6.0)
#       Predict: 0.4835007173601148
#     Else (feature 1 > 8.0)
#      Predict: 0.5906832298136646
#   Else (feature 7 > 8.0)
#    If (feature 1 <= 8.0)
#     If (feature 9 <= 9.0)
#      If (feature 7 <= 10.0)
#       Predict: 0.5818337617823479
#      Else (feature 7 > 10.0)
#       Predict: 0.5233160621761658
#     Else (feature 9 > 9.0)
#      Predict: 0.6196513470681458
#    Else (feature 1 > 8.0)
#     If (feature 3 <= 7.0)
#      Predict: 0.6221294363256785
#     Else (feature 3 > 7.0)
#      Predict: 0.946236559139785

# %% [markdown]
# With a value of 1000, we may see more of a decrease in the time, but the MSE has also increased a little bit. As well, the number of nodes in the model has decreased once again. Let's take it one step further and try with a value of <b>8000</b>

# %%
regDT_tuner(5, 32, 8000, 0.0)
# Out:
# 7.452342987060547
# Test Mean Squared Error = 0.6061451829718665
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 1 with 3 nodes
#   If (feature 7 <= 7.0)
#    Predict: 0.6142675429298283
#   Else (feature 7 > 7.0)
#    Predict: 0.6395015576323988

# %% [markdown]
# With a value of 8000, we may see that the run-time to build the model is starting to decrease a lot more, with only a small increase in MSE compared to when the value was set to 1000. The main difference we see is that the tree has become a lot smaller! This is to be expected since we are tuning a stopping parameter, which determines when the model finishes building.

# %% [markdown]
# <a id = "mig"></a>
#
# ### <span style="color:#0b486b">4.4 minInfoGain Parameter</span>
#
#
# For the last parameter, we will look at the minInfoGain parameter, which was initially set to 0.0. This value works well with negative values, and is very sensitive with values greater than 0.0. Try setting the value to a low number, such as -100.0

# %%
regDT_tuner(5, 32, 1, -100.0)
# Out:
# 7.491438150405884
# Test Mean Squared Error = 0.5617129041772837
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 63 nodes
#   If (feature 7 <= 8.0)
#    If (feature 5 <= 8.0)
#     If (feature 9 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 1.0658082975679541
#       Else (feature 1 > 8.0)
#        Predict: 0.6205493387589013
#      Else (feature 3 > 8.0)
#       If (feature 1 <= 8.0)
#        Predict: 0.6168505516549649
#       Else (feature 1 > 8.0)
#        Predict: 0.47962382445141066
#     Else (feature 9 > 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6046267087276551
#       Else (feature 3 > 8.0)
#        Predict: 0.4741100323624595
#      Else (feature 1 > 8.0)
#       If (feature 7 <= 6.0)
#        Predict: 0.5028248587570622
#       Else (feature 7 > 6.0)
#        Predict: 0.3765182186234818
#    Else (feature 5 > 8.0)
#     If (feature 1 <= 8.0)
#      If (feature 9 <= 1.0)
#       If (feature 1 <= 1.0)
#        Predict: 1.4444444444444444
#       Else (feature 1 > 1.0)
#        Predict: 0.48255813953488375
#      Else (feature 9 > 1.0)
#       If (feature 7 <= 4.0)
#        Predict: 0.47324414715719065
#       Else (feature 7 > 4.0)
#        Predict: 0.5271966527196653
#     Else (feature 1 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.45743329097839897
#       Else (feature 3 > 10.0)
#        Predict: 0.5611814345991561
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        Predict: 0.6354166666666666
#       Else (feature 3 > 8.0)
#        Predict: 1.0594059405940595
#   Else (feature 7 > 8.0)
#    If (feature 1 <= 8.0)
#     If (feature 5 <= 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.5529640427599611
#       Else (feature 5 > 8.0)
#        Predict: 0.8512396694214877
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 10.0)
#        Predict: 0.4821664464993395
#       Else (feature 9 > 10.0)
#        Predict: 0.611904761904762
#     Else (feature 5 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 6.0)
#        Predict: 0.3316831683168317
#       Else (feature 3 > 6.0)
#        Predict: 0.5648148148148148
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 10.0)
#        Predict: 0.6627906976744186
#       Else (feature 3 > 10.0)
#        Predict: 1.1858407079646018
#    Else (feature 1 > 8.0)
#     If (feature 3 <= 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.47566718995290425
#       Else (feature 5 > 8.0)
#        Predict: 0.5989010989010989
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 8.0)
#        Predict: 0.6765432098765433
#       Else (feature 5 > 8.0)
#        Predict: 0.9699570815450643
#     Else (feature 3 > 8.0)
#      If (feature 5 <= 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 0.6307277628032345
#       Else (feature 9 > 8.0)
#        Predict: 1.0486725663716814
#      Else (feature 5 > 8.0)
#       If (feature 9 <= 8.0)
#        Predict: 1.1502347417840375
#       Else (feature 9 > 8.0)
#        Predict: 2.048076923076923

# %% [markdown]
# Overall, we don't see much of a change at all to anything. Now try changing the value to 0.0003

# %%
regDT_tuner(5, 32, 1, 0.0003)
# Out:
# 7.650168418884277
# Test Mean Squared Error = 0.6059870234129415
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 0 with 1 nodes
#   Predict: 0.6258663153674323

# %% [markdown]
# We can see that small values greater than zero can cause drastic changes in how the model looks. Here, we see a small decrease in the training time, and small increase in the MSE value. But now the tree only contains one node in it. The affect of this parameter on the tree is similar to minInstancesPerNode, since they are both stopping parameters.

# %% [markdown]
# ---
# <a id = "dtc"></a>
# ## <span style="color:#0b486b">5. Decision Tree (Classification)</span>
#
# Now it's time for you to try it out for yourself! Build a Classification DecisionTree in a similar way that the Regression DecisionTree was built. Please note that you will be using the same dataset in this section (regDT_train, regDT_test), therefore you do not need to re-initialize that section.<br> <br>
#
# Try to only reference the above section when you are experiencing a lot of difficulty. This section is mainly for you to apply your learning.
#
# For some help with the variables:
# <ul>
#     <li><b>numClasses</b>: The number of classes for this dataset is <b>10</b> (parameter doesn't require tuning)</li>
#     <li><b>categoricalFeaturesInfo</b>: Has a value of <b>{}</b> (parameter doesn't require tuning)</li>
#     <li><b>impurity</b>: There are two types of impurites you can use -- <b>'gini'</b> or <b>'entropy'</b> <i>(Default: 'gini')</i></li>
#     <li><b>maxDepth</b>: Values range between <b>0 and 30</b> <i>(Default: 5)</i></li>
#     <li><b>maxBins</b>: Value ranges between <b>2 and 2147483647</b> (largest value for 32-bits) <i>(Default: 32)</i></li>
#     <li><b>minInstancesPerNode</b> ranges between <b>1 and 2147483647</b> <i>(Default: 1)</i></li>
#     <li><b>minInfoGain</b>: Ensure it is a float (has a decimal in the value) <i>(Default: 0.0)</i></li>
# </ul>
#
# When displaying the <b>Training Error</b>, use the following formula and print statement instead of MSE: <br>
# <b>classDT_error = classDT_label_pred.filter(lambda (v, p): v != p).count() / float(regDT_test.count())</b> <br>
# <b>print('Test Error = ' + str(classDT_error))</b>
#
#
# #### The Goal
# Try to create a model that is better than the model with default values. Challenge yourself by trying to create the best model you can!
#
#
# #### Note
# We want a model that doesn't take too long to train and will cause overfitting. Remember that a very large model with high accuracy but long run time may not be good because the model may have overfit the data.

# %%
start = time.time()
classDT_model = DecisionTree.trainClassifier(regDT_train, numClasses = 10, 
                                     categoricalFeaturesInfo = {},
                                     impurity = 'gini', maxDepth = 9,
                                     maxBins = 25, minInstancesPerNode = 4,
                                     minInfoGain = -3.0)
print(time.time() - start)
# Evaluate model on test instances and compute test error
classDT_pred = classDT_model.predict(regDT_test.map(lambda x: x.features))
classDT_label_pred = regDT_test.map(lambda lp: lp.label).zip(classDT_pred)
classDT_error = classDT_label_pred.filter(lambda value: value[0] != value[1]).count() / float(regDT_test.count())
print('Test Error = ' + str(classDT_error))
print('Learned classification tree model:' + classDT_model.toDebugString())

# 1.16329193115
# Test Error = 0.495765559887
# Learned classification tree model:DecisionTreeModel classifier of depth 5 with 63 nodes
# Impurity: entropy
# maxDepth: 5
# maxBins: 32
# minInstancesPerNode: 1
# minInfoGain: 0.0

# 1.16743922234
# Test Error = 0.453958865439
# Learned classification tree model:DecisionTreeModel classifier of depth 9 with 577 nodes
# Impurity: gini
# maxDepth: 9
# maxBins: 25
# minInstancesPerNode: 4
# minInfoGain: -3.0
# Out:
# 8.57907485961914
# Test Error = 0.44590120513839226
# Learned classification tree model:DecisionTreeModel classifier of depth 9 with 419 nodes
#   If (feature 5 <= 12.0)
#    If (feature 3 <= 11.0)
#     If (feature 9 <= 12.0)
#      If (feature 1 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 5 <= 11.0)
#         If (feature 7 <= 11.0)
#          If (feature 9 <= 11.0)
#           If (feature 1 <= 11.0)
#            Predict: 1.0
#           Else (feature 1 > 11.0)
#            Predict: 0.0
#          Else (feature 9 > 11.0)
#           If (feature 1 <= 11.0)
#            Predict: 0.0
#           Else (feature 1 > 11.0)
#            Predict: 1.0
#         Else (feature 7 > 11.0)
#          If (feature 1 <= 11.0)
#           If (feature 9 <= 11.0)
#            Predict: 0.0
#           Else (feature 9 > 11.0)
#            Predict: 1.0
#          Else (feature 1 > 11.0)
#           If (feature 9 <= 10.0)
#            Predict: 1.0
#           Else (feature 9 > 10.0)
#            Predict: 1.0
#        Else (feature 5 > 11.0)
#         If (feature 9 <= 11.0)
#          If (feature 7 <= 11.0)
#           If (feature 1 <= 11.0)
#            Predict: 0.0
#           Else (feature 1 > 11.0)
#            Predict: 1.0
#          Else (feature 7 > 11.0)
#           If (feature 9 <= 10.0)
#            Predict: 1.0
#           Else (feature 9 > 10.0)
#            Predict: 1.0
#         Else (feature 9 > 11.0)
#          If (feature 3 <= 6.0)
#           If (feature 1 <= 8.0)
#            Predict: 1.0
#           Else (feature 1 > 8.0)
#            Predict: 1.0
#          Else (feature 3 > 6.0)
#           If (feature 7 <= 8.0)
#            Predict: 1.0
#           Else (feature 7 > 8.0)
#            Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 6 <= 1.0)
#         If (feature 5 <= 1.0)
#          If (feature 3 <= 10.0)
#           If (feature 0 <= 2.0)
#            Predict: 0.0
#           Else (feature 0 > 2.0)
#            Predict: 1.0
#          Else (feature 3 > 10.0)
#           Predict: 0.0
#         Else (feature 5 > 1.0)
#          If (feature 3 <= 8.0)
#           If (feature 3 <= 7.0)
#            Predict: 0.0
#           Else (feature 3 > 7.0)
#            Predict: 0.0
#          Else (feature 3 > 8.0)
#           If (feature 5 <= 2.0)
#            Predict: 0.0
#           Else (feature 5 > 2.0)
#            Predict: 0.0
#        Else (feature 6 > 1.0)
#         If (feature 8 <= 2.0)
#          If (feature 9 <= 11.0)
#           If (feature 1 <= 5.0)
#            Predict: 1.0
#           Else (feature 1 > 5.0)
#            Predict: 0.0
#          Else (feature 9 > 11.0)
#           If (feature 0 <= 2.0)
#            Predict: 0.0
#           Else (feature 0 > 2.0)
#            Predict: 0.0
#         Else (feature 8 > 2.0)
#          If (feature 2 <= 2.0)
#           If (feature 9 <= 3.0)
#            Predict: 0.0
#           Else (feature 9 > 3.0)
#            Predict: 0.0
#          Else (feature 2 > 2.0)
#           If (feature 4 <= 2.0)
#            Predict: 0.0
#           Else (feature 4 > 2.0)
#            Predict: 0.0
#      Else (feature 1 > 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 3 <= 2.0)
#         If (feature 7 <= 6.0)
#          If (feature 9 <= 3.0)
#           If (feature 5 <= 5.0)
#            Predict: 1.0
#           Else (feature 5 > 5.0)
#            Predict: 1.0
#          Else (feature 9 > 3.0)
#           If (feature 5 <= 6.0)
#            Predict: 1.0
#           Else (feature 5 > 6.0)
#            Predict: 0.0
#         Else (feature 7 > 6.0)
#          If (feature 0 <= 2.0)
#           If (feature 5 <= 2.0)
#            Predict: 1.0
#           Else (feature 5 > 2.0)
#            Predict: 0.0
#          Else (feature 0 > 2.0)
#           If (feature 9 <= 2.0)
#            Predict: 1.0
#           Else (feature 9 > 2.0)
#            Predict: 0.0
#        Else (feature 3 > 2.0)
#         If (feature 3 <= 5.0)
#          If (feature 7 <= 4.0)
#           If (feature 5 <= 5.0)
#            Predict: 1.0
#           Else (feature 5 > 5.0)
#            Predict: 0.0
#          Else (feature 7 > 4.0)
#           If (feature 2 <= 3.0)
#            Predict: 0.0
#           Else (feature 2 > 3.0)
#            Predict: 0.0
#         Else (feature 3 > 5.0)
#          If (feature 7 <= 5.0)
#           If (feature 8 <= 3.0)
#            Predict: 0.0
#           Else (feature 8 > 3.0)
#            Predict: 0.0
#          Else (feature 7 > 5.0)
#           If (feature 5 <= 5.0)
#            Predict: 0.0
#           Else (feature 5 > 5.0)
#            Predict: 0.0
#       Else (feature 7 > 12.0)
#        If (feature 2 <= 3.0)
#         If (feature 5 <= 6.0)
#          If (feature 9 <= 6.0)
#           If (feature 0 <= 1.0)
#            Predict: 1.0
#           Else (feature 0 > 1.0)
#            Predict: 2.0
#          Else (feature 9 > 6.0)
#           If (feature 0 <= 2.0)
#            Predict: 1.0
#           Else (feature 0 > 2.0)
#            Predict: 1.0
#         Else (feature 5 > 6.0)
#          If (feature 3 <= 9.0)
#           If (feature 6 <= 2.0)
#            Predict: 1.0
#           Else (feature 6 > 2.0)
#            Predict: 1.0
#          Else (feature 3 > 9.0)
#           Predict: 1.0
#        Else (feature 2 > 3.0)
#         If (feature 4 <= 2.0)
#          Predict: 1.0
#         Else (feature 4 > 2.0)
#          Predict: 1.0
#     Else (feature 9 > 12.0)
#      If (feature 1 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 3 <= 4.0)
#         If (feature 5 <= 4.0)
#          If (feature 7 <= 3.0)
#           If (feature 4 <= 3.0)
#            Predict: 0.0
#           Else (feature 4 > 3.0)
#            Predict: 1.0
#          Else (feature 7 > 3.0)
#           If (feature 3 <= 1.0)
#            Predict: 0.0
#           Else (feature 3 > 1.0)
#            Predict: 0.0
#         Else (feature 5 > 4.0)
#          If (feature 7 <= 1.0)
#           If (feature 3 <= 1.0)
#            Predict: 1.0
#           Else (feature 3 > 1.0)
#            Predict: 0.0
#          Else (feature 7 > 1.0)
#           If (feature 5 <= 6.0)
#            Predict: 0.0
#           Else (feature 5 > 6.0)
#            Predict: 0.0
#        Else (feature 3 > 4.0)
#         If (feature 1 <= 4.0)
#          If (feature 5 <= 5.0)
#           If (feature 7 <= 6.0)
#            Predict: 1.0
#           Else (feature 7 > 6.0)
#            Predict: 0.0
#          Else (feature 5 > 5.0)
#           If (feature 7 <= 9.0)
#            Predict: 0.0
#           Else (feature 7 > 9.0)
#            Predict: 0.0
#         Else (feature 1 > 4.0)
#          If (feature 7 <= 4.0)
#           If (feature 5 <= 1.0)
#            Predict: 1.0
#           Else (feature 5 > 1.0)
#            Predict: 0.0
#          Else (feature 7 > 4.0)
#           If (feature 5 <= 4.0)
#            Predict: 0.0
#           Else (feature 5 > 4.0)
#            Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 5 <= 6.0)
#         If (feature 3 <= 3.0)
#          If (feature 1 <= 5.0)
#           Predict: 1.0
#          Else (feature 1 > 5.0)
#           Predict: 1.0
#         Else (feature 3 > 3.0)
#          If (feature 3 <= 6.0)
#           Predict: 1.0
#          Else (feature 3 > 6.0)
#           Predict: 1.0
#        Else (feature 5 > 6.0)
#         If (feature 3 <= 6.0)
#          If (feature 6 <= 1.0)
#           Predict: 1.0
#          Else (feature 6 > 1.0)
#           If (feature 0 <= 1.0)
#            Predict: 1.0
#           Else (feature 0 > 1.0)
#            Predict: 1.0
#         Else (feature 3 > 6.0)
#          If (feature 1 <= 6.0)
#           Predict: 1.0
#          Else (feature 1 > 6.0)
#           If (feature 2 <= 2.0)
#            Predict: 2.0
#           Else (feature 2 > 2.0)
#            Predict: 2.0
#      Else (feature 1 > 12.0)
#       If (feature 7 <= 11.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         If (feature 4 <= 2.0)
#          Predict: 1.0
#         Else (feature 4 > 2.0)
#          If (feature 0 <= 3.0)
#           If (feature 4 <= 3.0)
#            Predict: 1.0
#           Else (feature 4 > 3.0)
#            Predict: 1.0
#          Else (feature 0 > 3.0)
#           Predict: 1.0
#       Else (feature 7 > 11.0)
#        If (feature 6 <= 2.0)
#         Predict: 3.0
#        Else (feature 6 > 2.0)
#         Predict: 1.0
#    Else (feature 3 > 11.0)
#     If (feature 5 <= 11.0)
#      If (feature 9 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 7 <= 11.0)
#         If (feature 1 <= 3.0)
#          If (feature 5 <= 3.0)
#           If (feature 7 <= 4.0)
#            Predict: 1.0
#           Else (feature 7 > 4.0)
#            Predict: 0.0
#          Else (feature 5 > 3.0)
#           If (feature 9 <= 3.0)
#            Predict: 0.0
#           Else (feature 9 > 3.0)
#            Predict: 0.0
#         Else (feature 1 > 3.0)
#          If (feature 5 <= 5.0)
#           If (feature 7 <= 6.0)
#            Predict: 0.0
#           Else (feature 7 > 6.0)
#            Predict: 0.0
#          Else (feature 5 > 5.0)
#           If (feature 7 <= 4.0)
#            Predict: 0.0
#           Else (feature 7 > 4.0)
#            Predict: 0.0
#        Else (feature 7 > 11.0)
#         If (feature 6 <= 1.0)
#          If (feature 1 <= 7.0)
#           If (feature 8 <= 3.0)
#            Predict: 0.0
#           Else (feature 8 > 3.0)
#            Predict: 0.0
#          Else (feature 1 > 7.0)
#           If (feature 2 <= 1.0)
#            Predict: 0.0
#           Else (feature 2 > 1.0)
#            Predict: 1.0
#         Else (feature 6 > 1.0)
#          If (feature 8 <= 2.0)
#           If (feature 2 <= 1.0)
#            Predict: 1.0
#           Else (feature 2 > 1.0)
#            Predict: 0.0
#          Else (feature 8 > 2.0)
#           If (feature 1 <= 7.0)
#            Predict: 0.0
#           Else (feature 1 > 7.0)
#            Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         If (feature 7 <= 5.0)
#          If (feature 5 <= 5.0)
#           If (feature 6 <= 3.0)
#            Predict: 0.0
#           Else (feature 6 > 3.0)
#            Predict: 1.0
#          Else (feature 5 > 5.0)
#           If (feature 2 <= 3.0)
#            Predict: 1.0
#           Else (feature 2 > 3.0)
#            Predict: 0.0
#         Else (feature 7 > 5.0)
#          If (feature 7 <= 6.0)
#           If (feature 6 <= 2.0)
#            Predict: 0.0
#           Else (feature 6 > 2.0)
#            Predict: 0.0
#          Else (feature 7 > 6.0)
#           If (feature 7 <= 10.0)
#            Predict: 0.0
#           Else (feature 7 > 10.0)
#            Predict: 1.0
#        Else (feature 7 > 11.0)
#         If (feature 4 <= 1.0)
#          If (feature 6 <= 2.0)
#           If (feature 5 <= 6.0)
#            Predict: 1.0
#           Else (feature 5 > 6.0)
#            Predict: 1.0
#          Else (feature 6 > 2.0)
#           Predict: 1.0
#         Else (feature 4 > 1.0)
#          If (feature 8 <= 3.0)
#           If (feature 2 <= 3.0)
#            Predict: 1.0
#           Else (feature 2 > 3.0)
#            Predict: 1.0
#          Else (feature 8 > 3.0)
#           If (feature 5 <= 8.0)
#            Predict: 1.0
#           Else (feature 5 > 8.0)
#            Predict: 1.0
#      Else (feature 9 > 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 7 <= 11.0)
#         If (feature 0 <= 2.0)
#          If (feature 7 <= 9.0)
#           If (feature 5 <= 1.0)
#            Predict: 0.0
#           Else (feature 5 > 1.0)
#            Predict: 1.0
#          Else (feature 7 > 9.0)
#           If (feature 3 <= 12.0)
#            Predict: 0.0
#           Else (feature 3 > 12.0)
#            Predict: 0.0
#         Else (feature 0 > 2.0)
#          If (feature 9 <= 12.0)
#           If (feature 3 <= 12.0)
#            Predict: 1.0
#           Else (feature 3 > 12.0)
#            Predict: 0.0
#          Else (feature 9 > 12.0)
#           If (feature 3 <= 12.0)
#            Predict: 0.0
#           Else (feature 3 > 12.0)
#            Predict: 1.0
#        Else (feature 7 > 11.0)
#         If (feature 4 <= 2.0)
#          Predict: 1.0
#         Else (feature 4 > 2.0)
#          If (feature 2 <= 2.0)
#           If (feature 3 <= 12.0)
#            Predict: 1.0
#           Else (feature 3 > 12.0)
#            Predict: 1.0
#          Else (feature 2 > 2.0)
#           Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         If (feature 5 <= 7.0)
#          Predict: 1.0
#         Else (feature 5 > 7.0)
#          If (feature 7 <= 7.0)
#           Predict: 1.0
#          Else (feature 7 > 7.0)
#           Predict: 2.0
#        Else (feature 7 > 11.0)
#         Predict: 2.0
#     Else (feature 5 > 11.0)
#      If (feature 3 <= 12.0)
#       If (feature 1 <= 11.0)
#        If (feature 7 <= 11.0)
#         If (feature 6 <= 3.0)
#          If (feature 8 <= 2.0)
#           If (feature 7 <= 9.0)
#            Predict: 1.0
#           Else (feature 7 > 9.0)
#            Predict: 1.0
#          Else (feature 8 > 2.0)
#           Predict: 1.0
#         Else (feature 6 > 3.0)
#          If (feature 9 <= 5.0)
#           If (feature 1 <= 7.0)
#            Predict: 1.0
#           Else (feature 1 > 7.0)
#            Predict: 1.0
#          Else (feature 9 > 5.0)
#           If (feature 8 <= 2.0)
#            Predict: 1.0
#           Else (feature 8 > 2.0)
#            Predict: 2.0
#        Else (feature 7 > 11.0)
#         If (feature 7 <= 12.0)
#          Predict: 3.0
#         Else (feature 7 > 12.0)
#          Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 3.0
#      Else (feature 3 > 12.0)
#       If (feature 1 <= 11.0)
#        If (feature 9 <= 11.0)
#         If (feature 7 <= 11.0)
#          If (feature 1 <= 2.0)
#           If (feature 9 <= 2.0)
#            Predict: 1.0
#           Else (feature 9 > 2.0)
#            Predict: 0.0
#          Else (feature 1 > 2.0)
#           If (feature 7 <= 6.0)
#            Predict: 0.0
#           Else (feature 7 > 6.0)
#            Predict: 0.0
#         Else (feature 7 > 11.0)
#          Predict: 1.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         If (feature 9 <= 10.0)
#          Predict: 1.0
#         Else (feature 9 > 10.0)
#          Predict: 3.0
#        Else (feature 7 > 11.0)
#         Predict: 2.0
#   Else (feature 5 > 12.0)
#    If (feature 9 <= 12.0)
#     If (feature 3 <= 12.0)
#      If (feature 1 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 7 <= 8.0)
#         If (feature 1 <= 11.0)
#          If (feature 3 <= 3.0)
#           If (feature 1 <= 3.0)
#            Predict: 1.0
#           Else (feature 1 > 3.0)
#            Predict: 0.0
#          Else (feature 3 > 3.0)
#           If (feature 7 <= 3.0)
#            Predict: 0.0
#           Else (feature 7 > 3.0)
#            Predict: 0.0
#         Else (feature 1 > 11.0)
#          If (feature 9 <= 11.0)
#           If (feature 3 <= 10.0)
#            Predict: 0.0
#           Else (feature 3 > 10.0)
#            Predict: 0.0
#          Else (feature 9 > 11.0)
#           Predict: 1.0
#        Else (feature 7 > 8.0)
#         If (feature 3 <= 8.0)
#          If (feature 3 <= 1.0)
#           If (feature 4 <= 1.0)
#            Predict: 0.0
#           Else (feature 4 > 1.0)
#            Predict: 0.0
#          Else (feature 3 > 1.0)
#           If (feature 7 <= 9.0)
#            Predict: 0.0
#           Else (feature 7 > 9.0)
#            Predict: 0.0
#         Else (feature 3 > 8.0)
#          If (feature 1 <= 8.0)
#           If (feature 2 <= 3.0)
#            Predict: 0.0
#           Else (feature 2 > 3.0)
#            Predict: 0.0
#          Else (feature 1 > 8.0)
#           If (feature 9 <= 8.0)
#            Predict: 1.0
#           Else (feature 9 > 8.0)
#            Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 8 <= 2.0)
#         If (feature 3 <= 8.0)
#          If (feature 0 <= 2.0)
#           Predict: 1.0
#          Else (feature 0 > 2.0)
#           If (feature 9 <= 9.0)
#            Predict: 2.0
#           Else (feature 9 > 9.0)
#            Predict: 1.0
#         Else (feature 3 > 8.0)
#          If (feature 1 <= 7.0)
#           Predict: 1.0
#          Else (feature 1 > 7.0)
#           Predict: 2.0
#        Else (feature 8 > 2.0)
#         If (feature 3 <= 2.0)
#          Predict: 1.0
#         Else (feature 3 > 2.0)
#          If (feature 9 <= 9.0)
#           Predict: 1.0
#          Else (feature 9 > 9.0)
#           Predict: 1.0
#      Else (feature 1 > 12.0)
#       If (feature 7 <= 11.0)
#        If (feature 3 <= 4.0)
#         If (feature 9 <= 4.0)
#          Predict: 2.0
#         Else (feature 9 > 4.0)
#          If (feature 2 <= 2.0)
#           Predict: 1.0
#          Else (feature 2 > 2.0)
#           Predict: 1.0
#        Else (feature 3 > 4.0)
#         If (feature 7 <= 5.0)
#          Predict: 1.0
#         Else (feature 7 > 5.0)
#          If (feature 9 <= 5.0)
#           If (feature 2 <= 1.0)
#            Predict: 1.0
#           Else (feature 2 > 1.0)
#            Predict: 1.0
#          Else (feature 9 > 5.0)
#           If (feature 2 <= 1.0)
#            Predict: 1.0
#           Else (feature 2 > 1.0)
#            Predict: 2.0
#       Else (feature 7 > 11.0)
#        Predict: 2.0
#     Else (feature 3 > 12.0)
#      If (feature 8 <= 1.0)
#       If (feature 7 <= 6.0)
#        If (feature 1 <= 9.0)
#         Predict: 2.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 7 > 6.0)
#        Predict: 1.0
#      Else (feature 8 > 1.0)
#       If (feature 9 <= 8.0)
#        If (feature 1 <= 3.0)
#         If (feature 4 <= 1.0)
#          Predict: 1.0
#         Else (feature 4 > 1.0)
#          Predict: 1.0
#        Else (feature 1 > 3.0)
#         If (feature 1 <= 11.0)
#          If (feature 9 <= 3.0)
#           If (feature 1 <= 6.0)
#            Predict: 1.0
#           Else (feature 1 > 6.0)
#            Predict: 1.0
#          Else (feature 9 > 3.0)
#           If (feature 9 <= 4.0)
#            Predict: 2.0
#           Else (feature 9 > 4.0)
#            Predict: 1.0
#         Else (feature 1 > 11.0)
#          Predict: 1.0
#       Else (feature 9 > 8.0)
#        If (feature 2 <= 2.0)
#         Predict: 1.0
#        Else (feature 2 > 2.0)
#         Predict: 1.0
#    Else (feature 9 > 12.0)
#     If (feature 3 <= 12.0)
#      If (feature 8 <= 2.0)
#       If (feature 7 <= 11.0)
#        If (feature 0 <= 1.0)
#         If (feature 1 <= 6.0)
#          Predict: 1.0
#         Else (feature 1 > 6.0)
#          Predict: 1.0
#        Else (feature 0 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 11.0)
#        Predict: 1.0
#      Else (feature 8 > 2.0)
#       If (feature 6 <= 1.0)
#        Predict: 2.0
#       Else (feature 6 > 1.0)
#        If (feature 2 <= 1.0)
#         Predict: 1.0
#        Else (feature 2 > 1.0)
#         If (feature 3 <= 4.0)
#          If (feature 1 <= 9.0)
#           Predict: 1.0
#          Else (feature 1 > 9.0)
#           Predict: 1.0
#         Else (feature 3 > 4.0)
#          Predict: 1.0
#     Else (feature 3 > 12.0)
#      Predict: 3.0

# %% [markdown]
# ---
# <a id = "rfc"></a>
# ## <span style="color:#0b486b">6. RandomForest (Classifier)</span>
#
# Now that we've run through the DecisionTree model, let's work with RandomForests now. The process for this will be similar with the DecisionTree section.
#
# Import the following libraries:
# <ul>
#     <li>RandomForest, RandomForestModel from pyspark.mllib.tree</li>
#     <li>MLUtils from pyspark.mllib.util</li>
#     <li>time</li>
# </ul>

# %%
from pyspark.mllib.tree import RandomForest, RandomForestModel
from pyspark.mllib.util import MLUtils
import time

# %% [markdown]
# Next, we will load in the <b>pendigits.txt</b> LibSVM file, which is a dataset based on Pen-Based Recognition of Handwritten Digits. Use <b>MLUtils.loadLibSVMFile</b> and pass in the spark context (<b>sc</b>) and the path to the file <b>'resources/pendigits.txt'</b>. Store this into a variable called <b>classRF_data</b> <br> <br>
#
# Note: You can also try out this section with the poker.txt dataset if you want to compare results from both sections!

# %%
classRF_data = MLUtils.loadLibSVMFile(sc, '22_data/poker.txt')

# %% [markdown]
# Next, we need to split the data into a training dataset (called <b>classRF_train</b>) and testing dataset (called <b>classRF_test</b>). This will be done by running the <b>.randomSplit</b> function on <b>classRF_data</b>. The input into .randomSplit will be <b>[0.7, 0.3]</b>. <br> <br>
#
# This will give us a training dataset containing 70% of the data, and a testing dataset containing 30% of the data.

# %%
(classRF_train, classRF_test) = classRF_data.randomSplit([0.7, 0.3])

# %% [markdown]
# Next, we need to create the Random Forest Classifier called <b>classRF_model</b>. To instantiate the classifier, use <b>RandomForest.trainClassifier</b>. We will pass in the following parameters:
# <ul>
#     <li>1st: The input data. In our case, we will use <b>classRF_train</b></li>
#     <li>2nd: The number of classes. For this dataset, there will be 10 classes, so set <b>numClasses</b> equal to <b>10</b>
#     <li>3rd: The categorical features info. For our dataset, have <b>categoricalFeaturesInfo</b> equal <b>{}</b></li>
#     <li>4th: The number of trees. We will set <b>numTrees = 3</b>
#     <li>5th: The feature Subset Strategy. There are various inputs for this parameter, but for the sake of this section we will set <b>featureSubsetStrategy</b> equal to <b>"auto"</b></li>
#     <li>6th: The type of impurity. Since we're dealing with <b>Classification</b>, we will be have <b>impurity</b> set to <b>'gini'</b></li>
#     <li>7th: The maximum depth of the tree. For now, set <b>maxDepth</b> to <b>5</b>, which is the default value</li>
#     <li>8th: The maximum number of bins. For now, set <b>maxBins</b> to <b>32</b>, which is the default value</li>
#     <li>9th: The seed to generate random data. For now, set <b>seed</b> to <b>None</b></li>
# </ul> <br> <br>
#
# We will also be timing how long it takes to create the model, so run <b>start = time.time()</b> before creating the model and <b>print(time.time()-start)</b> after the model has been created. <br>
# <b>Note</b>: The timings differ on run and by computer, therefore some statements throughout the lab may not directly align with the results you get, which is okay! There are many factors that can affect the time output.

# %%
start = time.time()
classRF_model = RandomForest.trainClassifier(classRF_train, numClasses = 10, categoricalFeaturesInfo={},
                                           featureSubsetStrategy="auto", numTrees=3,
                                           impurity='gini', maxDepth=4, maxBins=32, seed=None)
print (time.time()-start)
# Out:
# 7.399451494216919

# %% [markdown]
# Next, we want to get the models prediction on the test data, which we will call <b>classRF_pred</b>. We will run <b>.predict</b> on classRF_model, passing in the testing data, <b>classRF_test</b> that is mapped using <b>.map</b> which maps the features using a lambda function (<b>lambda x: x.features</b>).

# %%
classRF_pred = classRF_model.predict(classRF_test.map(lambda x: x.features))

# %% [markdown]
# Now create a variable called <b>classRF_label_pred</b> which uses a <b>.map</b> on <b>classRF_test</b>. Pass <b>lambda l: l.label</b> into the mapping function. Outside of the mapping function, add a <b>.zip(classRF_pred)</b>. This will merge the label with the prediction</b>

# %%
classRF_label_pred = classRF_test.map(lambda l: l.label).zip(classRF_pred)

# %% [markdown]
# Now we will calculate the Test Error for this prediction, which we will call <b>classRF_error</b>. This will equate to <b>classRF_label_pred.filter(lambda (v, p): v != p).count() / float(classRF_test.count())</b>, which will count the number of incorrectly predicted values and divide it by the total number of predictions.

# %%
classRF_error = classRF_label_pred.filter(lambda value: value[0] != value[1]).count() / float(classRF_test.count())

# %% [markdown]
# Next, print out the test error value (<b>str(classRF_error)</b>, as well as the learned regression tree model (<b>classRF_model.toDebugString()</b>), so you have an idea of what the ensemble looks like.

# %%
print('Test Error = ' + str(classRF_error))
print('Learned classification tree model:' + classRF_model.toDebugString())
# Out:
# Test Error = 0.5028685790527018
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 4 <= 2.0)
#      If (feature 5 <= 4.0)
#       If (feature 7 <= 3.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 5 <= 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 2 <= 1.0)
#         Predict: 1.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 5 > 2.0)
#       If (feature 0 <= 2.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 0.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#   Tree 1:
#     If (feature 8 <= 2.0)
#      If (feature 7 <= 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 1.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 9.0)
#       If (feature 3 <= 8.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#       Else (feature 3 > 8.0)
#        If (feature 9 <= 9.0)
#         Predict: 1.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 4 <= 2.0)
#       If (feature 3 <= 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 3 > 1.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#      Else (feature 4 > 2.0)
#       If (feature 2 <= 2.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 2 > 2.0)
#        If (feature 3 <= 2.0)
#         Predict: 0.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 2 <= 2.0)
#      If (feature 8 <= 1.0)
#       If (feature 5 <= 3.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 3.0)
#        If (feature 1 <= 1.0)
#         Predict: 0.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#      Else (feature 8 > 1.0)
#       If (feature 3 <= 11.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 0.0
#       Else (feature 3 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#     Else (feature 2 > 2.0)
#      If (feature 9 <= 3.0)
#       If (feature 3 <= 3.0)
#        If (feature 5 <= 6.0)
#         Predict: 1.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#       Else (feature 3 > 3.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#      Else (feature 9 > 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 1 <= 3.0)
#         Predict: 1.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0

# %% [markdown]
# Now that we've created the basic Classification Random Forest, let's start tuning some parameters! This is similar to the previous section, but since most of the tuning parameters have been covered in the Decision Tree section, there will only be two parameter to tune in this section. <br> <br>
#
# Read over the code and understand how to build the Classification Random Forest as a whole. For the inputs, we have:
# <ul>
#     <li>1st: numTreesValue is the value for numTrees (Type: Int, Range: > 0, Default: 3)</li>
#     <li>2nd: featureSubsetStrategyValue is the value for featureSubsetStrategyValue (Default: "auto")</li>
#     <ul>
#         <li>Values include: "auto", "all", "sqrt", "log2", "onethird"</li>
#     </ul>
# </ul>

# %%
def classRF_tuner(numTreesValue, featureSubsetStrategyValue):
    start = time.time()
    classRF_model = RandomForest.trainClassifier(classRF_train, numClasses = 10, categoricalFeaturesInfo={},
                                           featureSubsetStrategy=featureSubsetStrategyValue, numTrees=numTreesValue,
                                           impurity='gini', maxDepth=4, maxBins=32, seed=None)
    print (time.time()-start)

    classRF_pred = classRF_model.predict(classRF_test.map(lambda x: x.features))
    classRF_label_pred = classRF_test.map(lambda l: l.label).zip(classRF_pred)
    classRF_error = classRF_label_pred.filter(lambda value: value[0] != value[1]).count() / float(classRF_test.count())
    
    print('Test Error = ' + str(classRF_error))
    print('Learned classification tree model:' + classRF_model.toDebugString())

# %% [markdown]
# Start off by re-creating the original Random Forest. That requires the input: <b>(3)</b> and <b>"auto"</b> into <b>classRF_tuner</b>

# %%
classRF_tuner(3, "auto")
# Out:
# 7.8247973918914795
# Test Error = 0.476184122748499
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 9 <= 9.0)
#      If (feature 1 <= 11.0)
#       If (feature 5 <= 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#      Else (feature 1 > 11.0)
#       If (feature 5 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#       Else (feature 5 > 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 1.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#     Else (feature 9 > 9.0)
#      If (feature 1 <= 9.0)
#       If (feature 1 <= 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 3.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#      Else (feature 1 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 1.0
#       Else (feature 7 > 9.0)
#        If (feature 3 <= 9.0)
#         Predict: 1.0
#        Else (feature 3 > 9.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 2 <= 2.0)
#      If (feature 6 <= 2.0)
#       If (feature 1 <= 11.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 5 <= 3.0)
#         Predict: 0.0
#        Else (feature 5 > 3.0)
#         Predict: 1.0
#      Else (feature 6 > 2.0)
#       If (feature 3 <= 10.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#       Else (feature 3 > 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#     Else (feature 2 > 2.0)
#      If (feature 0 <= 1.0)
#       If (feature 1 <= 11.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 1.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#      Else (feature 0 > 1.0)
#       If (feature 5 <= 12.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 5 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 1 <= 9.0)
#      If (feature 3 <= 9.0)
#       If (feature 5 <= 7.0)
#        If (feature 9 <= 9.0)
#         Predict: 1.0
#        Else (feature 9 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 7.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#      Else (feature 3 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#     Else (feature 1 > 9.0)
#      If (feature 9 <= 9.0)
#       If (feature 3 <= 7.0)
#        If (feature 9 <= 6.0)
#         Predict: 0.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#      Else (feature 9 > 9.0)
#       If (feature 3 <= 8.0)
#        If (feature 9 <= 10.0)
#         Predict: 1.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 3 > 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 1.0
#        Else (feature 5 > 8.0)
#         Predict: 1.0

# %% [markdown]
# <a id = "nt"></a>
# ### <span style="color:#0b486b">6.1 numTrees Parameter</span>
#
#
# Let's start by tuning the <b>numTrees</b> parameter. Begin by setting it to a lower value, such as <b>1</b>

# %%
classRF_tuner(1, "auto")
# Out:
# 8.302609920501709
# Test Error = 0.49099399599733157
# Learned classification tree model:TreeEnsembleModel classifier with 1 trees
#
#   Tree 0:
#     If (feature 8 <= 3.0)
#      If (feature 7 <= 5.0)
#       If (feature 5 <= 5.0)
#        If (feature 3 <= 5.0)
#         Predict: 1.0
#        Else (feature 3 > 5.0)
#         Predict: 0.0
#       Else (feature 5 > 5.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       If (feature 3 <= 7.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 1.0
#     Else (feature 8 > 3.0)
#      If (feature 2 <= 3.0)
#       If (feature 9 <= 12.0)
#        If (feature 5 <= 1.0)
#         Predict: 0.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#      Else (feature 2 > 3.0)
#       If (feature 5 <= 8.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#       Else (feature 5 > 8.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0

# %% [markdown]
# By setting numTrees to a value of 1, we see a slightly higher test error. Note that with numTrees equal to 1, the classifier acts as a Decision Tree, since there is only one tree in the ensemble.

# %% [markdown]
# Now let's try setting it to a numTrees to a larger value, such as 180.

# %%
classRF_tuner(180, "auto")
# Out:
# 16.193716764450073
# Test Error = 0.49939959973315545
# Learned classification tree model:TreeEnsembleModel classifier with 180 trees
#
#   Tree 0:
#     If (feature 9 <= 9.0)
#      If (feature 3 <= 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 1.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#      Else (feature 3 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#     Else (feature 9 > 9.0)
#      If (feature 4 <= 3.0)
#       If (feature 7 <= 9.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 8 <= 2.0)
#         Predict: 1.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 4 > 3.0)
#       If (feature 7 <= 9.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 1.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 7 <= 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 3 <= 8.0)
#        If (feature 1 <= 8.0)
#         Predict: 1.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#       Else (feature 3 > 8.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 8.0)
#        If (feature 7 <= 1.0)
#         Predict: 0.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 5 > 8.0)
#        If (feature 8 <= 1.0)
#         Predict: 1.0
#        Else (feature 8 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 9 <= 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 1.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#       Else (feature 3 > 8.0)
#        If (feature 1 <= 8.0)
#         Predict: 1.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 7 <= 10.0)
#      If (feature 3 <= 10.0)
#       If (feature 5 <= 11.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#       Else (feature 5 > 11.0)
#        If (feature 3 <= 5.0)
#         Predict: 0.0
#        Else (feature 3 > 5.0)
#         Predict: 0.0
#      Else (feature 3 > 10.0)
#       If (feature 0 <= 3.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#       Else (feature 0 > 3.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#     Else (feature 7 > 10.0)
#      If (feature 1 <= 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 1.0
#      Else (feature 1 > 10.0)
#       If (feature 9 <= 9.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 1.0
#       Else (feature 9 > 9.0)
#        If (feature 3 <= 10.0)
#         Predict: 1.0
#        Else (feature 3 > 10.0)
#         Predict: 1.0
#   Tree 3:
#     If (feature 9 <= 3.0)
#      If (feature 1 <= 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 1.0
#       Else (feature 7 > 3.0)
#        If (feature 5 <= 3.0)
#         Predict: 1.0
#        Else (feature 5 > 3.0)
#         Predict: 0.0
#      Else (feature 1 > 3.0)
#       If (feature 3 <= 3.0)
#        If (feature 5 <= 5.0)
#         Predict: 1.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#     Else (feature 9 > 3.0)
#      If (feature 3 <= 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#      Else (feature 3 > 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 5 <= 3.0)
#         Predict: 0.0
#        Else (feature 5 > 3.0)
#         Predict: 1.0
#   Tree 4:
#     If (feature 0 <= 1.0)
#      If (feature 6 <= 1.0)
#       If (feature 2 <= 1.0)
#        If (feature 4 <= 1.0)
#         Predict: 5.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#       Else (feature 2 > 1.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 6 > 1.0)
#       If (feature 7 <= 11.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#     Else (feature 0 > 1.0)
#      If (feature 3 <= 7.0)
#       If (feature 7 <= 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#      Else (feature 3 > 7.0)
#       If (feature 7 <= 6.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 6.0)
#        If (feature 3 <= 10.0)
#         Predict: 1.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#   Tree 5:
#     If (feature 6 <= 3.0)
#      If (feature 3 <= 10.0)
#       If (feature 1 <= 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#      Else (feature 3 > 10.0)
#       If (feature 9 <= 10.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#     Else (feature 6 > 3.0)
#      If (feature 8 <= 2.0)
#       If (feature 0 <= 3.0)
#        If (feature 9 <= 3.0)
#         Predict: 0.0
#        Else (feature 9 > 3.0)
#         Predict: 1.0
#       Else (feature 0 > 3.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 9 <= 12.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 9 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 2.0
#   Tree 6:
#     If (feature 3 <= 4.0)
#      If (feature 9 <= 4.0)
#       If (feature 8 <= 1.0)
#        If (feature 7 <= 4.0)
#         Predict: 1.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#       Else (feature 8 > 1.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#      Else (feature 9 > 4.0)
#       If (feature 1 <= 5.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 5.0)
#        If (feature 3 <= 1.0)
#         Predict: 0.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#     Else (feature 3 > 4.0)
#      If (feature 5 <= 4.0)
#       If (feature 7 <= 6.0)
#        If (feature 3 <= 7.0)
#         Predict: 1.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#       Else (feature 7 > 6.0)
#        If (feature 9 <= 6.0)
#         Predict: 0.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#      Else (feature 5 > 4.0)
#       If (feature 0 <= 1.0)
#        If (feature 9 <= 4.0)
#         Predict: 0.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 0 > 1.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 1.0
#   Tree 7:
#     If (feature 6 <= 1.0)
#      If (feature 5 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 3.0)
#         Predict: 1.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#       Else (feature 3 > 2.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 2.0)
#       If (feature 8 <= 3.0)
#        If (feature 7 <= 8.0)
#         Predict: 0.0
#        Else (feature 7 > 8.0)
#         Predict: 0.0
#       Else (feature 8 > 3.0)
#        If (feature 1 <= 2.0)
#         Predict: 0.0
#        Else (feature 1 > 2.0)
#         Predict: 1.0
#     Else (feature 6 > 1.0)
#      If (feature 7 <= 4.0)
#       If (feature 9 <= 4.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 3 <= 5.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 5.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 1.0
#   Tree 8:
#     If (feature 8 <= 3.0)
#      If (feature 7 <= 8.0)
#       If (feature 3 <= 9.0)
#        If (feature 1 <= 8.0)
#         Predict: 1.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#       Else (feature 3 > 9.0)
#        If (feature 4 <= 3.0)
#         Predict: 0.0
#        Else (feature 4 > 3.0)
#         Predict: 0.0
#      Else (feature 7 > 8.0)
#       If (feature 9 <= 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#       Else (feature 9 > 8.0)
#        If (feature 2 <= 1.0)
#         Predict: 1.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#     Else (feature 8 > 3.0)
#      If (feature 2 <= 3.0)
#       If (feature 9 <= 9.0)
#        If (feature 3 <= 6.0)
#         Predict: 0.0
#        Else (feature 3 > 6.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 2 > 3.0)
#       If (feature 7 <= 8.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 0.0
#       Else (feature 7 > 8.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#   Tree 9:
#     If (feature 3 <= 3.0)
#      If (feature 5 <= 3.0)
#       If (feature 3 <= 2.0)
#        If (feature 1 <= 3.0)
#         Predict: 1.0
#        Else (feature 1 > 3.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 3.0)
#       If (feature 0 <= 2.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#     Else (feature 3 > 3.0)
#      If (feature 6 <= 1.0)
#       If (feature 4 <= 1.0)
#        If (feature 8 <= 1.0)
#         Predict: 0.0
#        Else (feature 8 > 1.0)
#         Predict: 0.0
#       Else (feature 4 > 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#      Else (feature 6 > 1.0)
#       If (feature 2 <= 3.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 9 <= 3.0)
#         Predict: 0.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#   Tree 10:
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 2.0)
#        If (feature 4 <= 1.0)
#         Predict: 3.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#      Else (feature 9 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 7 <= 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 1.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 9 <= 3.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 3.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#   Tree 11:
#     If (feature 3 <= 7.0)
#      If (feature 7 <= 7.0)
#       If (feature 9 <= 7.0)
#        If (feature 1 <= 7.0)
#         Predict: 1.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#       Else (feature 9 > 7.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#      Else (feature 7 > 7.0)
#       If (feature 5 <= 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#     Else (feature 3 > 7.0)
#      If (feature 9 <= 8.0)
#       If (feature 5 <= 6.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 1.0
#      Else (feature 9 > 8.0)
#       If (feature 7 <= 7.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 1.0
#       Else (feature 7 > 7.0)
#        If (feature 3 <= 10.0)
#         Predict: 1.0
#        Else (feature 3 > 10.0)
#         Predict: 1.0
#   Tree 12:
#     If (feature 4 <= 2.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 10.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 9 <= 3.0)
#         Predict: 0.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 3 <= 9.0)
#         Predict: 1.0
#        Else (feature 3 > 9.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 6 <= 3.0)
#       If (feature 3 <= 12.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 12.0)
#        If (feature 2 <= 1.0)
#         Predict: 1.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#      Else (feature 6 > 3.0)
#       If (feature 5 <= 2.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#   Tree 13:
#     If (feature 8 <= 1.0)
#      If (feature 6 <= 1.0)
#       If (feature 7 <= 1.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 1.0
#       Else (feature 7 > 1.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#      Else (feature 6 > 1.0)
#       If (feature 0 <= 1.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#       Else (feature 0 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#     Else (feature 8 > 1.0)
#      If (feature 1 <= 2.0)
#       If (feature 0 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 9 <= 9.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 7 <= 8.0)
#         Predict: 0.0
#        Else (feature 7 > 8.0)
#         Predict: 1.0
#   Tree 14:
#     If (feature 0 <= 3.0)
#      If (feature 8 <= 2.0)
#       If (feature 7 <= 5.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 5.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 3 <= 6.0)
#        If (feature 5 <= 6.0)
#         Predict: 1.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#       Else (feature 3 > 6.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#     Else (feature 0 > 3.0)
#      If (feature 1 <= 6.0)
#       If (feature 7 <= 1.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 1.0
#       Else (feature 7 > 1.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 6.0)
#       If (feature 6 <= 3.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 1.0
#       Else (feature 6 > 3.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#   Tree 15:
#     If (feature 2 <= 2.0)
#      If (feature 9 <= 7.0)
#       If (feature 1 <= 8.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 8.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 0.0
#      Else (feature 9 > 7.0)
#       If (feature 3 <= 7.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 3 > 7.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 1.0
#     Else (feature 2 > 2.0)
#      If (feature 9 <= 3.0)
#       If (feature 8 <= 3.0)
#        If (feature 5 <= 3.0)
#         Predict: 1.0
#        Else (feature 5 > 3.0)
#         Predict: 0.0
#       Else (feature 8 > 3.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#      Else (feature 9 > 3.0)
#       If (feature 5 <= 2.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#   Tree 16:
#     If (feature 1 <= 4.0)
#      If (feature 7 <= 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 1.0
#       Else (feature 5 > 4.0)
#        If (feature 2 <= 2.0)
#         Predict: 1.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 1.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#     Else (feature 1 > 4.0)
#      If (feature 7 <= 4.0)
#       If (feature 3 <= 3.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 1.0
#       Else (feature 3 > 3.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 9 <= 4.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 1.0
#   Tree 17:
#     If (feature 3 <= 11.0)
#      If (feature 1 <= 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 0.0
#       Else (feature 5 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#      Else (feature 1 > 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 1.0
#        Else (feature 9 > 12.0)
#         Predict: 3.0
#     Else (feature 3 > 11.0)
#      If (feature 9 <= 11.0)
#       If (feature 6 <= 2.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#       Else (feature 6 > 2.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#      Else (feature 9 > 11.0)
#       If (feature 5 <= 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#       Else (feature 5 > 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 3.0
#   Tree 18:
#     If (feature 9 <= 10.0)
#      If (feature 5 <= 11.0)
#       If (feature 3 <= 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 1.0
#        Else (feature 7 > 10.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 5 > 11.0)
#       If (feature 9 <= 8.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#       Else (feature 9 > 8.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 1.0
#     Else (feature 9 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 1 <= 10.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 1.0
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#       Else (feature 3 > 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 1.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#   Tree 19:
#     If (feature 6 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 4 <= 1.0)
#         Predict: 1.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 7 <= 2.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 2.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#     Else (feature 6 > 2.0)
#      If (feature 5 <= 6.0)
#       If (feature 1 <= 8.0)
#        If (feature 7 <= 6.0)
#         Predict: 1.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 1 > 8.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 6.0)
#       If (feature 3 <= 6.0)
#        If (feature 8 <= 1.0)
#         Predict: 0.0
#        Else (feature 8 > 1.0)
#         Predict: 0.0
#       Else (feature 3 > 6.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 1.0
#   Tree 20:
#     If (feature 0 <= 3.0)
#      If (feature 8 <= 2.0)
#       If (feature 4 <= 3.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 1.0
#       Else (feature 4 > 3.0)
#        If (feature 3 <= 6.0)
#         Predict: 0.0
#        Else (feature 3 > 6.0)
#         Predict: 1.0
#      Else (feature 8 > 2.0)
#       If (feature 3 <= 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#     Else (feature 0 > 3.0)
#      If (feature 3 <= 9.0)
#       If (feature 6 <= 3.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 6 > 3.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#      Else (feature 3 > 9.0)
#       If (feature 5 <= 6.0)
#        If (feature 5 <= 2.0)
#         Predict: 0.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 1.0
#   Tree 21:
#     If (feature 3 <= 10.0)
#      If (feature 9 <= 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#      Else (feature 9 > 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 6 <= 1.0)
#         Predict: 1.0
#        Else (feature 6 > 1.0)
#         Predict: 0.0
#     Else (feature 3 > 10.0)
#      If (feature 9 <= 10.0)
#       If (feature 9 <= 5.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#       Else (feature 9 > 5.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#      Else (feature 9 > 10.0)
#       If (feature 0 <= 2.0)
#        If (feature 1 <= 5.0)
#         Predict: 0.0
#        Else (feature 1 > 5.0)
#         Predict: 1.0
#       Else (feature 0 > 2.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 1.0
#   Tree 22:
#     If (feature 9 <= 9.0)
#      If (feature 5 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 1 <= 5.0)
#         Predict: 0.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#      Else (feature 5 > 11.0)
#       If (feature 5 <= 12.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#       Else (feature 5 > 12.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 1.0
#     Else (feature 9 > 9.0)
#      If (feature 1 <= 9.0)
#       If (feature 7 <= 10.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#      Else (feature 1 > 9.0)
#       If (feature 3 <= 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#       Else (feature 3 > 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 1.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#   Tree 23:
#     If (feature 8 <= 3.0)
#      If (feature 3 <= 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 1.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#      Else (feature 3 > 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 5 <= 6.0)
#         Predict: 0.0
#        Else (feature 5 > 6.0)
#         Predict: 1.0
#     Else (feature 8 > 3.0)
#      If (feature 7 <= 1.0)
#       If (feature 1 <= 3.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 0.0
#       Else (feature 1 > 3.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 1.0)
#       If (feature 5 <= 5.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#       Else (feature 5 > 5.0)
#        If (feature 3 <= 1.0)
#         Predict: 0.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#   Tree 24:
#     If (feature 6 <= 1.0)
#      If (feature 1 <= 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#     Else (feature 6 > 1.0)
#      If (feature 8 <= 3.0)
#       If (feature 7 <= 5.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 5.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 1.0
#      Else (feature 8 > 3.0)
#       If (feature 6 <= 2.0)
#        If (feature 5 <= 11.0)
#         Predict: 1.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 6 > 2.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#   Tree 25:
#     If (feature 7 <= 4.0)
#      If (feature 6 <= 3.0)
#       If (feature 1 <= 4.0)
#        If (feature 3 <= 5.0)
#         Predict: 1.0
#        Else (feature 3 > 5.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#      Else (feature 6 > 3.0)
#       If (feature 0 <= 3.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 0 > 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#     Else (feature 7 > 4.0)
#      If (feature 1 <= 4.0)
#       If (feature 3 <= 5.0)
#        If (feature 5 <= 5.0)
#         Predict: 1.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 5.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 0.0
#      Else (feature 1 > 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 1.0
#   Tree 26:
#     If (feature 5 <= 5.0)
#      If (feature 3 <= 5.0)
#       If (feature 4 <= 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 1.0
#       Else (feature 4 > 2.0)
#        If (feature 7 <= 5.0)
#         Predict: 1.0
#        Else (feature 7 > 5.0)
#         Predict: 0.0
#      Else (feature 3 > 5.0)
#       If (feature 6 <= 2.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 6 > 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#     Else (feature 5 > 5.0)
#      If (feature 7 <= 5.0)
#       If (feature 1 <= 4.0)
#        If (feature 3 <= 5.0)
#         Predict: 1.0
#        Else (feature 3 > 5.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       If (feature 1 <= 4.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 1.0
#   Tree 27:
#     If (feature 8 <= 3.0)
#      If (feature 6 <= 1.0)
#       If (feature 2 <= 1.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#       Else (feature 2 > 1.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 6 > 1.0)
#       If (feature 3 <= 3.0)
#        If (feature 1 <= 3.0)
#         Predict: 1.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#       Else (feature 3 > 3.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 0.0
#     Else (feature 8 > 3.0)
#      If (feature 9 <= 11.0)
#       If (feature 5 <= 11.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 11.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#      Else (feature 9 > 11.0)
#       If (feature 7 <= 10.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 1.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#   Tree 28:
#     If (feature 7 <= 5.0)
#      If (feature 3 <= 5.0)
#       If (feature 9 <= 5.0)
#        If (feature 9 <= 3.0)
#         Predict: 1.0
#        Else (feature 9 > 3.0)
#         Predict: 1.0
#       Else (feature 9 > 5.0)
#        If (feature 4 <= 1.0)
#         Predict: 1.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#      Else (feature 3 > 5.0)
#       If (feature 8 <= 1.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#       Else (feature 8 > 1.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#     Else (feature 7 > 5.0)
#      If (feature 1 <= 4.0)
#       If (feature 8 <= 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 8 > 3.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#      Else (feature 1 > 4.0)
#       If (feature 5 <= 5.0)
#        If (feature 7 <= 8.0)
#         Predict: 0.0
#        Else (feature 7 > 8.0)
#         Predict: 0.0
#       Else (feature 5 > 5.0)
#        If (feature 3 <= 5.0)
#         Predict: 0.0
#        Else (feature 3 > 5.0)
#         Predict: 1.0
#   Tree 29:
#     If (feature 5 <= 3.0)
#      If (feature 1 <= 3.0)
#       If (feature 4 <= 1.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#       Else (feature 4 > 1.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 1.0
#      Else (feature 1 > 3.0)
#       If (feature 6 <= 3.0)
#        If (feature 9 <= 4.0)
#         Predict: 0.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 6 > 3.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#     Else (feature 5 > 3.0)
#      If (feature 3 <= 3.0)
#       If (feature 1 <= 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#      Else (feature 3 > 3.0)
#       If (feature 1 <= 4.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 1.0
#   Tree 30:
#     If (feature 4 <= 2.0)
#      If (feature 9 <= 8.0)
#       If (feature 7 <= 9.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 0.0
#      Else (feature 9 > 8.0)
#       If (feature 5 <= 11.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 5 > 11.0)
#        If (feature 2 <= 3.0)
#         Predict: 1.0
#        Else (feature 2 > 3.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 3 <= 11.0)
#       If (feature 8 <= 2.0)
#        If (feature 1 <= 5.0)
#         Predict: 0.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 8 > 2.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 0.0
#      Else (feature 3 > 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 2 <= 3.0)
#         Predict: 1.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#   Tree 31:
#     If (feature 6 <= 1.0)
#      If (feature 7 <= 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 1 <= 2.0)
#         Predict: 3.0
#        Else (feature 1 > 2.0)
#         Predict: 1.0
#       Else (feature 9 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 1.0)
#       If (feature 0 <= 1.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 0 > 1.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#     Else (feature 6 > 1.0)
#      If (feature 0 <= 2.0)
#       If (feature 9 <= 4.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 1.0
#      Else (feature 0 > 2.0)
#       If (feature 7 <= 6.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 6.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 1.0
#   Tree 32:
#     If (feature 3 <= 9.0)
#      If (feature 5 <= 9.0)
#       If (feature 4 <= 3.0)
#        If (feature 9 <= 10.0)
#         Predict: 1.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 4 > 3.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#     Else (feature 3 > 9.0)
#      If (feature 7 <= 9.0)
#       If (feature 5 <= 6.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#      Else (feature 7 > 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 5 > 9.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#   Tree 33:
#     If (feature 8 <= 3.0)
#      If (feature 7 <= 5.0)
#       If (feature 1 <= 5.0)
#        If (feature 0 <= 1.0)
#         Predict: 1.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#       Else (feature 1 > 5.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       If (feature 9 <= 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 9 > 3.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 1.0
#     Else (feature 8 > 3.0)
#      If (feature 1 <= 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#      Else (feature 1 > 4.0)
#       If (feature 5 <= 10.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 1.0
#   Tree 34:
#     If (feature 8 <= 2.0)
#      If (feature 9 <= 6.0)
#       If (feature 5 <= 6.0)
#        If (feature 7 <= 7.0)
#         Predict: 1.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 1.0
#      Else (feature 9 > 6.0)
#       If (feature 5 <= 12.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 1.0
#       Else (feature 5 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 1.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 3 <= 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 2.0
#       Else (feature 9 > 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#      Else (feature 3 > 1.0)
#       If (feature 5 <= 6.0)
#        If (feature 9 <= 6.0)
#         Predict: 0.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#   Tree 35:
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 7 <= 2.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 2.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 1.0
#      Else (feature 3 > 2.0)
#       If (feature 1 <= 2.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 1.0
#       Else (feature 1 > 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#     Else (feature 5 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 5 <= 11.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#   Tree 36:
#     If (feature 2 <= 3.0)
#      If (feature 7 <= 4.0)
#       If (feature 9 <= 4.0)
#        If (feature 1 <= 3.0)
#         Predict: 1.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 9 <= 3.0)
#        If (feature 5 <= 3.0)
#         Predict: 1.0
#        Else (feature 5 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#     Else (feature 2 > 3.0)
#      If (feature 1 <= 1.0)
#       If (feature 7 <= 1.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 3.0
#       Else (feature 7 > 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#      Else (feature 1 > 1.0)
#       If (feature 5 <= 2.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#   Tree 37:
#     If (feature 3 <= 7.0)
#      If (feature 5 <= 7.0)
#       If (feature 1 <= 7.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 7.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 7.0)
#       If (feature 4 <= 2.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 0.0
#       Else (feature 4 > 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 7.0)
#      If (feature 7 <= 7.0)
#       If (feature 3 <= 9.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 3 > 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#      Else (feature 7 > 7.0)
#       If (feature 1 <= 7.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 0.0
#       Else (feature 1 > 7.0)
#        If (feature 5 <= 7.0)
#         Predict: 1.0
#        Else (feature 5 > 7.0)
#         Predict: 1.0
#   Tree 38:
#     If (feature 2 <= 2.0)
#      If (feature 2 <= 1.0)
#       If (feature 4 <= 2.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 4 > 2.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#      Else (feature 2 > 1.0)
#       If (feature 1 <= 3.0)
#        If (feature 9 <= 3.0)
#         Predict: 1.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 3.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#     Else (feature 2 > 2.0)
#      If (feature 8 <= 3.0)
#       If (feature 9 <= 2.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#      Else (feature 8 > 3.0)
#       If (feature 4 <= 1.0)
#        If (feature 1 <= 5.0)
#         Predict: 1.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 4 > 1.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#   Tree 39:
#     If (feature 8 <= 3.0)
#      If (feature 1 <= 1.0)
#       If (feature 3 <= 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 3.0
#        Else (feature 7 > 1.0)
#         Predict: 1.0
#       Else (feature 3 > 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#      Else (feature 1 > 1.0)
#       If (feature 3 <= 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
# ...
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#   Tree 167:
#     If (feature 9 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 2.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#      Else (feature 1 > 2.0)
#       If (feature 7 <= 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 1.0)
#        If (feature 8 <= 1.0)
#         Predict: 0.0
#        Else (feature 8 > 1.0)
#         Predict: 0.0
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 12.0)
#         Predict: 1.0
#        Else (feature 9 > 12.0)
#         Predict: 0.0
#       Else (feature 3 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 7 <= 3.0)
#        If (feature 9 <= 3.0)
#         Predict: 1.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 3 <= 2.0)
#         Predict: 0.0
#        Else (feature 3 > 2.0)
#         Predict: 1.0
#   Tree 168:
#     If (feature 7 <= 4.0)
#      If (feature 1 <= 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 1.0
#       Else (feature 5 > 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#      Else (feature 1 > 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 9 <= 6.0)
#         Predict: 1.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 4.0)
#      If (feature 1 <= 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 5 <= 5.0)
#         Predict: 1.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#      Else (feature 1 > 4.0)
#       If (feature 9 <= 4.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#   Tree 169:
#     If (feature 7 <= 5.0)
#      If (feature 5 <= 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 1.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 4.0)
#       If (feature 3 <= 6.0)
#        If (feature 1 <= 5.0)
#         Predict: 1.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 6.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#     Else (feature 7 > 5.0)
#      If (feature 9 <= 5.0)
#       If (feature 2 <= 2.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 2 > 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 5.0)
#       If (feature 3 <= 7.0)
#        If (feature 1 <= 5.0)
#         Predict: 0.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 1.0
#   Tree 170:
#     If (feature 3 <= 7.0)
#      If (feature 5 <= 7.0)
#       If (feature 9 <= 7.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 7.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 7.0)
#       If (feature 1 <= 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#       Else (feature 1 > 8.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 1.0
#     Else (feature 3 > 7.0)
#      If (feature 5 <= 6.0)
#       If (feature 9 <= 8.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 9 > 8.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#      Else (feature 5 > 6.0)
#       If (feature 1 <= 6.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 6.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 1.0
#   Tree 171:
#     If (feature 7 <= 5.0)
#      If (feature 3 <= 5.0)
#       If (feature 1 <= 5.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 1.0
#       Else (feature 1 > 5.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 0.0
#      Else (feature 3 > 5.0)
#       If (feature 5 <= 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#     Else (feature 7 > 5.0)
#      If (feature 5 <= 5.0)
#       If (feature 2 <= 3.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#      Else (feature 5 > 5.0)
#       If (feature 3 <= 7.0)
#        If (feature 5 <= 6.0)
#         Predict: 1.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 1.0
#   Tree 172:
#     If (feature 5 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 7 <= 3.0)
#        If (feature 9 <= 1.0)
#         Predict: 3.0
#        Else (feature 9 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 3.0)
#        If (feature 8 <= 3.0)
#         Predict: 1.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 7 <= 2.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 1.0
#       Else (feature 7 > 2.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#     Else (feature 5 > 2.0)
#      If (feature 7 <= 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 1 <= 2.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#       Else (feature 1 > 2.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 1.0
#   Tree 173:
#     If (feature 4 <= 2.0)
#      If (feature 8 <= 1.0)
#       If (feature 6 <= 1.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 1.0
#       Else (feature 6 > 1.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 0.0
#      Else (feature 8 > 1.0)
#       If (feature 0 <= 2.0)
#        If (feature 9 <= 3.0)
#         Predict: 0.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 9 <= 5.0)
#       If (feature 7 <= 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 1.0)
#        If (feature 5 <= 5.0)
#         Predict: 1.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#      Else (feature 9 > 5.0)
#       If (feature 8 <= 2.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 8 > 2.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#   Tree 174:
#     If (feature 7 <= 7.0)
#      If (feature 1 <= 6.0)
#       If (feature 9 <= 6.0)
#        If (feature 5 <= 7.0)
#         Predict: 1.0
#        Else (feature 5 > 7.0)
#         Predict: 0.0
#       Else (feature 9 > 6.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 0.0
#      Else (feature 1 > 6.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 3 > 2.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#     Else (feature 7 > 7.0)
#      If (feature 1 <= 7.0)
#       If (feature 3 <= 7.0)
#        If (feature 1 <= 2.0)
#         Predict: 0.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 3 <= 8.0)
#         Predict: 1.0
#        Else (feature 3 > 8.0)
#         Predict: 0.0
#      Else (feature 1 > 7.0)
#       If (feature 5 <= 7.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 0.0
#       Else (feature 5 > 7.0)
#        If (feature 8 <= 1.0)
#         Predict: 1.0
#        Else (feature 8 > 1.0)
#         Predict: 1.0
#   Tree 175:
#     If (feature 3 <= 1.0)
#      If (feature 4 <= 2.0)
#       If (feature 5 <= 1.0)
#        If (feature 1 <= 1.0)
#         Predict: 3.0
#        Else (feature 1 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 1.0)
#        If (feature 1 <= 1.0)
#         Predict: 1.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#      Else (feature 4 > 2.0)
#       If (feature 9 <= 1.0)
#        If (feature 8 <= 3.0)
#         Predict: 1.0
#        Else (feature 8 > 3.0)
#         Predict: 1.0
#       Else (feature 9 > 1.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 1.0
#     Else (feature 3 > 1.0)
#      If (feature 9 <= 1.0)
#       If (feature 1 <= 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 3.0
#        Else (feature 7 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 9 > 1.0)
#       If (feature 0 <= 3.0)
#        If (feature 7 <= 1.0)
#         Predict: 0.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 0 > 3.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#   Tree 176:
#     If (feature 9 <= 10.0)
#      If (feature 5 <= 5.0)
#       If (feature 3 <= 6.0)
#        If (feature 7 <= 6.0)
#         Predict: 1.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 3 > 6.0)
#        If (feature 9 <= 4.0)
#         Predict: 0.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#      Else (feature 5 > 5.0)
#       If (feature 3 <= 5.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 5.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 1.0
#     Else (feature 9 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 1 <= 10.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 8 <= 2.0)
#         Predict: 1.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 0 <= 2.0)
#         Predict: 1.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 9 <= 11.0)
#         Predict: 1.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#   Tree 177:
#     If (feature 0 <= 3.0)
#      If (feature 1 <= 12.0)
#       If (feature 5 <= 9.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#      Else (feature 1 > 12.0)
#       If (feature 9 <= 12.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#       Else (feature 9 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 1.0
#        Else (feature 3 > 12.0)
#         Predict: 3.0
#     Else (feature 0 > 3.0)
#      If (feature 1 <= 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 1.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#      Else (feature 1 > 4.0)
#       If (feature 9 <= 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 1.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 1.0
#   Tree 178:
#     If (feature 0 <= 3.0)
#      If (feature 3 <= 11.0)
#       If (feature 5 <= 11.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 5 > 11.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#      Else (feature 3 > 11.0)
#       If (feature 7 <= 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#       Else (feature 7 > 11.0)
#        If (feature 0 <= 2.0)
#         Predict: 1.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#     Else (feature 0 > 3.0)
#      If (feature 6 <= 3.0)
#       If (feature 8 <= 2.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 1.0
#       Else (feature 8 > 2.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 0.0
#      Else (feature 6 > 3.0)
#       If (feature 2 <= 3.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#   Tree 179:
#     If (feature 9 <= 9.0)
#      If (feature 7 <= 9.0)
#       If (feature 6 <= 1.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#      Else (feature 7 > 9.0)
#       If (feature 0 <= 2.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#       Else (feature 0 > 2.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 1.0
#     Else (feature 9 > 9.0)
#      If (feature 7 <= 9.0)
#       If (feature 9 <= 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#       Else (feature 9 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#      Else (feature 7 > 9.0)
#       If (feature 9 <= 10.0)
#        If (feature 1 <= 9.0)
#         Predict: 1.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 9 > 10.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0

# %% [markdown]
# With a lot more trees in the ensemble, the training error has decreased a lot! But the training time has increased substantially as well. Remember that the training time increases roughly linearly with the number of trees.

# %% [markdown]
# <a id = "fss"></a>
#
# ### <span style="color:#0b486b">6.2 featureSubsetStrategy Parameter</span>
#
# Remember that the featureSubsetStrategy parameter only changes the number of features used as candidates for splitting. The default is set to <b>"auto"</b>, which will select "all", "sqrt", or "onethird" based on the value of numTrees. Since we are basing our analysis off of the default values, we have a numTrees value of 3, which means "sqrt" is selected. So let's start by changing it it <b>"all"</b>, which will use all of the features

# %%
classRF_tuner(3, "all")
# Out:
# 7.198732376098633
# Test Error = 0.5068712474983322
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 8 <= 2.0)
#      If (feature 9 <= 6.0)
#       If (feature 3 <= 6.0)
#        If (feature 7 <= 7.0)
#         Predict: 1.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 3 > 6.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#      Else (feature 9 > 6.0)
#       If (feature 7 <= 8.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 8.0)
#        If (feature 3 <= 6.0)
#         Predict: 0.0
#        Else (feature 3 > 6.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 2 <= 2.0)
#       If (feature 6 <= 1.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 2 > 2.0)
#       If (feature 4 <= 2.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#       Else (feature 4 > 2.0)
#        If (feature 5 <= 6.0)
#         Predict: 0.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#   Tree 1:
#     If (feature 0 <= 2.0)
#      If (feature 6 <= 3.0)
#       If (feature 4 <= 1.0)
#        If (feature 5 <= 2.0)
#         Predict: 0.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#       Else (feature 4 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 6 > 3.0)
#       If (feature 7 <= 11.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 11.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 1.0
#     Else (feature 0 > 2.0)
#      If (feature 4 <= 2.0)
#       If (feature 7 <= 11.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#       Else (feature 7 > 11.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 1.0
#      Else (feature 4 > 2.0)
#       If (feature 8 <= 2.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 8 > 2.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 0 <= 3.0)
#      If (feature 9 <= 9.0)
#       If (feature 7 <= 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 1.0
#      Else (feature 9 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#       Else (feature 7 > 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 1.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#     Else (feature 0 > 3.0)
#      If (feature 2 <= 3.0)
#       If (feature 2 <= 1.0)
#        If (feature 1 <= 1.0)
#         Predict: 0.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#       Else (feature 2 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 0.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 2 > 3.0)
#       If (feature 9 <= 5.0)
#        If (feature 1 <= 10.0)
#         Predict: 1.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#       Else (feature 9 > 5.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 0.0

# %% [markdown]
# We can see that there is a small increase in the building time of the model, which is expected since we are considering all of the features. As well, there is a small increase in the test error. A possibility to the increase in test error is that there are some features that aren't "good" in the model, causing an increase in the test error. Next, we will try with <b>"sqrt"</b>

# %%
classRF_tuner(3, "sqrt")
# Out:
# 7.753561019897461
# Test Error = 0.49086057371581054
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 3 <= 10.0)
#      If (feature 5 <= 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 1.0
#        Else (feature 7 > 11.0)
#         Predict: 0.0
#       Else (feature 9 > 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#      Else (feature 5 > 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 1.0
#     Else (feature 3 > 10.0)
#      If (feature 5 <= 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 1.0
#      Else (feature 5 > 10.0)
#       If (feature 2 <= 2.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 1.0
#       Else (feature 2 > 2.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 3 <= 3.0)
#      If (feature 7 <= 3.0)
#       If (feature 0 <= 2.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 1.0
#       Else (feature 0 > 2.0)
#        If (feature 6 <= 1.0)
#         Predict: 1.0
#        Else (feature 6 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 3.0)
#       If (feature 7 <= 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 4.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#     Else (feature 3 > 3.0)
#      If (feature 8 <= 3.0)
#       If (feature 9 <= 8.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 0.0
#       Else (feature 9 > 8.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 1.0
#      Else (feature 8 > 3.0)
#       If (feature 5 <= 2.0)
#        If (feature 1 <= 1.0)
#         Predict: 1.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 5 <= 11.0)
#      If (feature 3 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#      Else (feature 3 > 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#       Else (feature 9 > 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#     Else (feature 5 > 11.0)
#      If (feature 7 <= 11.0)
#       If (feature 3 <= 11.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#       Else (feature 3 > 11.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 1.0
#      Else (feature 7 > 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 1.0
#        Else (feature 3 > 11.0)
#         Predict: 2.0

# %% [markdown]
# This has very similar values to the "auto", which is correct since "auto" is using "sqrt" for featureSubsetStrategy, since our numTrees value was set to 3. Let's try using "onethird" now, which uses one third of the features.

# %%
classRF_tuner(3, "onethird")
# Out:
# 8.623813152313232
# Test Error = 0.48112074716477654
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 4 <= 2.0)
#      If (feature 5 <= 7.0)
#       If (feature 7 <= 6.0)
#        If (feature 1 <= 7.0)
#         Predict: 1.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#       Else (feature 7 > 6.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 7.0)
#       If (feature 1 <= 7.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 1 > 7.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 1 <= 12.0)
#       If (feature 2 <= 3.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#      Else (feature 1 > 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 1.0
#       Else (feature 5 > 12.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 7 <= 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 9 <= 8.0)
#        If (feature 9 <= 3.0)
#         Predict: 1.0
#        Else (feature 9 > 3.0)
#         Predict: 1.0
#       Else (feature 9 > 8.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 8.0)
#       If (feature 5 <= 7.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 7.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 1.0
#     Else (feature 7 > 8.0)
#      If (feature 9 <= 8.0)
#       If (feature 4 <= 1.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#       Else (feature 4 > 1.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#      Else (feature 9 > 8.0)
#       If (feature 3 <= 8.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 1.0
#       Else (feature 3 > 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 1.0
#        Else (feature 5 > 8.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 8 <= 2.0)
#      If (feature 9 <= 9.0)
#       If (feature 5 <= 10.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 4 <= 3.0)
#         Predict: 0.0
#        Else (feature 4 > 3.0)
#         Predict: 0.0
#      Else (feature 9 > 9.0)
#       If (feature 1 <= 9.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 1.0
#       Else (feature 1 > 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 1.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 5 <= 2.0)
#       If (feature 1 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#       Else (feature 1 > 2.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 2.0)
#       If (feature 0 <= 2.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#       Else (feature 0 > 2.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0

# %% [markdown]
# We see that the run-time is similar to the default, but the testing error has decreased a little bit. It's possible that there is about the same number of features when you take one third of them, as if you take the square root of them for this particular dataset. Let's try with the last type, which is <b>"log2"</b>

# %%
classRF_tuner(3, "log2")
# Out:
# 8.921212911605835
# Test Error = 0.4883255503669113
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 5 <= 4.0)
#      If (feature 3 <= 4.0)
#       If (feature 7 <= 4.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 1.0
#       Else (feature 7 > 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#      Else (feature 3 > 4.0)
#       If (feature 7 <= 3.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 5 <= 2.0)
#         Predict: 0.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#     Else (feature 5 > 4.0)
#      If (feature 3 <= 4.0)
#       If (feature 4 <= 3.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 4 > 3.0)
#        If (feature 3 <= 2.0)
#         Predict: 0.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#      Else (feature 3 > 4.0)
#       If (feature 0 <= 3.0)
#        If (feature 9 <= 4.0)
#         Predict: 0.0
#        Else (feature 9 > 4.0)
#         Predict: 1.0
#       Else (feature 0 > 3.0)
#        If (feature 9 <= 1.0)
#         Predict: 0.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#   Tree 1:
#     If (feature 8 <= 3.0)
#      If (feature 7 <= 5.0)
#       If (feature 9 <= 5.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 9 > 5.0)
#        If (feature 5 <= 6.0)
#         Predict: 0.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       If (feature 3 <= 7.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 1.0
#     Else (feature 8 > 3.0)
#      If (feature 7 <= 10.0)
#       If (feature 7 <= 7.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 0.0
#       Else (feature 7 > 7.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 4.0)
#        If (feature 4 <= 3.0)
#         Predict: 0.0
#        Else (feature 4 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 5 <= 1.0)
#      If (feature 3 <= 1.0)
#       If (feature 8 <= 3.0)
#        If (feature 1 <= 12.0)
#         Predict: 1.0
#        Else (feature 1 > 12.0)
#         Predict: 1.0
#       Else (feature 8 > 3.0)
#        If (feature 1 <= 1.0)
#         Predict: 3.0
#        Else (feature 1 > 1.0)
#         Predict: 1.0
#      Else (feature 3 > 1.0)
#       If (feature 4 <= 2.0)
#        If (feature 1 <= 1.0)
#         Predict: 1.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#       Else (feature 4 > 2.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#     Else (feature 5 > 1.0)
#      If (feature 9 <= 9.0)
#       If (feature 1 <= 11.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 9.0)
#       If (feature 1 <= 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 9.0)
#        If (feature 2 <= 2.0)
#         Predict: 1.0
#        Else (feature 2 > 2.0)
#         Predict: 1.0

# %% [markdown]
# When using <b>"log2"</b>, there is a decrease in run-time, along with testing error!

# %% [markdown]
# ---
# <a id = "rfr"></a>
# ## <span style="color:#0b486b">7. RandomForest (Regression)</span>
#
# Now it's time for you to try it out for yourself! Build a Regression RandomForest in a similar way that the Classification RandomForest was built. Please note that you will be using the same dataset in this section (classRF_train, classRF_test), therefore you do not need to re-initialize that section.<br> <br>
#
# Try to only reference the above section when you are experiencing a lot of difficulty. This section is mainly for you to apply your learning.
#
# For some help with the variables:
# <ul>
#     <li><b>categoricalFeaturesInfo</b>: Has a value of <b>{}</b> (parameter doesn't require tuning)</li>
#     <li><b>featureSubsetStrategy</b>: Can change these values between <b>"auto"</b>, <b>"all"</b>, <b>"sqrt"</b>, <b>"log2"</b>, and <b>"onethird"</b></li>
#     <li><b>numTrees</b>: Values range from <b>1</b> to infinity<i>(Default: 3)</i></li>
#     <ul>
#         <li>Note: If the value is too large, the system can run out of memory and not run.</li>
#     </ul>
#     <li><b>impurity</b>: For Regression, the value must be set to <b>'variance'</b> <i>(Default: 'variance')</i></li>
#     <li><b>maxDepth</b>: Values range between <b>0 and 30</b> <i>(Default: 5)</i></li>
#     <li><b>maxBins</b>: Value ranges between <b>2 and 2147483647</b> (largest value for 32-bits) <i>(Default: 32)</i></li>
#     <li><b>seed</b> Can be set to any value, or to a value based on system time with <i>None</i> <i>(Default: None)</i></li>
# </ul>
#
# When displaying the <b>Mean Squared Error</b>, use the following formula and print statement instead of Training Error: <br>
# <b>regRF_MSE = regRF_label_pred.map(lambda (v, p): (v - p)**2).sum() / float(classRF_test.count())</b> <br>
# <b>print('Test Error = ' + str(regRF_MSE))</b>
#
# #### The Goal
# Try to create a model that is better than the model with default values.
#
# #### Try to beat!
# With some parameter tuning, I was able to get a run-time increase of the model by ~0.9 seconds and a Test error decrease of ~2.54. Try to get a value similar to this, or better.
#
# #### Note
# We want a model that doesn't take too long to train and will cause overfitting. Remember that a very large model with high accuracy but long run time may not be good because the model may have overfit the data.

# %%
start = time.time()
regRF_model = RandomForest.trainRegressor(classRF_train, categoricalFeaturesInfo={},
                                    numTrees=14, featureSubsetStrategy="onethird",
                                    impurity='variance', maxDepth=11, maxBins=24, seed=None)
print(time.time() - start)
# Evaluate model on test instances and compute test error
regRF_pred = regRF_model.predict(classRF_train.map(lambda x: x.features))
regRF_label_pred = classRF_train.map(lambda lp: lp.label).zip(regRF_pred)
regRF_MSE = regRF_label_pred.map(lambda value: (value[0] - value[1]) ** 2).sum()/\
                                   float(classRF_train.count())
print('Test Mean Squared Error = ' + str(regRF_MSE))
print('Learned regression forest model: ' + regRF_model.toDebugString())

# 0.541887044907
# Test Mean Squared Error = 2.63255831252
# Learned regression forest model: TreeEnsembleModel regressor with 3 trees
# numTrees: 3
# featureSubsetStrategy="auto"
# Impurity: variance
# maxDepth: 4
# maxBins: 32


# 1.41001796722
# Test Mean Squared Error = 0.088487863674
# Learned regression forest model: TreeEnsembleModel regressor with 14 trees
# numTrees: 14
# featureSubsetStrategy="onethird"
# Impurity: variance
# maxDepth: 11
# maxBins: 16
# Out:
# 17.723559617996216
# Test Mean Squared Error = 0.3485446591381959
# Learned regression forest model: TreeEnsembleModel regressor with 14 trees
#
#   Tree 0:
#     If (feature 3 <= 1.0)
#      If (feature 5 <= 1.0)
#       If (feature 0 <= 3.0)
#        If (feature 2 <= 1.0)
#         If (feature 7 <= 10.0)
#          If (feature 0 <= 1.0)
#           If (feature 7 <= 4.0)
#            Predict: 1.0
#           Else (feature 7 > 4.0)
#            Predict: 2.0
#          Else (feature 0 > 1.0)
#           Predict: 1.0
#         Else (feature 7 > 10.0)
#          Predict: 2.0
#        Else (feature 2 > 1.0)
#         If (feature 2 <= 3.0)
#          Predict: 1.0
#         Else (feature 2 > 3.0)
#          If (feature 7 <= 8.0)
#           Predict: 1.0
#          Else (feature 7 > 8.0)
#           If (feature 7 <= 9.0)
#            Predict: 2.0
#           Else (feature 7 > 9.0)
#            Predict: 1.0
#       Else (feature 0 > 3.0)
#        If (feature 1 <= 1.0)
#         Predict: 3.0
#        Else (feature 1 > 1.0)
#         If (feature 9 <= 1.0)
#          Predict: 3.0
#         Else (feature 9 > 1.0)
#          If (feature 7 <= 11.0)
#           If (feature 6 <= 1.0)
#            Predict: 2.0
#           Else (feature 6 > 1.0)
#            If (feature 2 <= 3.0)
#             If (feature 7 <= 8.0)
#              Predict: 1.0
#             Else (feature 7 > 8.0)
#              If (feature 1 <= 6.0)
#               Predict: 1.0
#              Else (feature 1 > 6.0)
#               Predict: 2.0
#            Else (feature 2 > 3.0)
#             If (feature 1 <= 2.0)
#              Predict: 1.0
#             Else (feature 1 > 2.0)
#              Predict: 2.0
#          Else (feature 7 > 11.0)
#           Predict: 1.0
#      Else (feature 5 > 1.0)
#       If (feature 1 <= 1.0)
#        If (feature 9 <= 2.0)
#         If (feature 6 <= 3.0)
#          Predict: 3.0
#         Else (feature 6 > 3.0)
#          Predict: 1.0
#        Else (feature 9 > 2.0)
#         If (feature 0 <= 3.0)
#          If (feature 5 <= 3.0)
#           If (feature 8 <= 3.0)
#            Predict: 1.0
#           Else (feature 8 > 3.0)
#            Predict: 2.0
#          Else (feature 5 > 3.0)
#           If (feature 7 <= 12.0)
#            Predict: 1.0
#           Else (feature 7 > 12.0)
#            If (feature 2 <= 3.0)
#             Predict: 2.0
#            Else (feature 2 > 3.0)
#             Predict: 1.0
#         Else (feature 0 > 3.0)
#          If (feature 7 <= 1.0)
#           If (feature 4 <= 1.0)
#            Predict: 3.0
#           Else (feature 4 > 1.0)
#            Predict: 6.0
#          Else (feature 7 > 1.0)
#           If (feature 6 <= 1.0)
#            If (feature 4 <= 3.0)
#             Predict: 1.0
#            Else (feature 4 > 3.0)
#             Predict: 2.0
#           Else (feature 6 > 1.0)
#            If (feature 7 <= 4.0)
#             If (feature 9 <= 3.0)
#              Predict: 2.0
#             Else (feature 9 > 3.0)
#              Predict: 1.0
#            Else (feature 7 > 4.0)
#             Predict: 1.0
#       Else (feature 1 > 1.0)
#        If (feature 8 <= 1.0)
#         If (feature 7 <= 1.0)
#          If (feature 5 <= 5.0)
#           If (feature 2 <= 1.0)
#            Predict: 2.0
#           Else (feature 2 > 1.0)
#            If (feature 6 <= 1.0)
#             Predict: 1.0
#            Else (feature 6 > 1.0)
#             Predict: 2.0
#          Else (feature 5 > 5.0)
#           If (feature 2 <= 3.0)
#            If (feature 0 <= 2.0)
#             Predict: 1.0
#            Else (feature 0 > 2.0)
#             If (feature 4 <= 3.0)
#              Predict: 1.0
#             Else (feature 4 > 3.0)
#              Predict: 2.0
#           Else (feature 2 > 3.0)
#            If (feature 1 <= 3.0)
#             Predict: 2.0
#            Else (feature 1 > 3.0)
#             Predict: 1.0
#         Else (feature 7 > 1.0)
#          If (feature 4 <= 2.0)
#           If (feature 9 <= 1.0)
#            Predict: 1.0
#           Else (feature 9 > 1.0)
#            If (feature 1 <= 4.0)
#             If (feature 0 <= 3.0)
#              Predict: 0.0
#             Else (feature 0 > 3.0)
#              If (feature 7 <= 7.0)
#               Predict: 1.0
#              Else (feature 7 > 7.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.3333333333333333
#               Else (feature 7 > 12.0)
#                Predict: 0.0
#            Else (feature 1 > 4.0)
#             If (feature 0 <= 2.0)
#              If (feature 9 <= 8.0)
#               If (feature 5 <= 11.0)
#                Predict: 0.18518518518518517
#               Else (feature 5 > 11.0)
#                Predict: 1.0
#              Else (feature 9 > 8.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.6363636363636364
#               Else (feature 1 > 9.0)
#                Predict: 1.0
#             Else (feature 0 > 2.0)
#              If (feature 6 <= 3.0)
#               If (feature 5 <= 8.0)
#                Predict: 0.34615384615384615
#               Else (feature 5 > 8.0)
#                Predict: 0.058823529411764705
#              Else (feature 6 > 3.0)
#               If (feature 1 <= 8.0)
#                Predict: 1.0
#               Else (feature 1 > 8.0)
#                Predict: 0.0
#          Else (feature 4 > 2.0)
#           If (feature 2 <= 1.0)
#            If (feature 7 <= 9.0)
#             If (feature 4 <= 3.0)
#              If (feature 0 <= 2.0)
#               Predict: 1.0
#              Else (feature 0 > 2.0)
#               Predict: 0.0
#             Else (feature 4 > 3.0)
#              If (feature 1 <= 7.0)
#               If (feature 9 <= 4.0)
#                Predict: 1.0
#               Else (feature 9 > 4.0)
#                Predict: 0.25
#              Else (feature 1 > 7.0)
#               If (feature 0 <= 2.0)
#                Predict: 3.0
#               Else (feature 0 > 2.0)
#                Predict: 0.0
#            Else (feature 7 > 9.0)
#             Predict: 0.0
#           Else (feature 2 > 1.0)
#            If (feature 0 <= 1.0)
#             If (feature 6 <= 3.0)
#              If (feature 7 <= 3.0)
#               Predict: 1.0
#              Else (feature 7 > 3.0)
#               If (feature 1 <= 7.0)
#                Predict: 0.07692307692307693
#               Else (feature 1 > 7.0)
#                Predict: 0.6666666666666666
#             Else (feature 6 > 3.0)
#              If (feature 9 <= 2.0)
#               Predict: 0.0
#              Else (feature 9 > 2.0)
#               Predict: 1.0
#            Else (feature 0 > 1.0)
#             If (feature 5 <= 2.0)
#              If (feature 0 <= 2.0)
#               If (feature 9 <= 12.0)
#                Predict: 0.0
#               Else (feature 9 > 12.0)
#                Predict: 1.0
#              Else (feature 0 > 2.0)
#               Predict: 0.0
#             Else (feature 5 > 2.0)
#              If (feature 1 <= 3.0)
#               If (feature 6 <= 3.0)
#                Predict: 1.2142857142857142
#               Else (feature 6 > 3.0)
#                Predict: 0.5
#              Else (feature 1 > 3.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.16666666666666666
#               Else (feature 7 > 2.0)
#                Predict: 0.7763157894736842
#        Else (feature 8 > 1.0)
#         If (feature 2 <= 2.0)
#          If (feature 9 <= 1.0)
#           If (feature 8 <= 2.0)
#            If (feature 7 <= 1.0)
#             Predict: 3.0
#            Else (feature 7 > 1.0)
#             If (feature 7 <= 6.0)
#              Predict: 1.0
#             Else (feature 7 > 6.0)
#              Predict: 2.0
#           Else (feature 8 > 2.0)
#            If (feature 0 <= 3.0)
#             Predict: 1.0
#            Else (feature 0 > 3.0)
#             Predict: 2.0
#          Else (feature 9 > 1.0)
#           If (feature 1 <= 6.0)
#            If (feature 7 <= 1.0)
#             If (feature 5 <= 5.0)
#              If (feature 1 <= 2.0)
#               Predict: 1.0
#              Else (feature 1 > 2.0)
#               Predict: 2.0
#             Else (feature 5 > 5.0)
#              Predict: 1.0
#            Else (feature 7 > 1.0)
#             If (feature 5 <= 6.0)
#              If (feature 6 <= 1.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.4166666666666667
#               Else (feature 8 > 3.0)
#                Predict: 1.1666666666666667
#              Else (feature 6 > 1.0)
#               If (feature 5 <= 3.0)
#                Predict: 0.5238095238095238
#               Else (feature 5 > 3.0)
#                Predict: 0.14814814814814814
#             Else (feature 5 > 6.0)
#              If (feature 7 <= 2.0)
#               Predict: 0.0
#              Else (feature 7 > 2.0)
#               If (feature 7 <= 5.0)
#                Predict: 0.6470588235294118
#               Else (feature 7 > 5.0)
#                Predict: 0.23170731707317074
#           Else (feature 1 > 6.0)
#            If (feature 5 <= 6.0)
#             If (feature 7 <= 1.0)
#              If (feature 9 <= 5.0)
#               Predict: 1.0
#              Else (feature 9 > 5.0)
#               If (feature 5 <= 2.0)
#                Predict: 1.0
#               Else (feature 5 > 2.0)
#                Predict: 2.0
#             Else (feature 7 > 1.0)
#              If (feature 9 <= 8.0)
#               If (feature 7 <= 8.0)
#                Predict: 0.6875
#               Else (feature 7 > 8.0)
#                Predict: 0.20588235294117646
#              Else (feature 9 > 8.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.045454545454545456
#               Else (feature 0 > 2.0)
#                Predict: 0.20833333333333334
#            Else (feature 5 > 6.0)
#             If (feature 5 <= 7.0)
#              If (feature 9 <= 6.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.2
#               Else (feature 2 > 1.0)
#                Predict: 1.0
#              Else (feature 9 > 6.0)
#               If (feature 9 <= 7.0)
#                Predict: 2.0
#               Else (feature 9 > 7.0)
#                Predict: 1.6666666666666667
#             Else (feature 5 > 7.0)
#              If (feature 5 <= 12.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.5434782608695652
#               Else (feature 6 > 2.0)
#                Predict: 0.32608695652173914
#              Else (feature 5 > 12.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.625
#               Else (feature 0 > 2.0)
#                Predict: 0.16666666666666666
#         Else (feature 2 > 2.0)
#          If (feature 4 <= 2.0)
#           If (feature 7 <= 1.0)
#            If (feature 0 <= 2.0)
#             If (feature 6 <= 2.0)
#              Predict: 1.0
#             Else (feature 6 > 2.0)
#              Predict: 2.0
#            Else (feature 0 > 2.0)
#             Predict: 1.0
#           Else (feature 7 > 1.0)
#            If (feature 9 <= 1.0)
#             Predict: 1.0
#            Else (feature 9 > 1.0)
#             If (feature 9 <= 7.0)
#              If (feature 1 <= 12.0)
#               If (feature 1 <= 5.0)
#                Predict: 0.4166666666666667
#               Else (feature 1 > 5.0)
#                Predict: 0.09333333333333334
#              Else (feature 1 > 12.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.16666666666666666
#               Else (feature 7 > 2.0)
#                Predict: 0.8
#             Else (feature 9 > 7.0)
#              If (feature 5 <= 12.0)
#               If (feature 1 <= 12.0)
#                Predict: 0.25
#               Else (feature 1 > 12.0)
#                Predict: 0.9090909090909091
#              Else (feature 5 > 12.0)
#               Predict: 3.0
#          Else (feature 4 > 2.0)
#           If (feature 6 <= 1.0)
#            If (feature 4 <= 3.0)
#             If (feature 0 <= 1.0)
#              Predict: 0.0
#             Else (feature 0 > 1.0)
#              If (feature 2 <= 3.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                Predict: 1.5714285714285714
#              Else (feature 2 > 3.0)
#               If (feature 7 <= 10.0)
#                Predict: 1.0
#               Else (feature 7 > 10.0)
#                Predict: 0.0
#            Else (feature 4 > 3.0)
#             If (feature 1 <= 2.0)
#              If (feature 7 <= 3.0)
#               Predict: 0.0
#              Else (feature 7 > 3.0)
#               Predict: 1.0
#             Else (feature 1 > 2.0)
#              If (feature 8 <= 2.0)
#               If (feature 9 <= 2.0)
#                Predict: 0.0
#               Else (feature 9 > 2.0)
#                Predict: 0.75
#              Else (feature 8 > 2.0)
#               If (feature 1 <= 3.0)
#                Predict: 0.16666666666666666
#               Else (feature 1 > 3.0)
#                Predict: 0.0
#           Else (feature 6 > 1.0)
#            If (feature 5 <= 3.0)
#             If (feature 1 <= 3.0)
#              Predict: 3.0
#             Else (feature 1 > 3.0)
#              If (feature 9 <= 10.0)
#               If (feature 7 <= 4.0)
#                Predict: 1.0
#               Else (feature 7 > 4.0)
#                Predict: 0.5
#              Else (feature 9 > 10.0)
#               Predict: 0.0
#            Else (feature 5 > 3.0)
#             If (feature 9 <= 1.0)
#              Predict: 1.0
#             Else (feature 9 > 1.0)
#              If (feature 5 <= 7.0)
#               If (feature 1 <= 8.0)
#                Predict: 0.4090909090909091
#               Else (feature 1 > 8.0)
#                Predict: 0.13043478260869565
#              Else (feature 5 > 7.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.23728813559322035
#               Else (feature 8 > 3.0)
#                Predict: 0.7692307692307693
#     Else (feature 3 > 1.0)
#      If (feature 1 <= 12.0)
#       If (feature 7 <= 1.0)
#        If (feature 5 <= 1.0)
#         If (feature 1 <= 1.0)
#          Predict: 3.0
#         Else (feature 1 > 1.0)
#          If (feature 2 <= 1.0)
#           If (feature 9 <= 9.0)
#            Predict: 1.0
#           Else (feature 9 > 9.0)
#            Predict: 2.0
#          Else (feature 2 > 1.0)
#           If (feature 1 <= 8.0)
#            Predict: 1.0
#           Else (feature 1 > 8.0)
#            If (feature 6 <= 2.0)
#             Predict: 1.0
#            Else (feature 6 > 2.0)
#             If (feature 3 <= 8.0)
#              If (feature 0 <= 1.0)
#               Predict: 2.0
#              Else (feature 0 > 1.0)
#               Predict: 1.0
#             Else (feature 3 > 8.0)
#              Predict: 2.0
#        Else (feature 5 > 1.0)
#         If (feature 9 <= 1.0)
#          If (feature 6 <= 1.0)
#           If (feature 3 <= 10.0)
#            If (feature 8 <= 2.0)
#             If (feature 0 <= 2.0)
#              If (feature 1 <= 3.0)
#               Predict: 1.0
#              Else (feature 1 > 3.0)
#               Predict: 2.0
#             Else (feature 0 > 2.0)
#              Predict: 2.0
#            Else (feature 8 > 2.0)
#             If (feature 2 <= 1.0)
#              Predict: 1.0
#             Else (feature 2 > 1.0)
#              Predict: 2.0
#           Else (feature 3 > 10.0)
#            Predict: 1.0
#          Else (feature 6 > 1.0)
#           If (feature 3 <= 4.0)
#            If (feature 5 <= 6.0)
#             If (feature 6 <= 3.0)
#              Predict: 1.0
#             Else (feature 6 > 3.0)
#              If (feature 2 <= 2.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.6666666666666667
#               Else (feature 0 > 3.0)
#                Predict: 2.0
#              Else (feature 2 > 2.0)
#               Predict: 3.0
#            Else (feature 5 > 6.0)
#             Predict: 1.0
#           Else (feature 3 > 4.0)
#            If (feature 2 <= 1.0)
#             If (feature 0 <= 3.0)
#              Predict: 1.0
#             Else (feature 0 > 3.0)
#              Predict: 2.0
#            Else (feature 2 > 1.0)
#             If (feature 1 <= 2.0)
#              Predict: 2.0
#             Else (feature 1 > 2.0)
#              If (feature 3 <= 12.0)
#               Predict: 1.0
#              Else (feature 3 > 12.0)
#               Predict: 1.3333333333333333
#         Else (feature 9 > 1.0)
#          If (feature 1 <= 1.0)
#           If (feature 3 <= 2.0)
#            If (feature 6 <= 3.0)
#             If (feature 0 <= 3.0)
#              If (feature 4 <= 2.0)
#               Predict: 2.0
#              Else (feature 4 > 2.0)
#               Predict: 6.0
#             Else (feature 0 > 3.0)
#              Predict: 1.0
#            Else (feature 6 > 3.0)
#             Predict: 1.0
#           Else (feature 3 > 2.0)
#            If (feature 3 <= 8.0)
#             If (feature 8 <= 3.0)
#              If (feature 2 <= 2.0)
#               Predict: 1.0
#              Else (feature 2 > 2.0)
#               If (feature 5 <= 8.0)
#                Predict: 1.7142857142857142
#               Else (feature 5 > 8.0)
#                Predict: 1.1428571428571428
#             Else (feature 8 > 3.0)
#              Predict: 1.0
#            Else (feature 3 > 8.0)
#             If (feature 4 <= 3.0)
#              Predict: 1.0
#             Else (feature 4 > 3.0)
#              If (feature 6 <= 2.0)
#               If (feature 9 <= 3.0)
#                Predict: 1.0
#               Else (feature 9 > 3.0)
#                Predict: 2.0
#              Else (feature 6 > 2.0)
#               Predict: 1.0
#          Else (feature 1 > 1.0)
#           If (feature 6 <= 1.0)
#            If (feature 1 <= 4.0)
#             If (feature 5 <= 5.0)
#              If (feature 9 <= 4.0)
#               If (feature 3 <= 4.0)
#                Predict: 4.0
#               Else (feature 3 > 4.0)
#                Predict: 1.5
#              Else (feature 9 > 4.0)
#               If (feature 5 <= 3.0)
#                Predict: 0.0
#               Else (feature 5 > 3.0)
#                Predict: 0.6
#             Else (feature 5 > 5.0)
#              If (feature 1 <= 2.0)
#               Predict: 0.0
#              Else (feature 1 > 2.0)
#               If (feature 3 <= 4.0)
#                Predict: 1.2857142857142858
#               Else (feature 3 > 4.0)
#                Predict: 0.47368421052631576
#            Else (feature 1 > 4.0)
#             If (feature 5 <= 4.0)
#              If (feature 9 <= 4.0)
#               If (feature 2 <= 3.0)
#                Predict: 1.0
#               Else (feature 2 > 3.0)
#                Predict: 0.0
#              Else (feature 9 > 4.0)
#               If (feature 3 <= 2.0)
#                Predict: 0.6666666666666666
#               Else (feature 3 > 2.0)
#                Predict: 0.08333333333333333
#             Else (feature 5 > 4.0)
#              If (feature 3 <= 7.0)
#               If (feature 5 <= 7.0)
#                Predict: 1.0
#               Else (feature 5 > 7.0)
#                Predict: 0.18604651162790697
#              Else (feature 3 > 7.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.0
#               Else (feature 0 > 1.0)
#                Predict: 0.5945945945945946
#           Else (feature 6 > 1.0)
#            If (feature 1 <= 8.0)
#             If (feature 0 <= 1.0)
#              If (feature 1 <= 3.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.4117647058823529
#               Else (feature 8 > 2.0)
#                Predict: 0.7368421052631579
#              Else (feature 1 > 3.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.4032258064516129
#               Else (feature 8 > 3.0)
#                Predict: 0.14285714285714285
#             Else (feature 0 > 1.0)
#              If (feature 5 <= 7.0)
#               If (feature 1 <= 6.0)
#                Predict: 0.49523809523809526
#               Else (feature 1 > 6.0)
#                Predict: 0.2033898305084746
#              Else (feature 5 > 7.0)
#               If (feature 9 <= 4.0)
#                Predict: 0.41379310344827586
#               Else (feature 9 > 4.0)
#                Predict: 0.1
#            Else (feature 1 > 8.0)
#             If (feature 5 <= 8.0)
#              If (feature 4 <= 3.0)
#               If (feature 2 <= 2.0)
#                Predict: 0.46774193548387094
#               Else (feature 2 > 2.0)
#                Predict: 0.16326530612244897
#              Else (feature 4 > 3.0)
#               If (feature 3 <= 8.0)
#                Predict: 0.0
#               Else (feature 3 > 8.0)
#                Predict: 0.125
#             Else (feature 5 > 8.0)
#              If (feature 1 <= 10.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.6363636363636364
#               Else (feature 1 > 9.0)
#                Predict: 0.875
#              Else (feature 1 > 10.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.21875
#               Else (feature 4 > 2.0)
#                Predict: 0.5384615384615384
#       Else (feature 7 > 1.0)
#        If (feature 1 <= 1.0)
#         If (feature 5 <= 1.0)
#          If (feature 3 <= 8.0)
#           If (feature 7 <= 12.0)
#            If (feature 2 <= 3.0)
#             If (feature 7 <= 11.0)
#              If (feature 9 <= 1.0)
#               Predict: 3.0
#              Else (feature 9 > 1.0)
#               If (feature 6 <= 1.0)
#                Predict: 1.4
#               Else (feature 6 > 1.0)
#                Predict: 1.0
#             Else (feature 7 > 11.0)
#              If (feature 8 <= 1.0)
#               Predict: 3.0
#              Else (feature 8 > 1.0)
#               Predict: 2.0
#            Else (feature 2 > 3.0)
#             Predict: 1.0
#           Else (feature 7 > 12.0)
#            Predict: 3.0
#          Else (feature 3 > 8.0)
#           If (feature 9 <= 1.0)
#            Predict: 3.0
#           Else (feature 9 > 1.0)
#            Predict: 1.0
#         Else (feature 5 > 1.0)
#          If (feature 5 <= 4.0)
#           If (feature 3 <= 2.0)
#            If (feature 9 <= 5.0)
#             If (feature 0 <= 2.0)
#              Predict: 8.0
#             Else (feature 0 > 2.0)
#              If (feature 6 <= 1.0)
#               Predict: 3.0
#              Else (feature 6 > 1.0)
#               Predict: 1.0
#            Else (feature 9 > 5.0)
#             If (feature 7 <= 6.0)
#              If (feature 6 <= 3.0)
#               Predict: 0.0
#              Else (feature 6 > 3.0)
#               Predict: 1.0
#             Else (feature 7 > 6.0)
#              If (feature 8 <= 1.0)
#               If (feature 7 <= 7.0)
#                Predict: 1.0
#               Else (feature 7 > 7.0)
#                Predict: 0.0
#              Else (feature 8 > 1.0)
#               Predict: 1.0
#           Else (feature 3 > 2.0)
#            If (feature 7 <= 9.0)
#             If (feature 3 <= 7.0)
#              If (feature 4 <= 1.0)
#               If (feature 7 <= 4.0)
#                Predict: 0.7777777777777778
#               Else (feature 7 > 4.0)
#                Predict: 0.0
#              Else (feature 4 > 1.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0606060606060606
#               Else (feature 0 > 2.0)
#                Predict: 0.5652173913043478
#             Else (feature 3 > 7.0)
#              If (feature 5 <= 2.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.9375
#               Else (feature 4 > 2.0)
#                Predict: 0.2727272727272727
#              Else (feature 5 > 2.0)
#               If (feature 9 <= 1.0)
#                Predict: 1.0
#               Else (feature 9 > 1.0)
#                Predict: 0.359375
#            Else (feature 7 > 9.0)
#             If (feature 3 <= 4.0)
#              If (feature 7 <= 10.0)
#               Predict: 0.0
#              Else (feature 7 > 10.0)
#               If (feature 9 <= 5.0)
#                Predict: 0.5
#               Else (feature 9 > 5.0)
#                Predict: 1.0
#             Else (feature 3 > 4.0)
#              If (feature 9 <= 1.0)
#               Predict: 1.0
#              Else (feature 9 > 1.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.14
#               Else (feature 7 > 12.0)
#                Predict: 0.3076923076923077
#          Else (feature 5 > 4.0)
#           If (feature 4 <= 3.0)
#            If (feature 9 <= 1.0)
#             If (feature 7 <= 10.0)
#              If (feature 5 <= 8.0)
#               If (feature 5 <= 7.0)
#                Predict: 1.2222222222222223
#               Else (feature 5 > 7.0)
#                Predict: 1.0
#              Else (feature 5 > 8.0)
#               If (feature 2 <= 1.0)
#                Predict: 1.6666666666666667
#               Else (feature 2 > 1.0)
#                Predict: 1.2307692307692308
#             Else (feature 7 > 10.0)
#              Predict: 1.0
#            Else (feature 9 > 1.0)
#             If (feature 3 <= 5.0)
#              If (feature 9 <= 5.0)
#               If (feature 9 <= 3.0)
#                Predict: 0.3111111111111111
#               Else (feature 9 > 3.0)
#                Predict: 0.65625
#              Else (feature 9 > 5.0)
#               If (feature 3 <= 2.0)
#                Predict: 0.2727272727272727
#               Else (feature 3 > 2.0)
#                Predict: 0.13592233009708737
#             Else (feature 3 > 5.0)
#              If (feature 7 <= 11.0)
#               If (feature 5 <= 5.0)
#                Predict: 0.2564102564102564
#               Else (feature 5 > 5.0)
#                Predict: 0.4791666666666667
#              Else (feature 7 > 11.0)
#               If (feature 5 <= 12.0)
#                Predict: 0.603448275862069
#               Else (feature 5 > 12.0)
#                Predict: 1.375
#           Else (feature 4 > 3.0)
#            If (feature 9 <= 1.0)
#             If (feature 0 <= 2.0)
#              Predict: 1.0
#             Else (feature 0 > 2.0)
#              If (feature 0 <= 3.0)
#               Predict: 2.0
#              Else (feature 0 > 3.0)
#               Predict: 1.0
#            Else (feature 9 > 1.0)
#             If (feature 6 <= 1.0)
#              If (feature 8 <= 2.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.46153846153846156
#               Else (feature 7 > 12.0)
#                Predict: 1.1666666666666667
#              Else (feature 8 > 2.0)
#               If (feature 2 <= 3.0)
#                Predict: 0.5294117647058824
#               Else (feature 2 > 3.0)
#                Predict: 0.07142857142857142
#             Else (feature 6 > 1.0)
#              If (feature 5 <= 9.0)
#               If (feature 7 <= 9.0)
#                Predict: 0.22950819672131148
#               Else (feature 7 > 9.0)
#                Predict: 0.0
#              Else (feature 5 > 9.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.5454545454545454
#               Else (feature 0 > 2.0)
#                Predict: 0.13513513513513514
#        Else (feature 1 > 1.0)
#         If (feature 5 <= 1.0)
#          If (feature 8 <= 1.0)
#           If (feature 9 <= 1.0)
#            If (feature 3 <= 3.0)
#             If (feature 7 <= 7.0)
#              Predict: 2.0
#             Else (feature 7 > 7.0)
#              Predict: 1.0
#            Else (feature 3 > 3.0)
#             Predict: 1.0
#           Else (feature 9 > 1.0)
#            If (feature 2 <= 1.0)
#             If (feature 1 <= 2.0)
#              Predict: 0.0
#             Else (feature 1 > 2.0)
#              If (feature 1 <= 11.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.5476190476190477
#               Else (feature 7 > 12.0)
#                Predict: 0.9
#              Else (feature 1 > 11.0)
#               Predict: 0.0
#            Else (feature 2 > 1.0)
#             If (feature 3 <= 7.0)
#              If (feature 7 <= 12.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.23076923076923078
#               Else (feature 4 > 2.0)
#                Predict: 0.08823529411764706
#              Else (feature 7 > 12.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.0
#               Else (feature 0 > 1.0)
#                Predict: 0.0
#             Else (feature 3 > 7.0)
#              If (feature 1 <= 5.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.45454545454545453
#               Else (feature 0 > 3.0)
#                Predict: 0.75
#              Else (feature 1 > 5.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.5
#               Else (feature 7 > 2.0)
#                Predict: 0.1956521739130435
#          Else (feature 8 > 1.0)
#           If (feature 8 <= 3.0)
#            If (feature 3 <= 7.0)
#             If (feature 7 <= 8.0)
#              If (feature 1 <= 10.0)
#               If (feature 9 <= 10.0)
#                Predict: 0.9393939393939394
#               Else (feature 9 > 10.0)
#                Predict: 0.47368421052631576
#              Else (feature 1 > 10.0)
#               If (feature 9 <= 2.0)
#                Predict: 0.8
#               Else (feature 9 > 2.0)
#                Predict: 0.0
#             Else (feature 7 > 8.0)
#              If (feature 0 <= 1.0)
#               If (feature 4 <= 2.0)
#                Predict: 1.0
#               Else (feature 4 > 2.0)
#                Predict: 0.45454545454545453
#              Else (feature 0 > 1.0)
#               If (feature 9 <= 1.0)
#                Predict: 1.0
#               Else (feature 9 > 1.0)
#                Predict: 0.30303030303030304
#            Else (feature 3 > 7.0)
#             If (feature 9 <= 1.0)
#              Predict: 1.0
#             Else (feature 9 > 1.0)
#              If (feature 1 <= 5.0)
#               If (feature 7 <= 10.0)
#                Predict: 0.11320754716981132
#               Else (feature 7 > 10.0)
#                Predict: 0.45
#              Else (feature 1 > 5.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.07692307692307693
#               Else (feature 7 > 2.0)
#                Predict: 0.536
#           Else (feature 8 > 3.0)
#            If (feature 9 <= 2.0)
#             If (feature 6 <= 3.0)
#              If (feature 3 <= 3.0)
#               Predict: 2.0
#              Else (feature 3 > 3.0)
#               If (feature 3 <= 11.0)
#                Predict: 1.0
#               Else (feature 3 > 11.0)
#                Predict: 0.0
#             Else (feature 6 > 3.0)
#              If (feature 1 <= 3.0)
#               Predict: 0.0
#              Else (feature 1 > 3.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.0
#               Else (feature 0 > 1.0)
#                Predict: 1.0
#            Else (feature 9 > 2.0)
#             If (feature 3 <= 2.0)
#              If (feature 7 <= 6.0)
#               If (feature 9 <= 5.0)
#                Predict: 0.8571428571428571
#               Else (feature 9 > 5.0)
#                Predict: 0.0
#              Else (feature 7 > 6.0)
#               If (feature 9 <= 9.0)
#                Predict: 0.875
#               Else (feature 9 > 9.0)
#                Predict: 2.0
#             Else (feature 3 > 2.0)
#              If (feature 7 <= 2.0)
#               Predict: 0.0
#              Else (feature 7 > 2.0)
#               If (feature 2 <= 2.0)
#                Predict: 0.2815533980582524
#               Else (feature 2 > 2.0)
#                Predict: 0.48936170212765956
#         Else (feature 5 > 1.0)
#          If (feature 5 <= 11.0)
#           If (feature 9 <= 1.0)
#            If (feature 4 <= 1.0)
#             If (feature 0 <= 1.0)
#              If (feature 6 <= 1.0)
#               Predict: 0.0
#              Else (feature 6 > 1.0)
#               If (feature 7 <= 10.0)
#                Predict: 0.10714285714285714
#               Else (feature 7 > 10.0)
#                Predict: 0.25
#             Else (feature 0 > 1.0)
#              If (feature 3 <= 11.0)
#               If (feature 5 <= 8.0)
#                Predict: 0.5365853658536586
#               Else (feature 5 > 8.0)
#                Predict: 0.20512820512820512
#              Else (feature 3 > 11.0)
#               If (feature 5 <= 2.0)
#                Predict: 0.5
#               Else (feature 5 > 2.0)
#                Predict: 0.11538461538461539
#            Else (feature 4 > 1.0)
#             If (feature 5 <= 6.0)
#              If (feature 0 <= 3.0)
#               If (feature 3 <= 7.0)
#                Predict: 0.5578947368421052
#               Else (feature 3 > 7.0)
#                Predict: 0.2571428571428571
#              Else (feature 0 > 3.0)
#               If (feature 5 <= 3.0)
#                Predict: 0.41025641025641024
#               Else (feature 5 > 3.0)
#                Predict: 0.0425531914893617
#             Else (feature 5 > 6.0)
#              If (feature 3 <= 6.0)
#               If (feature 3 <= 4.0)
#                Predict: 0.4262295081967213
#               Else (feature 3 > 4.0)
#                Predict: 0.17391304347826086
#              Else (feature 3 > 6.0)
#               If (feature 1 <= 6.0)
#                Predict: 0.23595505617977527
#               Else (feature 1 > 6.0)
#                Predict: 0.7142857142857143
#           Else (feature 9 > 1.0)
#            If (feature 5 <= 2.0)
#             If (feature 3 <= 2.0)
#              If (feature 8 <= 3.0)
#               If (feature 1 <= 2.0)
#                Predict: 4.5
#               Else (feature 1 > 2.0)
#                Predict: 1.4893617021276595
#              Else (feature 8 > 3.0)
#               If (feature 4 <= 1.0)
#                Predict: 6.333333333333333
#               Else (feature 4 > 1.0)
#                Predict: 1.25
#             Else (feature 3 > 2.0)
#              If (feature 9 <= 2.0)
#               If (feature 7 <= 2.0)
#                Predict: 3.0
#               Else (feature 7 > 2.0)
#                Predict: 1.2682926829268293
#              Else (feature 9 > 2.0)
#               If (feature 3 <= 10.0)
#                Predict: 0.5271317829457365
#               Else (feature 3 > 10.0)
#                Predict: 0.4265402843601896
#            Else (feature 5 > 2.0)
#             If (feature 3 <= 11.0)
#              If (feature 5 <= 3.0)
#               If (feature 3 <= 3.0)
#                Predict: 1.0393700787401574
#               Else (feature 3 > 3.0)
#                Predict: 0.765079365079365
#              Else (feature 5 > 3.0)
#               If (feature 5 <= 10.0)
#                Predict: 0.7064528899445764
#               Else (feature 5 > 10.0)
#                Predict: 0.8068181818181818
#             Else (feature 3 > 11.0)
#              If (feature 9 <= 11.0)
#               If (feature 7 <= 11.0)
#                Predict: 0.49206349206349204
#               Else (feature 7 > 11.0)
#                Predict: 0.8734939759036144
#              Else (feature 9 > 11.0)
#               If (feature 2 <= 2.0)
#                Predict: 0.9401709401709402
#               Else (feature 2 > 2.0)
#                Predict: 1.1415094339622642
#          Else (feature 5 > 11.0)
#           If (feature 3 <= 11.0)
#            If (feature 7 <= 9.0)
#             If (feature 9 <= 10.0)
#              If (feature 1 <= 11.0)
#               If (feature 3 <= 6.0)
#                Predict: 0.4880636604774536
#               Else (feature 3 > 6.0)
#                Predict: 0.3349397590361446
#              Else (feature 1 > 11.0)
#               If (feature 9 <= 2.0)
#                Predict: 0.125
#               Else (feature 9 > 2.0)
#                Predict: 0.9318181818181818
#             Else (feature 9 > 10.0)
#              If (feature 1 <= 10.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.7129629629629629
#               Else (feature 4 > 2.0)
#                Predict: 0.367816091954023
#              Else (feature 1 > 10.0)
#               If (feature 3 <= 10.0)
#                Predict: 0.9347826086956522
#               Else (feature 3 > 10.0)
#                Predict: 1.8
#            Else (feature 7 > 9.0)
#             If (feature 3 <= 9.0)
#              If (feature 9 <= 9.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.44047619047619047
#               Else (feature 6 > 2.0)
#                Predict: 0.6783216783216783
#              Else (feature 9 > 9.0)
#               If (feature 1 <= 10.0)
#                Predict: 0.8064516129032258
#               Else (feature 1 > 10.0)
#                Predict: 1.2222222222222223
#             Else (feature 3 > 9.0)
#              If (feature 1 <= 11.0)
#               If (feature 9 <= 9.0)
#                Predict: 0.6617647058823529
#               Else (feature 9 > 9.0)
#                Predict: 1.3333333333333333
#              Else (feature 1 > 11.0)
#               If (feature 7 <= 10.0)
#                Predict: 9.0
#               Else (feature 7 > 10.0)
#                Predict: 1.8333333333333333
#           Else (feature 3 > 11.0)
#            If (feature 9 <= 11.0)
#             If (feature 9 <= 3.0)
#              If (feature 4 <= 3.0)
#               If (feature 7 <= 8.0)
#                Predict: 0.1388888888888889
#               Else (feature 7 > 8.0)
#                Predict: 0.8620689655172413
#              Else (feature 4 > 3.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.625
#               Else (feature 8 > 3.0)
#                Predict: 1.0
#             Else (feature 9 > 3.0)
#              If (feature 5 <= 12.0)
#               If (feature 3 <= 12.0)
#                Predict: 1.2564102564102564
#               Else (feature 3 > 12.0)
#                Predict: 0.48214285714285715
#              Else (feature 5 > 12.0)
#               If (feature 3 <= 12.0)
#                Predict: 0.47619047619047616
#               Else (feature 3 > 12.0)
#                Predict: 1.36
#            Else (feature 9 > 11.0)
#             If (feature 0 <= 3.0)
#              If (feature 1 <= 11.0)
#               If (feature 0 <= 1.0)
#                Predict: 2.25
#               Else (feature 0 > 1.0)
#                Predict: 1.2941176470588236
#              Else (feature 1 > 11.0)
#               If (feature 4 <= 2.0)
#                Predict: 2.5
#               Else (feature 4 > 2.0)
#                Predict: 2.0
#             Else (feature 0 > 3.0)
#              If (feature 1 <= 3.0)
#               Predict: 3.0
#              Else (feature 1 > 3.0)
#               If (feature 7 <= 9.0)
#                Predict: 1.6666666666666667
#               Else (feature 7 > 9.0)
#                Predict: 3.0
#      Else (feature 1 > 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 7 <= 12.0)
#         If (feature 2 <= 3.0)
#          If (feature 3 <= 12.0)
#           If (feature 3 <= 5.0)
#            If (feature 5 <= 5.0)
#             If (feature 7 <= 6.0)
#              If (feature 7 <= 1.0)
#               Predict: 0.0
#              Else (feature 7 > 1.0)
#               If (feature 3 <= 4.0)
#                Predict: 1.0285714285714285
#               Else (feature 3 > 4.0)
#                Predict: 0.4444444444444444
#             Else (feature 7 > 6.0)
#              If (feature 4 <= 1.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.375
#               Else (feature 0 > 3.0)
#                Predict: 1.0
#              Else (feature 4 > 1.0)
#               If (feature 3 <= 3.0)
#                Predict: 0.375
#               Else (feature 3 > 3.0)
#                Predict: 0.125
#            Else (feature 5 > 5.0)
#             If (feature 9 <= 11.0)
#              If (feature 4 <= 2.0)
#               If (feature 5 <= 10.0)
#                Predict: 0.19047619047619047
#               Else (feature 5 > 10.0)
#                Predict: 0.4782608695652174
#              Else (feature 4 > 2.0)
#               If (feature 5 <= 6.0)
#                Predict: 0.0
#               Else (feature 5 > 6.0)
#                Predict: 0.20253164556962025
#             Else (feature 9 > 11.0)
#              If (feature 8 <= 1.0)
#               If (feature 2 <= 1.0)
#                Predict: 5.0
#               Else (feature 2 > 1.0)
#                Predict: 0.6666666666666666
#              Else (feature 8 > 1.0)
#               If (feature 7 <= 11.0)
#                Predict: 0.47058823529411764
#               Else (feature 7 > 11.0)
#                Predict: 1.0
#           Else (feature 3 > 5.0)
#            If (feature 9 <= 12.0)
#             If (feature 4 <= 1.0)
#              If (feature 9 <= 8.0)
#               If (feature 5 <= 2.0)
#                Predict: 0.7368421052631579
#               Else (feature 5 > 2.0)
#                Predict: 0.3114754098360656
#              Else (feature 9 > 8.0)
#               If (feature 7 <= 8.0)
#                Predict: 0.6363636363636364
#               Else (feature 7 > 8.0)
#                Predict: 1.8888888888888888
#             Else (feature 4 > 1.0)
#              If (feature 9 <= 7.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.48148148148148145
#               Else (feature 8 > 1.0)
#                Predict: 0.2441860465116279
#              Else (feature 9 > 7.0)
#               If (feature 5 <= 11.0)
#                Predict: 0.42857142857142855
#               Else (feature 5 > 11.0)
#                Predict: 1.3
#            Else (feature 9 > 12.0)
#             If (feature 8 <= 1.0)
#              Predict: 1.0
#             Else (feature 8 > 1.0)
#              If (feature 6 <= 2.0)
#               If (feature 4 <= 2.0)
#                Predict: 1.2142857142857142
#               Else (feature 4 > 2.0)
#                Predict: 2.0
#              Else (feature 6 > 2.0)
#               Predict: 1.0
#          Else (feature 3 > 12.0)
#           If (feature 5 <= 4.0)
#            If (feature 0 <= 3.0)
#             Predict: 2.0
#            Else (feature 0 > 3.0)
#             If (feature 7 <= 5.0)
#              Predict: 1.0
#             Else (feature 7 > 5.0)
#              If (feature 2 <= 1.0)
#               Predict: 2.0
#              Else (feature 2 > 1.0)
#               If (feature 6 <= 1.0)
#                Predict: 2.0
#               Else (feature 6 > 1.0)
#                Predict: 1.0
#           Else (feature 5 > 4.0)
#            If (feature 4 <= 3.0)
#             If (feature 6 <= 3.0)
#              If (feature 2 <= 2.0)
#               Predict: 1.0
#              Else (feature 2 > 2.0)
#               If (feature 5 <= 5.0)
#                Predict: 1.5
#               Else (feature 5 > 5.0)
#                Predict: 1.0
#             Else (feature 6 > 3.0)
#              If (feature 8 <= 2.0)
#               Predict: 2.0
#              Else (feature 8 > 2.0)
#               Predict: 1.0
#            Else (feature 4 > 3.0)
#             If (feature 2 <= 2.0)
#              If (feature 9 <= 1.0)
#               Predict: 2.0
#              Else (feature 9 > 1.0)
#               Predict: 1.0
#             Else (feature 2 > 2.0)
#              Predict: 2.0
#         Else (feature 2 > 3.0)
#          If (feature 9 <= 12.0)
#           If (feature 9 <= 11.0)
#            If (feature 3 <= 12.0)
#             If (feature 3 <= 6.0)
#              If (feature 0 <= 1.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.14285714285714285
#               Else (feature 6 > 2.0)
#                Predict: 0.6923076923076923
#              Else (feature 0 > 1.0)
#               If (feature 5 <= 4.0)
#                Predict: 0.09523809523809523
#               Else (feature 5 > 4.0)
#                Predict: 0.2830188679245283
#             Else (feature 3 > 6.0)
#              If (feature 5 <= 6.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.4666666666666667
#               Else (feature 8 > 3.0)
#                Predict: 0.0
#              Else (feature 5 > 6.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.3125
#               Else (feature 6 > 2.0)
#                Predict: 0.75
#            Else (feature 3 > 12.0)
#             If (feature 4 <= 3.0)
#              If (feature 5 <= 4.0)
#               If (feature 7 <= 1.0)
#                Predict: 1.0
#               Else (feature 7 > 1.0)
#                Predict: 2.0
#              Else (feature 5 > 4.0)
#               Predict: 1.0
#             Else (feature 4 > 3.0)
#              Predict: 1.0
#           Else (feature 9 > 11.0)
#            If (feature 4 <= 2.0)
#             If (feature 7 <= 8.0)
#              If (feature 5 <= 3.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.09090909090909091
#               Else (feature 8 > 3.0)
#                Predict: 1.0
#              Else (feature 5 > 3.0)
#               Predict: 0.0
#             Else (feature 7 > 8.0)
#              Predict: 1.0
#            Else (feature 4 > 2.0)
#             Predict: 0.0
#          Else (feature 9 > 12.0)
#           If (feature 8 <= 2.0)
#            If (feature 0 <= 1.0)
#             Predict: 1.0
#            Else (feature 0 > 1.0)
#             Predict: 2.0
#           Else (feature 8 > 2.0)
#            Predict: 1.0
#        Else (feature 7 > 12.0)
#         If (feature 3 <= 12.0)
#          If (feature 0 <= 2.0)
#           If (feature 8 <= 3.0)
#            Predict: 1.0
#           Else (feature 8 > 3.0)
#            If (feature 9 <= 2.0)
#             Predict: 2.0
#            Else (feature 9 > 2.0)
#             If (feature 6 <= 3.0)
#              If (feature 5 <= 3.0)
#               Predict: 1.0
#              Else (feature 5 > 3.0)
#               Predict: 2.0
#             Else (feature 6 > 3.0)
#              Predict: 1.0
#          Else (feature 0 > 2.0)
#           If (feature 9 <= 12.0)
#            If (feature 4 <= 1.0)
#             Predict: 1.0
#            Else (feature 4 > 1.0)
#             If (feature 9 <= 1.0)
#              Predict: 1.0
#             Else (feature 9 > 1.0)
#              If (feature 3 <= 7.0)
#               If (feature 4 <= 2.0)
#                Predict: 2.0
#               Else (feature 4 > 2.0)
#                Predict: 1.3333333333333333
#              Else (feature 3 > 7.0)
#               If (feature 9 <= 8.0)
#                Predict: 1.0
#               Else (feature 9 > 8.0)
#                Predict: 2.0
#           Else (feature 9 > 12.0)
#            Predict: 3.0
#         Else (feature 3 > 12.0)
#          If (feature 4 <= 3.0)
#           Predict: 3.0
#          Else (feature 4 > 3.0)
#           If (feature 0 <= 3.0)
#            Predict: 6.0
#           Else (feature 0 > 3.0)
#            Predict: 3.0
#       Else (feature 5 > 12.0)
#        If (feature 7 <= 12.0)
#         If (feature 2 <= 1.0)
#          If (feature 9 <= 3.0)
#           If (feature 0 <= 1.0)
#            Predict: 1.0
#           Else (feature 0 > 1.0)
#            If (feature 6 <= 2.0)
#             Predict: 1.0
#            Else (feature 6 > 2.0)
#             Predict: 2.0
#          Else (feature 9 > 3.0)
#           Predict: 1.0
#         Else (feature 2 > 1.0)
#          If (feature 9 <= 9.0)
#           If (feature 3 <= 12.0)
#            If (feature 0 <= 2.0)
#             Predict: 1.0
#            Else (feature 0 > 2.0)
#             If (feature 3 <= 4.0)
#              If (feature 8 <= 1.0)
#               Predict: 1.0
#              Else (feature 8 > 1.0)
#               Predict: 2.0
#             Else (feature 3 > 4.0)
#              If (feature 7 <= 5.0)
#               Predict: 1.0
#              Else (feature 7 > 5.0)
#               Predict: 2.0
#           Else (feature 3 > 12.0)
#            Predict: 3.0
#          Else (feature 9 > 9.0)
#           If (feature 9 <= 11.0)
#            Predict: 2.0
#           Else (feature 9 > 11.0)
#            Predict: 3.0
#        Else (feature 7 > 12.0)
#         Predict: 3.0
#   Tree 1:
#     If (feature 8 <= 3.0)
#      If (feature 5 <= 5.0)
#       If (feature 3 <= 5.0)
#        If (feature 1 <= 5.0)
#         If (feature 7 <= 4.0)
#          If (feature 1 <= 4.0)
#           If (feature 3 <= 4.0)
#            If (feature 6 <= 2.0)
#             If (feature 2 <= 2.0)
#              If (feature 6 <= 1.0)
#               If (feature 7 <= 2.0)
#                Predict: 1.125
#               Else (feature 7 > 2.0)
#                Predict: 2.125
#              Else (feature 6 > 1.0)
#               If (feature 9 <= 7.0)
#                Predict: 1.0
#               Else (feature 9 > 7.0)
#                Predict: 0.3333333333333333
#             Else (feature 2 > 2.0)
#              If (feature 9 <= 4.0)
#               If (feature 1 <= 2.0)
#                Predict: 2.888888888888889
#               Else (feature 1 > 2.0)
#                Predict: 6.0
#              Else (feature 9 > 4.0)
#               If (feature 7 <= 3.0)
#                Predict: 1.1904761904761905
#               Else (feature 7 > 3.0)
#                Predict: 2.0
#            Else (feature 6 > 2.0)
#             If (feature 9 <= 3.0)
#              If (feature 4 <= 1.0)
#               Predict: 6.0
#              Else (feature 4 > 1.0)
#               If (feature 8 <= 2.0)
#                Predict: 2.7142857142857144
#               Else (feature 8 > 2.0)
#                Predict: 4.2
#             Else (feature 9 > 3.0)
#              If (feature 4 <= 3.0)
#               If (feature 5 <= 4.0)
#                Predict: 1.1363636363636365
#               Else (feature 5 > 4.0)
#                Predict: 0.2857142857142857
#              Else (feature 4 > 3.0)
#               If (feature 5 <= 2.0)
#                Predict: 2.0
#               Else (feature 5 > 2.0)
#                Predict: 1.0
#           Else (feature 3 > 4.0)
#            If (feature 9 <= 7.0)
#             If (feature 2 <= 1.0)
#              If (feature 9 <= 6.0)
#               Predict: 1.0
#              Else (feature 9 > 6.0)
#               Predict: 3.0
#             Else (feature 2 > 1.0)
#              If (feature 5 <= 4.0)
#               If (feature 5 <= 1.0)
#                Predict: 2.0
#               Else (feature 5 > 1.0)
#                Predict: 1.0
#              Else (feature 5 > 4.0)
#               If (feature 7 <= 1.0)
#                Predict: 1.0
#               Else (feature 7 > 1.0)
#                Predict: 2.0
#            Else (feature 9 > 7.0)
#             If (feature 2 <= 1.0)
#              Predict: 0.0
#             Else (feature 2 > 1.0)
#              If (feature 4 <= 2.0)
#               If (feature 5 <= 2.0)
# ...
#                Predict: 0.3333333333333333
#            Else (feature 5 > 10.0)
#             If (feature 7 <= 12.0)
#              If (feature 7 <= 11.0)
#               If (feature 3 <= 11.0)
#                Predict: 0.8372093023255814
#               Else (feature 3 > 11.0)
#                Predict: 0.5
#              Else (feature 7 > 11.0)
#               If (feature 9 <= 3.0)
#                Predict: 0.0
#               Else (feature 9 > 3.0)
#                Predict: 3.0
#             Else (feature 7 > 12.0)
#              If (feature 4 <= 1.0)
#               If (feature 9 <= 1.0)
#                Predict: 0.0
#               Else (feature 9 > 1.0)
#                Predict: 1.0
#              Else (feature 4 > 1.0)
#               Predict: 0.0
#           Else (feature 1 > 10.0)
#            If (feature 7 <= 11.0)
#             If (feature 4 <= 1.0)
#              If (feature 7 <= 10.0)
#               If (feature 5 <= 12.0)
#                Predict: 0.6470588235294118
#               Else (feature 5 > 12.0)
#                Predict: 0.2
#              Else (feature 7 > 10.0)
#               If (feature 1 <= 11.0)
#                Predict: 1.0
#               Else (feature 1 > 11.0)
#                Predict: 0.1
#             Else (feature 4 > 1.0)
#              If (feature 6 <= 1.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.8181818181818182
#               Else (feature 0 > 3.0)
#                Predict: 0.0
#              Else (feature 6 > 1.0)
#               If (feature 9 <= 3.0)
#                Predict: 0.14285714285714285
#               Else (feature 9 > 3.0)
#                Predict: 0.42857142857142855
#            Else (feature 7 > 11.0)
#             If (feature 4 <= 1.0)
#              If (feature 9 <= 4.0)
#               If (feature 2 <= 2.0)
#                Predict: 0.5
#               Else (feature 2 > 2.0)
#                Predict: 1.0
#              Else (feature 9 > 4.0)
#               If (feature 3 <= 7.0)
#                Predict: 0.0
#               Else (feature 3 > 7.0)
#                Predict: 3.0
#             Else (feature 4 > 1.0)
#              If (feature 6 <= 1.0)
#               Predict: 0.0
#              Else (feature 6 > 1.0)
#               If (feature 1 <= 12.0)
#                Predict: 1.1111111111111112
#               Else (feature 1 > 12.0)
#                Predict: 0.6666666666666666
#          Else (feature 4 > 2.0)
#           If (feature 0 <= 3.0)
#            If (feature 5 <= 12.0)
#             If (feature 8 <= 3.0)
#              If (feature 3 <= 12.0)
#               If (feature 1 <= 7.0)
#                Predict: 0.9166666666666666
#               Else (feature 1 > 7.0)
#                Predict: 0.6126126126126126
#              Else (feature 3 > 12.0)
#               If (feature 5 <= 7.0)
#                Predict: 1.3
#               Else (feature 5 > 7.0)
#                Predict: 0.7894736842105263
#             Else (feature 8 > 3.0)
#              If (feature 9 <= 3.0)
#               If (feature 3 <= 9.0)
#                Predict: 0.0
#               Else (feature 3 > 9.0)
#                Predict: 0.42857142857142855
#              Else (feature 9 > 3.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.3333333333333333
#               Else (feature 4 > 3.0)
#                Predict: 1.2857142857142858
#            Else (feature 5 > 12.0)
#             If (feature 6 <= 2.0)
#              If (feature 0 <= 2.0)
#               If (feature 3 <= 7.0)
#                Predict: 0.0
#               Else (feature 3 > 7.0)
#                Predict: 1.0
#              Else (feature 0 > 2.0)
#               Predict: 0.0
#             Else (feature 6 > 2.0)
#              If (feature 8 <= 2.0)
#               If (feature 7 <= 8.0)
#                Predict: 0.2857142857142857
#               Else (feature 7 > 8.0)
#                Predict: 1.6666666666666667
#              Else (feature 8 > 2.0)
#               If (feature 4 <= 3.0)
#                Predict: 9.0
#               Else (feature 4 > 3.0)
#                Predict: 1.5
#           Else (feature 0 > 3.0)
#            If (feature 6 <= 1.0)
#             If (feature 7 <= 10.0)
#              If (feature 9 <= 3.0)
#               If (feature 5 <= 8.0)
#                Predict: 3.0
#               Else (feature 5 > 8.0)
#                Predict: 1.0
#              Else (feature 9 > 3.0)
#               If (feature 1 <= 8.0)
#                Predict: 1.0
#               Else (feature 1 > 8.0)
#                Predict: 0.0
#             Else (feature 7 > 10.0)
#              If (feature 3 <= 9.0)
#               Predict: 2.0
#              Else (feature 3 > 9.0)
#               Predict: 7.0
#            Else (feature 6 > 1.0)
#             If (feature 6 <= 3.0)
#              If (feature 9 <= 1.0)
#               If (feature 3 <= 10.0)
#                Predict: 0.9
#               Else (feature 3 > 10.0)
#                Predict: 0.25
#              Else (feature 9 > 1.0)
#               If (feature 3 <= 9.0)
#                Predict: 1.25
#               Else (feature 3 > 9.0)
#                Predict: 0.8484848484848485
#             Else (feature 6 > 3.0)
#              If (feature 2 <= 2.0)
#               If (feature 9 <= 2.0)
#                Predict: 0.25
#               Else (feature 9 > 2.0)
#                Predict: 2.0
#              Else (feature 2 > 2.0)
#               Predict: 0.0
#        Else (feature 9 > 6.0)
#         If (feature 2 <= 2.0)
#          If (feature 6 <= 1.0)
#           If (feature 7 <= 11.0)
#            If (feature 3 <= 6.0)
#             If (feature 4 <= 1.0)
#              If (feature 9 <= 10.0)
#               If (feature 7 <= 7.0)
#                Predict: 1.0
#               Else (feature 7 > 7.0)
#                Predict: 0.5
#              Else (feature 9 > 10.0)
#               Predict: 0.0
#             Else (feature 4 > 1.0)
#              If (feature 8 <= 1.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.75
#               Else (feature 2 > 1.0)
#                Predict: 0.0
#              Else (feature 8 > 1.0)
#               If (feature 1 <= 9.0)
#                Predict: 1.125
#               Else (feature 1 > 9.0)
#                Predict: 0.675
#            Else (feature 3 > 6.0)
#             If (feature 5 <= 8.0)
#              If (feature 5 <= 7.0)
#               If (feature 9 <= 11.0)
#                Predict: 1.0
#               Else (feature 9 > 11.0)
#                Predict: 0.0
#              Else (feature 5 > 7.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.0
#               Else (feature 8 > 3.0)
#                Predict: 1.0
#             Else (feature 5 > 8.0)
#              If (feature 9 <= 12.0)
#               If (feature 3 <= 12.0)
#                Predict: 1.6785714285714286
#               Else (feature 3 > 12.0)
#                Predict: 0.625
#              Else (feature 9 > 12.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                Predict: 0.375
#           Else (feature 7 > 11.0)
#            If (feature 3 <= 9.0)
#             If (feature 5 <= 12.0)
#              If (feature 0 <= 1.0)
#               If (feature 4 <= 3.0)
#                Predict: 1.0
#               Else (feature 4 > 3.0)
#                Predict: 0.0
#              Else (feature 0 > 1.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.0
#               Else (feature 4 > 3.0)
#                Predict: 0.6666666666666666
#             Else (feature 5 > 12.0)
#              If (feature 1 <= 9.0)
#               Predict: 0.0
#              Else (feature 1 > 9.0)
#               Predict: 1.0
#            Else (feature 3 > 9.0)
#             If (feature 8 <= 3.0)
#              If (feature 1 <= 9.0)
#               Predict: 1.0
#              Else (feature 1 > 9.0)
#               If (feature 0 <= 3.0)
#                Predict: 2.0
#               Else (feature 0 > 3.0)
#                Predict: 1.0
#             Else (feature 8 > 3.0)
#              Predict: 0.0
#          Else (feature 6 > 1.0)
#           If (feature 3 <= 6.0)
#            If (feature 3 <= 3.0)
#             If (feature 7 <= 9.0)
#              If (feature 0 <= 3.0)
#               If (feature 6 <= 2.0)
#                Predict: 2.3333333333333335
#               Else (feature 6 > 2.0)
#                Predict: 0.9459459459459459
#              Else (feature 0 > 3.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.6666666666666666
#               Else (feature 6 > 2.0)
#                Predict: 0.0
#             Else (feature 7 > 9.0)
#              If (feature 7 <= 10.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.2222222222222222
#               Else (feature 0 > 2.0)
#                Predict: 0.8571428571428571
#              Else (feature 7 > 10.0)
#               If (feature 3 <= 1.0)
#                Predict: 1.0714285714285714
#               Else (feature 3 > 1.0)
#                Predict: 0.65
#            Else (feature 3 > 3.0)
#             If (feature 9 <= 12.0)
#              If (feature 5 <= 12.0)
#               If (feature 1 <= 7.0)
#                Predict: 1.3333333333333333
#               Else (feature 1 > 7.0)
#                Predict: 0.5463917525773195
#              Else (feature 5 > 12.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.4444444444444444
#               Else (feature 8 > 3.0)
#                Predict: 0.0
#             Else (feature 9 > 12.0)
#              If (feature 5 <= 12.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.47619047619047616
#               Else (feature 7 > 12.0)
#                Predict: 1.75
#              Else (feature 5 > 12.0)
#               Predict: 3.0
#           Else (feature 3 > 6.0)
#            If (feature 1 <= 7.0)
#             If (feature 5 <= 8.0)
#              If (feature 9 <= 8.0)
#               Predict: 3.0
#              Else (feature 9 > 8.0)
#               If (feature 9 <= 10.0)
#                Predict: 1.0
#               Else (feature 9 > 10.0)
#                Predict: 3.0
#             Else (feature 5 > 8.0)
#              If (feature 9 <= 7.0)
#               Predict: 2.0
#              Else (feature 9 > 7.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.6666666666666666
#               Else (feature 0 > 2.0)
#                Predict: 1.1538461538461537
#            Else (feature 1 > 7.0)
#             If (feature 0 <= 2.0)
#              If (feature 7 <= 9.0)
#               If (feature 4 <= 2.0)
#                Predict: 1.0
#               Else (feature 4 > 2.0)
#                Predict: 1.55
#              Else (feature 7 > 9.0)
#               If (feature 5 <= 7.0)
#                Predict: 0.3333333333333333
#               Else (feature 5 > 7.0)
#                Predict: 1.0
#             Else (feature 0 > 2.0)
#              If (feature 9 <= 8.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.7142857142857143
#               Else (feature 8 > 3.0)
#                Predict: 1.8333333333333333
#              Else (feature 9 > 8.0)
#               If (feature 7 <= 12.0)
#                Predict: 1.6842105263157894
#               Else (feature 7 > 12.0)
#                Predict: 0.9473684210526315
#         Else (feature 2 > 2.0)
#          If (feature 5 <= 11.0)
#           If (feature 9 <= 11.0)
#            If (feature 3 <= 6.0)
#             If (feature 5 <= 7.0)
#              If (feature 9 <= 7.0)
#               Predict: 1.0
#              Else (feature 9 > 7.0)
#               If (feature 7 <= 7.0)
#                Predict: 1.0
#               Else (feature 7 > 7.0)
#                Predict: 0.08
#             Else (feature 5 > 7.0)
#              If (feature 7 <= 12.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.6764705882352942
#               Else (feature 4 > 2.0)
#                Predict: 0.921875
#              Else (feature 7 > 12.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.5555555555555556
#               Else (feature 8 > 3.0)
#                Predict: 0.0
#            Else (feature 3 > 6.0)
#             If (feature 4 <= 3.0)
#              If (feature 6 <= 2.0)
#               If (feature 7 <= 7.0)
#                Predict: 4.5
#               Else (feature 7 > 7.0)
#                Predict: 2.3773584905660377
#              Else (feature 6 > 2.0)
#               If (feature 6 <= 3.0)
#                Predict: 1.86
#               Else (feature 6 > 3.0)
#                Predict: 1.0714285714285714
#             Else (feature 4 > 3.0)
#              If (feature 6 <= 2.0)
#               If (feature 5 <= 7.0)
#                Predict: 3.0
#               Else (feature 5 > 7.0)
#                Predict: 1.6
#              Else (feature 6 > 2.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.5
#               Else (feature 1 > 9.0)
#                Predict: 1.0
#           Else (feature 9 > 11.0)
#            If (feature 5 <= 9.0)
#             If (feature 3 <= 10.0)
#              If (feature 4 <= 2.0)
#               If (feature 5 <= 8.0)
#                Predict: 1.0
#               Else (feature 5 > 8.0)
#                Predict: 0.5
#              Else (feature 4 > 2.0)
#               If (feature 5 <= 8.0)
#                Predict: 0.35294117647058826
#               Else (feature 5 > 8.0)
#                Predict: 0.5882352941176471
#             Else (feature 3 > 10.0)
#              If (feature 1 <= 12.0)
#               If (feature 5 <= 7.0)
#                Predict: 1.0
#               Else (feature 5 > 7.0)
#                Predict: 2.0
#              Else (feature 1 > 12.0)
#               Predict: 3.0
#            Else (feature 5 > 9.0)
#             If (feature 1 <= 7.0)
#              If (feature 7 <= 9.0)
#               Predict: 5.0
#              Else (feature 7 > 9.0)
#               If (feature 2 <= 3.0)
#                Predict: 2.0
#               Else (feature 2 > 3.0)
#                Predict: 1.0
#             Else (feature 1 > 7.0)
#              If (feature 3 <= 8.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.0
#               Else (feature 0 > 3.0)
#                Predict: 0.5
#              Else (feature 3 > 8.0)
#               If (feature 7 <= 8.0)
#                Predict: 0.875
#               Else (feature 7 > 8.0)
#                Predict: 2.75
#          Else (feature 5 > 11.0)
#           If (feature 3 <= 8.0)
#            If (feature 4 <= 3.0)
#             If (feature 7 <= 7.0)
#              If (feature 1 <= 9.0)
#               Predict: 0.0
#              Else (feature 1 > 9.0)
#               If (feature 3 <= 3.0)
#                Predict: 0.0
#               Else (feature 3 > 3.0)
#                Predict: 0.7777777777777778
#             Else (feature 7 > 7.0)
#              If (feature 1 <= 10.0)
#               If (feature 2 <= 3.0)
#                Predict: 0.52
#               Else (feature 2 > 3.0)
#                Predict: 0.8928571428571429
#              Else (feature 1 > 10.0)
#               If (feature 7 <= 9.0)
#                Predict: 0.875
#               Else (feature 7 > 9.0)
#                Predict: 1.0
#            Else (feature 4 > 3.0)
#             If (feature 3 <= 6.0)
#              If (feature 5 <= 12.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.0
#               Else (feature 8 > 1.0)
#                Predict: 0.1111111111111111
#              Else (feature 5 > 12.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.16666666666666666
#               Else (feature 0 > 2.0)
#                Predict: 1.0
#             Else (feature 3 > 6.0)
#              Predict: 1.0
#           Else (feature 3 > 8.0)
#            If (feature 9 <= 8.0)
#             If (feature 1 <= 12.0)
#              Predict: 1.0
#             Else (feature 1 > 12.0)
#              If (feature 4 <= 1.0)
#               Predict: 0.0
#              Else (feature 4 > 1.0)
#               Predict: 1.0
#            Else (feature 9 > 8.0)
#             If (feature 6 <= 2.0)
#              If (feature 4 <= 1.0)
#               Predict: 1.0
#              Else (feature 4 > 1.0)
#               If (feature 8 <= 1.0)
#                Predict: 1.0
#               Else (feature 8 > 1.0)
#                Predict: 2.1904761904761907
#             Else (feature 6 > 2.0)
#              If (feature 8 <= 1.0)
#               If (feature 6 <= 3.0)
#                Predict: 2.0
#               Else (feature 6 > 3.0)
#                Predict: 1.25
#              Else (feature 8 > 1.0)
#               If (feature 4 <= 3.0)
#                Predict: 1.0
#               Else (feature 4 > 3.0)
#                Predict: 1.4
